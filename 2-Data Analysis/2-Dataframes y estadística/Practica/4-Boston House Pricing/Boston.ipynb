# %%
import pandas as pd

boston_data = pd.read_csv("../../Teoría/data/boston_house_prices.csv")
boston_data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
boston_data[boston_data["CRIM"] > 14]
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 374  18.4982  0.0   18.1     0  0.668  4.138  100.0  1.1370   24  666
# 375  19.6091  0.0   18.1     0  0.671  7.313   97.9  1.3163   24  666
# 376  15.2880  0.0   18.1     0  0.671  6.649   93.3  1.3449   24  666
# 378  23.6482  0.0   18.1     0  0.671  6.380   96.2  1.3861   24  666
# 379  17.8667  0.0   18.1     0  0.671  6.223  100.0  1.3861   24  666
# 380  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666
# 381  15.8744  0.0   18.1     0  0.671  6.545   99.1  1.5192   24  666
# 384  20.0849  0.0   18.1     0  0.700  4.368   91.2  1.4395   24  666
# 385  16.8118  0.0   18.1     0  0.700  5.277   98.1  1.4261   24  666
# 386  24.3938  0.0   18.1     0  0.700  4.652  100.0  1.4672   24  666
# 387  22.5971  0.0   18.1     0  0.700  5.000   89.5  1.5184   24  666
# 388  14.3337  0.0   18.1     0  0.700  4.880  100.0  1.5895   24  666
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 400  25.0461  0.0   18.1     0  0.693  5.987  100.0  1.5888   24  666
# 401  14.2362  0.0   18.1     0  0.693  6.343  100.0  1.5741   24  666
# 403  24.8017  0.0   18.1     0  0.693  5.349   96.0  1.7028   24  666
# 404  41.5292  0.0   18.1     0  0.693  5.531   85.4  1.6074   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 406  20.7162  0.0   18.1     0  0.659  4.138  100.0  1.1781   24  666
# 409  14.4383  0.0   18.1     0  0.597  6.852  100.0  1.4655   24  666
# 410  51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24  666
# 411  14.0507  0.0   18.1     0  0.597  6.657  100.0  1.5275   24  666
# 412  18.8110  0.0   18.1     0  0.597  4.628  100.0  1.5539   24  666
# 413  28.6558  0.0   18.1     0  0.597  5.155  100.0  1.5894   24  666
# 414  45.7461  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666
# 415  18.0846  0.0   18.1     0  0.679  6.434  100.0  1.8347   24  666
# 417  25.9406  0.0   18.1     0  0.679  5.304   89.1  1.6475   24  666
# 418  73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24  666
# 425  15.8603  0.0   18.1     0  0.679  5.896   95.4  1.9096   24  666
# 427  37.6619  0.0   18.1     0  0.679  6.202   78.7  1.8629   24  666
# 436  14.4208  0.0   18.1     0  0.740  6.461   93.3  2.0026   24  666
# 437  15.1772  0.0   18.1     0  0.740  6.152  100.0  1.9142   24  666
# 440  22.0511  0.0   18.1     0  0.740  5.818   92.4  1.8662   24  666
# 468  15.5757  0.0   18.1     0  0.580  5.926   71.0  2.9084   24  666
# 477  15.0234  0.0   18.1     0  0.614  5.304   97.3  2.1007   24  666
# 479  14.3337  0.0   18.1     0  0.614  6.229   88.0  1.9512   24  666
#
#      PTRATIO       B  LSTAT  MEDV
# 374     20.2  396.90  37.97  13.8
# 375     20.2  396.90  13.44  15.0
# 376     20.2  363.02  23.24  13.9
# 378     20.2  396.90  23.69  13.1
# 379     20.2  393.74  21.78  10.2
# 380     20.2  396.90  17.21  10.4
# 381     20.2  396.90  21.08  10.9
# 384     20.2  285.83  30.63   8.8
# 385     20.2  396.90  30.81   7.2
# 386     20.2  396.90  28.28  10.5
# 387     20.2  396.90  31.99   7.4
# 388     20.2  372.92  30.62  10.2
# 398     20.2  396.90  30.59   5.0
# 400     20.2  396.90  26.77   5.6
# 401     20.2  396.90  20.32   7.2
# 403     20.2  396.90  19.77   8.3
# 404     20.2  329.46  27.38   8.5
# 405     20.2  384.97  22.98   5.0
# 406     20.2  370.22  23.34  11.9
# 409     20.2  179.36  19.78  27.5
# 410     20.2    2.60  10.11  15.0
# 411     20.2   35.05  21.22  17.2
# 412     20.2   28.79  34.37  17.9
# 413     20.2  210.97  20.08  16.3
# 414     20.2   88.27  36.98   7.0
# 415     20.2   27.25  29.05   7.2
# 417     20.2  127.36  26.64  10.4
# 418     20.2   16.45  20.62   8.8
# 425     20.2    7.68  24.39   8.3
# 427     20.2   18.82  14.52  10.9
# 436     20.2   27.49  18.05   9.6
# 437     20.2    9.32  26.45   8.7
# 440     20.2  391.45  22.11  10.5
# 468     20.2  368.74  18.13  19.1
# 477     20.2  349.48  24.91  12.0
# 479     20.2  383.32  13.11  21.4

# %%
boston_data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
sns.histplot(boston_data["CRIM"], kde=True);

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x=boston_data["MEDV"], color="sienna");

# %%
from scipy import stats

stats.normaltest(boston_data["MEDV"])
# Out:
# NormaltestResult(statistic=90.9746873700967, pvalue=1.7583188871696095e-20)

# %%
stats.normaltest(boston_data["CRIM"])
# Out:
# NormaltestResult(statistic=562.7482944823795, pvalue=6.320631961562874e-123)

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x=boston_data["CRIM"], color="sienna");

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x=boston_data["NOX"], color="sienna");

# %%
stats.normaltest(boston_data["NOX"])
# Out:
# NormaltestResult(statistic=37.509688611575996, pvalue=7.159366727337585e-09)

# %%
sns.jointplot(x=boston_data['CRIM'],
              y=boston_data['MEDV'],
              color="#4CB391",
             height = 8)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=boston_data['MEDV'],
                y=boston_data['AGE'],
                hue = boston_data['CRIM'],
               s=100);

# %%
# import graph objects as "go"
import plotly.graph_objs as go

# plotly
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)

# create trace 1 that is 3d scatter
trace1 = go.Scatter3d(x=boston_data['MEDV'],
                      y=boston_data['RM'],
                      z = boston_data['CRIM'],
                     mode = 'markers',
                     marker = dict(size = 5, color = 'rgb(255,0,0)'))

data = [trace1]
layout = go.Layout()

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="0371c855-c3c5-4fce-93f3-e89daf3f441b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0371c855-c3c5-4fce-93f3-e89daf3f441b")) {                    Plotly.newPlot(                        "0371c855-c3c5-4fce-93f3-e89daf3f441b",                        [{"marker":{"color":"rgb(255,0,0)","size":5},"mode":"markers","x":[24.0,21.6,34.7,33.4,36.2,28.7,22.9,27.1,16.5,18.9,15.0,18.9,21.7,20.4,18.2,19.9,23.1,17.5,20.2,18.2,13.6,19.6,15.2,14.5,15.6,13.9,16.6,14.8,18.4,21.0,12.7,14.5,13.2,13.1,13.5,18.9,20.0,21.0,24.7,30.8,34.9,26.6,25.3,24.7,21.2,19.3,20.0,16.6,14.4,19.4,19.7,20.5,25.0,23.4,18.9,35.4,24.7,31.6,23.3,19.6,18.7,16.0,22.2,25.0,33.0,23.5,19.4,22.0,17.4,20.9,24.2,21.7,22.8,23.4,24.1,21.4,20.0,20.8,21.2,20.3,28.0,23.9,24.8,22.9,23.9,26.6,22.5,22.2,23.6,28.7,22.6,22.0,22.9,25.0,20.6,28.4,21.4,38.7,43.8,33.2,27.5,26.5,18.6,19.3,20.1,19.5,19.5,20.4,19.8,19.4,21.7,22.8,18.8,18.7,18.5,18.3,21.2,19.2,20.4,19.3,22.0,20.3,20.5,17.3,18.8,21.4,15.7,16.2,18.0,14.3,19.2,19.6,23.0,18.4,15.6,18.1,17.4,17.1,13.3,17.8,14.0,14.4,13.4,15.6,11.8,13.8,15.6,14.6,17.8,15.4,21.5,19.6,15.3,19.4,17.0,15.6,13.1,41.3,24.3,23.3,27.0,50.0,50.0,50.0,22.7,25.0,50.0,23.8,23.8,22.3,17.4,19.1,23.1,23.6,22.6,29.4,23.2,24.6,29.9,37.2,39.8,36.2,37.9,32.5,26.4,29.6,50.0,32.0,29.8,34.9,37.0,30.5,36.4,31.1,29.1,50.0,33.3,30.3,34.6,34.9,32.9,24.1,42.3,48.5,50.0,22.6,24.4,22.5,24.4,20.0,21.7,19.3,22.4,28.1,23.7,25.0,23.3,28.7,21.5,23.0,26.7,21.7,27.5,30.1,44.8,50.0,37.6,31.6,46.7,31.5,24.3,31.7,41.7,48.3,29.0,24.0,25.1,31.5,23.7,23.3,22.0,20.1,22.2,23.7,17.6,18.5,24.3,20.5,24.5,26.2,24.4,24.8,29.6,42.8,21.9,20.9,44.0,50.0,36.0,30.1,33.8,43.1,48.8,31.0,36.5,22.8,30.7,50.0,43.5,20.7,21.1,25.2,24.4,35.2,32.4,32.0,33.2,33.1,29.1,35.1,45.4,35.4,46.0,50.0,32.2,22.0,20.1,23.2,22.3,24.8,28.5,37.3,27.9,23.9,21.7,28.6,27.1,20.3,22.5,29.0,24.8,22.0,26.4,33.1,36.1,28.4,33.4,28.2,22.8,20.3,16.1,22.1,19.4,21.6,23.8,16.2,17.8,19.8,23.1,21.0,23.8,23.1,20.4,18.5,25.0,24.6,23.0,22.2,19.3,22.6,19.8,17.1,19.4,22.2,20.7,21.1,19.5,18.5,20.6,19.0,18.7,32.7,16.5,23.9,31.2,17.5,17.2,23.1,24.5,26.6,22.9,24.1,18.6,30.1,18.2,20.6,17.8,21.7,22.7,22.6,25.0,19.9,20.8,16.8,21.9,27.5,21.9,23.1,50.0,50.0,50.0,50.0,50.0,13.8,13.8,15.0,13.9,13.3,13.1,10.2,10.4,10.9,11.3,12.3,8.8,7.2,10.5,7.4,10.2,11.5,15.1,23.2,9.7,13.8,12.7,13.1,12.5,8.5,5.0,6.3,5.6,7.2,12.1,8.3,8.5,5.0,11.9,27.9,17.2,27.5,15.0,17.2,17.9,16.3,7.0,7.2,7.5,10.4,8.8,8.4,16.7,14.2,20.8,13.4,11.7,8.3,10.2,10.9,11.0,9.5,14.5,14.1,16.1,14.3,11.7,13.4,9.6,8.7,8.4,12.8,10.5,17.1,18.4,15.4,10.8,11.8,14.9,12.6,14.1,13.0,13.4,15.2,16.1,17.8,14.9,14.1,12.7,13.5,14.9,20.0,16.4,17.7,19.5,20.2,21.4,19.9,19.0,19.1,19.1,20.1,19.9,19.6,23.2,29.8,13.8,13.3,16.7,12.0,14.6,21.4,23.0,23.7,25.0,21.8,20.6,21.2,19.1,20.6,15.2,7.0,8.1,13.6,20.1,21.8,24.5,23.1,19.7,18.3,21.2,17.5,16.8,22.4,20.6,23.9,22.0,11.9],"y":[6.575,6.421,7.185,6.998,7.147,6.43,6.012,6.172,5.631,6.004,6.377,6.009,5.889,5.949,6.096,5.834,5.935,5.99,5.456,5.727,5.57,5.965,6.142,5.813,5.924,5.599,5.813,6.047,6.495,6.674,5.713,6.072,5.95,5.701,6.096,5.933,5.841,5.85,5.966,6.595,7.024,6.77,6.169,6.211,6.069,5.682,5.786,6.03,5.399,5.602,5.963,6.115,6.511,5.998,5.888,7.249,6.383,6.816,6.145,5.927,5.741,5.966,6.456,6.762,7.104,6.29,5.787,5.878,5.594,5.885,6.417,5.961,6.065,6.245,6.273,6.286,6.279,6.14,6.232,5.874,6.727,6.619,6.302,6.167,6.389,6.63,6.015,6.121,7.007,7.079,6.417,6.405,6.442,6.211,6.249,6.625,6.163,8.069,7.82,7.416,6.727,6.781,6.405,6.137,6.167,5.851,5.836,6.127,6.474,6.229,6.195,6.715,5.913,6.092,6.254,5.928,6.176,6.021,5.872,5.731,5.87,6.004,5.961,5.856,5.879,5.986,5.613,5.693,6.431,5.637,6.458,6.326,6.372,5.822,5.757,6.335,5.942,6.454,5.857,6.151,6.174,5.019,5.403,5.468,4.903,6.13,5.628,4.926,5.186,5.597,6.12 ...

# %% [markdown]
# Automatizado
#
# Bien con ydata-profiler o PyGWalker: https://github.com/Kanaries/pygwalker

# %%
# !pip install ydata-profiling pygwalker

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(boston_data, title="Boston Report")
profile.to_file("boston_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import pygwalker as pyg

pyg.walk(boston_data)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-000619ceb41e72c8OiBEoJUKh6Zc4Gjz" style="height: auto">\n    <head>…

# %% [markdown]
# Con datos extra

# %%
codes = pd.read_csv('offense_codes.csv', encoding='latin-1')
crimes = pd.read_csv('crime.csv', encoding='latin-1', parse_dates=['OCCURRED_ON_DATE'])
crimes['DAY_OF_WEEK'] = pd.Categorical(crimes['DAY_OF_WEEK'], ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], ordered=True)
crimes['HOUR'] = crimes['OCCURRED_ON_DATE'].dt.hour
codes['CODE'] = codes['CODE'].astype('int')

# %%
crimes[crimes["DISTRICT"].isnull()]
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 15          I182070920          3006               Medical Assistance
# 20          I182070913          3006               Medical Assistance
# 25          I182070906          3831  Motor Vehicle Accident Response
# 39          I182070889          1843                   Drug Violation
# 40          I182070889          3125                  Warrant Arrests
# ...                ...           ...                              ...
# 318337      I152049991          1503               Firearm Violations
# 318338      I152049991          1842                   Drug Violation
# 318528      I152049734          1845                   Drug Violation
# 318551      I152049699          3802  Motor Vehicle Accident Response
# 318601      I152049621           614       Larceny From Motor Vehicle
#
#                                    OFFENSE_DESCRIPTION DISTRICT  \
# 15                       SICK/INJURED/MEDICAL - PERSON      NaN
# 20                       SICK/INJURED/MEDICAL - PERSON      NaN
# 25               M/V - LEAVING SCENE - PROPERTY DAMAGE      NaN
# 39      DRUGS - POSS CLASS B - INTENT TO MFR DIST DISP      NaN
# 40                                      WARRANT ARREST      NaN
# ...                                                ...      ...
# 318337     WEAPON - OTHER - CARRYING / POSSESSING, ETC      NaN
# 318338            DRUGS - POSS CLASS A - HEROIN, ETC.       NaN
# 318528                            DRUGS - POSS CLASS D      NaN
# 318551                 M/V ACCIDENT - PROPERTY  DAMAGE      NaN
# 318601           LARCENY THEFT FROM MV - NON-ACCESSORY      NaN
#
#        REPORTING_AREA SHOOTING    OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  \
# 15                         NaN 2018-09-03 19:43:00  2018      9      Monday
# 20                         NaN 2018-09-03 18:46:00  2018      9      Monday
# 25                         NaN 2018-09-03 18:20:00  2018      9      Monday
# 39                         NaN 2018-09-03 18:05:00  2018      9      Monday
# 40                         NaN 2018-09-03 18:05:00  2018      9      Monday
# ...               ...      ...                 ...   ...    ...         ...
# 318337                     NaN 2015-06-16 18:35:00  2015      6     Tuesday
# 318338                     NaN 2015-06-16 18:35:00  2015      6     Tuesday
# 318528                     NaN 2015-06-15 19:00:00  2015      6      Monday
# 318551                     NaN 2015-06-15 17:13:00  2015      6      Monday
# 318601                     NaN 2015-06-15 11:30:00  2015      6      Monday
#
#         HOUR    UCR_PART    STREET        Lat       Long  \
# 15        19  Part Three       NaN  42.352875 -71.073830
# 20        18  Part Three   WOLCOTT  -1.000000  -1.000000
# 25        18  Part Three       NaN  42.283593 -71.055657
# 39        18    Part Two       NaN  42.306769 -71.084319
# 40        18  Part Three       NaN  42.306769 -71.084319
# ...      ...         ...       ...        ...        ...
# 318337    18    Part Two  HAMILTON        NaN        NaN
# 318338    18    Part Two  HAMILTON        NaN        NaN
# 318528    19    Part Two       NaN        NaN        NaN
# 318551    17  Part Three       NaN        NaN        NaN
# 318601    11    Part One   NEWCOMB        NaN        NaN
#
#                            Location
# 15      (42.35287456, -71.07382970)
# 20       (-1.00000000, -1.00000000)
# 25      (42.28359328, -71.05565683)
# 39      (42.30676881, -71.08431925)
# 40      (42.30676881, -71.08431925)
# ...                             ...
# 318337     (0.00000000, 0.00000000)
# 318338     (0.00000000, 0.00000000)
# 318528     (0.00000000, 0.00000000)
# 318551     (0.00000000, 0.00000000)
# 318601     (0.00000000, 0.00000000)
#
# [1765 rows x 17 columns]

# %%
crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319073 entries, 0 to 319072
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   INCIDENT_NUMBER      319073 non-null  object
#  1   OFFENSE_CODE         319073 non-null  int64
#  2   OFFENSE_CODE_GROUP   319073 non-null  object
#  3   OFFENSE_DESCRIPTION  319073 non-null  object
#  4   DISTRICT             317308 non-null  object
#  5   REPORTING_AREA       319073 non-null  object
#  6   SHOOTING             1019 non-null    object
#  7   OCCURRED_ON_DATE     319073 non-null  datetime64[ns]
#  8   YEAR                 319073 non-null  int64
#  9   MONTH                319073 non-null  int64
#  10  DAY_OF_WEEK          319073 non-null  category
#  11  HOUR                 319073 non-null  int32
#  12  UCR_PART             318983 non-null  object
#  13  STREET               308202 non-null  object
#  14  Lat                  299074 non-null  float64
#  15  Long                 299074 non-null  float64
#  16  Location             319073 non-null  object
# dtypes: category(1), datetime64[ns](1), float64(2), int32(1), int64(3), object(9)
# memory usage: 38.0+ MB

# %%
crimes.describe()
# Out:
#         OFFENSE_CODE               OCCURRED_ON_DATE           YEAR  \
# count  319073.000000                         319073  319073.000000
# mean     2317.546956  2017-01-25 11:54:00.922723072    2016.560586
# min       111.000000            2015-06-15 00:00:00    2015.000000
# 25%      1001.000000            2016-04-12 01:23:00    2016.000000
# 50%      2907.000000            2017-01-28 03:17:00    2017.000000
# 75%      3201.000000            2017-11-05 18:14:00    2017.000000
# max      3831.000000            2018-09-03 21:25:00    2018.000000
# std      1185.285543                            NaN       0.996344
#
#                MONTH           HOUR            Lat           Long
# count  319073.000000  319073.000000  299074.000000  299074.000000
# mean        6.609719      13.118205      42.214381     -70.908272
# min         1.000000       0.000000      -1.000000     -71.178674
# 25%         4.000000       9.000000      42.297442     -71.097135
# 50%         7.000000      14.000000      42.325538     -71.077524
# 75%         9.000000      18.000000      42.348624     -71.062467
# max        12.000000      23.000000      42.395042      -1.000000
# std         3.273691       6.294205       2.159766       3.493618

# %%
crimes.head(2)
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP OFFENSE_DESCRIPTION  \
# 0      I182070945           619            Larceny  LARCENY ALL OTHERS
# 1      I182070943          1402          Vandalism           VANDALISM
#
#   DISTRICT REPORTING_AREA SHOOTING    OCCURRED_ON_DATE  YEAR  MONTH  \
# 0      D14            808      NaN 2018-09-02 13:00:00  2018      9
# 1      C11            347      NaN 2018-08-21 00:00:00  2018      8
#
#   DAY_OF_WEEK  HOUR  UCR_PART      STREET        Lat       Long  \
# 0      Sunday    13  Part One  LINCOLN ST  42.357791 -71.139371
# 1     Tuesday     0  Part Two    HECLA ST  42.306821 -71.060300
#
#                       Location
# 0  (42.35779134, -71.13937053)
# 1  (42.30682138, -71.06030035)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

def offense_groups_countplot(data, title, xlabel, ylabel, size):
    plt.figure(figsize=size)
    ax = sns.countplot(y=data['OFFENSE_CODE_GROUP'], palette='viridis', hue=data['OFFENSE_CODE_GROUP'], order=data['OFFENSE_CODE_GROUP'].value_counts().index)
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    plt.title(title, fontsize=16, fontweight='bold', pad=10)
    plt.xlabel(xlabel, weight='bold')
    plt.ylabel(ylabel, weight='bold')
    plt.tight_layout()
    plt.show()

serious = crimes[crimes['UCR_PART'] == 'Part One']
offense_groups_countplot(serious, 'Most serious offenses', '# of crimes', 'Offense Group', (12,5))

# %%
crimes_dow_hour = crimes.pivot_table(index='DAY_OF_WEEK', columns='HOUR', values='INCIDENT_NUMBER', aggfunc='count', observed=False)

def heatmap_plot(data, title):
    plt.figure(figsize=(10,3))
    ax = sns.heatmap(data, cmap='BuPu')
    ax.xaxis.set_ticks_position('top')
    _ = plt.xlabel('')
    _ = plt.ylabel('')
    _ = plt.title(title, fontsize=16, fontweight='bold', pad=10)
    plt.tight_layout()
    plt.show()

heatmap_plot(crimes_dow_hour, 'Hourly Crimes')

# %%
crimes['SHOOTING'].value_counts()
# Out:
# SHOOTING
# Y    1019
# Name: count, dtype: int64

# %%
shootings = crimes[~crimes['SHOOTING'].isna()]
shootings.head()
# Out:
#      INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 1295      I182069509           413  Aggravated Assault
# 1860      I182068876           413  Aggravated Assault
# 3259      I182067317           111            Homicide
# 3260      I182067317          2662          Ballistics
# 4107      I182066420           413  Aggravated Assault
#
#                       OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 1295       ASSAULT - AGGRAVATED - BATTERY      E18            540        Y
# 1860       ASSAULT - AGGRAVATED - BATTERY       B2            183        Y
# 3259  MURDER, NON-NEGLIGIENT MANSLAUGHTER       B2            312        Y
# 3260            BALLISTICS EVIDENCE/FOUND       B2            312        Y
# 4107       ASSAULT - AGGRAVATED - BATTERY      A15            900        Y
#
#         OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  UCR_PART  \
# 1295 2018-08-29 23:19:00  2018      8   Wednesday    23  Part One
# 1860 2018-08-27 22:56:00  2018      8      Monday    22  Part One
# 3259 2018-08-22 15:00:00  2018      8   Wednesday    15  Part One
# 3260 2018-08-22 15:00:00  2018      8   Wednesday    15  Part Two
# 4107 2018-08-19 22:46:00  2018      8      Sunday    22  Part One
#
#             STREET        Lat       Long                     Location
# 1295     HILLIS RD  42.250405 -71.131737  (42.25040550, -71.13173740)
# 1860     DUDLEY ST  42.321042 -71.072153  (42.32104169, -71.07215291)
# 3259  HOLLANDER ST  42.315689 -71.089514  (42.31568920, -71.08951391)
# 3260  HOLLANDER ST  42.315689 -71.089514  (42.31568920, -71.08951391)
# 4107    MCNULTY CT  42.378085 -71.057841  (42.37808452, -71.05784115)

# %%
offense_groups_countplot(shootings, 'Crimes related to shootings', '# of crimes', 'Offense Group', (16,8))

# %%
shootings_dow = shootings.pivot_table(index='DAY_OF_WEEK', columns='HOUR', values='INCIDENT_NUMBER', aggfunc='count', observed=False)
heatmap_plot(shootings_dow, 'Hourly Shootings')

# %%
shootings_sat = shootings[shootings['DAY_OF_WEEK'].eq('Saturday') & shootings['HOUR'].eq(0)]
offense_groups_countplot(shootings_sat, "Saturday's Midnight Crimes", '# of crimes committed', 'Offense Group', (12,5))

# %%
display(shootings['DISTRICT'].value_counts() / len(shootings))
print((shootings['DISTRICT'].value_counts() / len(shootings))[:3].sum())
# Out:
# DISTRICT
# B2     0.337586
# B3     0.216879
# C11    0.183513
# E13    0.063788
# D4     0.054956
# C6     0.040236
# E18    0.033366
# D14    0.019627
# E5     0.018646
# A7     0.013739
# A1     0.010795
# A15    0.004907
# Name: count, dtype: float64
# 0.7379784102060845

# %%
# !pip install geopandas

# %%
import geopandas as gpd
from shapely.geometry import Point
geo = gpd.read_file(r'Boston_Neighborhoods.geojson')

# Removing abnormal data and transforming the data
serious = serious[(serious['Lat']>40) & (serious['Long']<-69)]
serious_gdf = gpd.GeoDataFrame(serious, geometry=gpd.GeoSeries(serious.apply(lambda s: Point((s['Long'], s['Lat'])), axis=1)))

# Merging GDFs
intersects_gdf = gpd.sjoin(serious_gdf, geo, how='right')
display(intersects_gdf.head(2))

# Getting number of serious crimes per neighborhood and preparing for plot
crimes_per_nb = gpd.GeoDataFrame(intersects_gdf.groupby('Name')['INCIDENT_NUMBER'].count().to_frame('Crimes') \
                                    .merge(geo.set_index('Name'), left_index=True, right_index=True, how='inner')) \
                                    .reset_index()
crimes_per_nb['coords'] = crimes_per_nb['geometry'].apply(lambda x: x.representative_point().coords[:])
crimes_per_nb['coords'] = [coords[0] for coords in crimes_per_nb['coords']]
display(crimes_per_nb.head())
# Out:
# /tmp/ipykernel_11947/2448867948.py:10: UserWarning:
#
# CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#    index_left INCIDENT_NUMBER  OFFENSE_CODE          OFFENSE_CODE_GROUP  \
# 0       120.0      I182070805         616.0                     Larceny
# 0       165.0      I182070759         614.0  Larceny From Motor Vehicle
#
#                      OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0               LARCENY THEFT OF BICYCLE       E5            564      NaN
# 0  LARCENY THEFT FROM MV - NON-ACCESSORY       E5            562      NaN
#
#      OCCURRED_ON_DATE    YEAR  ...       Long                     Location  \
# 0 2018-09-02 21:51:00  2018.0  ... -71.121390  (42.29277202, -71.12138967)
# 0 2018-09-02 16:45:00  2018.0  ... -71.126586  (42.28788933, -71.12658585)
#
#    OBJECTID        Name        Acres  Neighborhood_ID  SqMiles   ShapeSTArea  \
# 0        27  Roslindale  1605.568237               15     2.51  6.993827e+07
# 0        27  Roslindale  1605.568237               15     2.51  6.993827e+07
#
#    ShapeSTLength                                           geometry
# 0   53563.912597  MULTIPOLYGON (((-71.12593 42.27201, -71.12611 ...
# 0   53563.912597  MULTIPOLYGON (((-71.12593 42.27201, -71.12611 ...
#
# [2 rows x 26 columns]
#           Name  Crimes  OBJECTID        Acres Neighborhood_ID  SqMiles  \
# 0      Allston    1947        51   998.534479              24     1.56
# 1     Back Bay    5305        37   399.314411               2     0.62
# 2  Bay Village     216        31    26.539839              33     0.04
# 3  Beacon Hill     655        41   200.156904              30     0.31
# 4     Brighton    1916        44  1840.408596              25     2.88
#
#     ShapeSTArea  ShapeSTLength  \
# 0  4.349599e+07   37859.091242
# 1  1.739407e+07   19455.671146
# 2  1.156071e+06    4650.635493
# 3  8.718800e+06   14303.829017
# 4  8.016788e+07   48787.519652
#
#                                             geometry  \
# 0  POLYGON ((-71.13517 42.34601, -71.13338 42.347...
# 1  POLYGON ((-71.07569 42.35692, -71.07571 42.356...
# 2  POLYGON ((-71.06663 42.34878, -71.06663 42.348...
# 3  POLYGON ((-71.07141 42.36119, -71.07308 42.361...
# 4  POLYGON ((-71.13517 42.34601, -71.13823 42.347...
#
#                                     coords
# 0  (-71.12697288663797, 42.35986959769542)
# 1  (-71.08136045159323, 42.34924974964974)
# 2   (-71.0687104592235, 42.34934955969946)
# 3  (-71.06884200243624, 42.35661870441018)
# 4  (-71.1567888753615, 42.348577418976184)

# %%
crimes_per_nb
# Out:
#                        Name  Crimes  OBJECTID        Acres Neighborhood_ID  \
# 0                   Allston    1947        51   998.534479              24
# 1                  Back Bay    5305        37   399.314411               2
# 2               Bay Village     216        31    26.539839              33
# 3               Beacon Hill     655        41   200.156904              30
# 4                  Brighton    1916        44  1840.408596              25
# 5               Charlestown    1085        39   871.541223               4
# 6                 Chinatown     686        33    76.324410              26
# 7                Dorchester   12152        48  4662.879457               6
# 8                  Downtown    5310        42   397.472846               7
# 9               East Boston    2145        38  3012.059593               8
# 10                   Fenway    2747        43   560.618461              34
# 11           Harbor Islands       0        52   824.888658              22
# 12                Hyde Park    1947        46  2927.221168              10
# 13            Jamaica Plain    3118        28  2519.245394              11
# 14         Leather District     149        32    15.639908              27
# 15                 Longwood     365        30   188.611947              28
# 16                 Mattapan    2106        47  1352.098354              12
# 17             Mission Hill    1261        29   350.853564              13
# 18                North End     516        34   126.910439              14
# 19               Roslindale    1332        27  1605.568237              15
# 20                  Roxbury    6653        35  2108.469072              16
# 21             South Boston    2728        50  1439.888807              17
# 22  South Boston Waterfront     246        49   621.843524              29
# 23                South End    2753        36   471.535356              32
# 24                 West End     638        40   190.490732              31
# 25             West Roxbury     895        45  3516.421786              19
#
#     SqMiles   ShapeSTArea  ShapeSTLength  \
# 0      1.56  4.349599e+07   37859.091242
# 1      0.62  1.739407e+07   19455.671146
# 2      0.04  1.156071e+06    4650.635493
# 3      0.31  8.718800e+06   14303.829017
# 4      2.88  8.016788e+07   48787.519652
# 5      1.36  3.796418e+07   57509.688645
# 6      0.12  3.324678e+06    9736.590413
# 7      7.29  2.031142e+08  104344.034005
# 8      0.62  1.731385e+07   34612.804441
# 9      4.71  1.313845e+08  121089.100852
# 10     0.88  2.442044e+07   24620.876452
# 11     1.29  3.593201e+07   92482.183568
# 12     4.57  1.275092e+08   66861.244955
# 13     3.94  1.097379e+08   56349.937161
# 14     0.02  6.812717e+05    3237.140537
# 15     0.29  8.215904e+06   11908.757148
# 16     2.11  5.889717e+07   42005.773707
# 17     0.55  1.528312e+07   17918.724113
# 18     0.20  5.527506e+06   16177.826815
# 19     2.51  6.993827e+07   53563.912597
# 20     3.29  9.184455e+07   49488.800485
# 21     2.25  6.272131e+07   64998.420283
# 22     0.97  2.708740e+07   38391.352905
# 23     0.74  2.054000e+07   17912.333569
# 24     0.30  8.297743e+06   17728.590027
# 25     5.49  1.531747e+08   66067.419838
#
#                                              geometry  \
# 0   POLYGON ((-71.13517 42.34601, -71.13338 42.347...
# 1   POLYGON ((-71.07569 42.35692, -71.07571 42.356...
# 2   POLYGON ((-71.06663 42.34878, -71.06663 42.348...
# 3   POLYGON ((-71.07141 42.36119, -71.07308 42.361...
# 4   POLYGON ((-71.13517 42.34601, -71.13823 42.347...
# 5   MULTIPOLYGON (((-71.07416 42.39051, -71.07417 ...
# 6   POLYGON ((-71.05791 42.35238, -71.05811 42.352...
# 7   MULTIPOLYGON (((-71.05896 42.32876, -71.05914 ...
# 8   POLYGON ((-71.05342 42.36130, -71.05391 42.361...
# 9   POLYGON ((-70.99546 42.39394, -70.99557 42.394...
# 10  POLYGON ((-71.11011 42.35208, -71.11028 42.352...
# 11  MULTIPOLYGON (((-70.96718 42.31377, -70.96713 ...
# 12  POLYGON ((-71.12588 42.27211, -71.12583 42.272...
# 13  POLYGON ((-71.10499 42.32610, -71.10503 42.326...
# 14  POLYGON ((-71.05838 42.34983, -71.05834 42.349...
# 15  POLYGON ((-71.09811 42.33673, -71.09832 42.337...
# 16  POLYGON ((-71.09633 42.29316, -71.09646 42.293...
# 17  POLYGON ((-71.09043 42.33577, -71.09050 42.335...
# 18  POLYGON ((-71.05200 42.36884, -71.05219 42.368...
# 19  MULTIPOLYGON (((-71.12593 42.27201, -71.12611 ...
# 20  POLYGON ((-71.09646 42.29323, -71.09633 42.293...
# 21  POLYGON ((-71.06104 42.34283, -71.06102 42.342...
# 22  POLYGON ((-71.04348 42.35294, -71.04349 42.352...
# 23  POLYGON ((-71.06834 42.34775, -71.06913 42.347...
# 24  MULTIPOLYGON (((-71.06478 42.36882, -71.06492 ...
# 25  POLYGON ((-71.16470 42.30384, -71.17861 42.294...
#
#                                       coords
# 0    (-71.12697288663797, 42.35986959769542)
# 1    (-71.08136045159323, 42.34924974964974)
# 2     (-71.0687104592235, 42.34934955969946)
# 3    (-71.06884200243624, 42.35661870441018)
# 4    (-71.1567888753615, 42.348577418976184)
# 5      (-71.06329081971847, 42.379541099003)
# 6    (-71.06122663324065, 42.34922674866667)
# 7    (-71.06625571778213, 42.29916897886081)
# 8     (-71.0574461223714, 42.35430045216789)
# 9    (-71.02819136219634, 42.37184786655102)
# 10    (-71.0958404777981, 42.34394085614191)
# 11   (-70.95829330576048, 42.35043480617428)
# 12   (-71.12765436555979, 42.25155826697539)
# 13  (-71.11741230311375, 42.308246349570766)
# 14    (-71.0579043478778, 42.35090955419071)
# 15   (-71.10484838512677, 42.33903747754854)
# 16   (-71.09066515423027, 42.27807915730341)
# 17   (-71.10414988317825, 42.33181646459366)
# 18   (-71.05391940172257, 42.36530966577081)
# 19  (-71.12383770493841, 42.283116123534356)
# 20  (-71.08558192538757, 42.316782584158275)
# 21    (-71.04640108800334, 42.3338175210791)
# 22   (-71.03872344590019, 42.34668419189418)
# 23    (-71.0722690548413, 42.34011533769142)
# 24  (-71.06436093849825, 42.365024189959016)
# 25   (-71.16327194045641, 42.27835923245998)

# %%
import matplotlib.patheffects as pe
sns.set_style('dark')
ax = crimes_per_nb.plot(column='Crimes', cmap='viridis', legend=True, figsize=(20,10))
for idx, row in crimes_per_nb.iterrows():
    plt.annotate(text=row['Name'], xy=row['coords'],
                 horizontalalignment='center', color='midnightblue', path_effects=[pe.withStroke(linewidth=2, foreground="white")], weight='bold', fontsize=8, rotation=30)
ax.axis('off')
plt.tight_layout()
plt.show()
