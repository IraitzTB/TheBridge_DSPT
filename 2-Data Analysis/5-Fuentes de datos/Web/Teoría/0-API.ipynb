# %% [markdown]
# # Obtención de Datos Mediante APIs en Python

# %% [markdown]
# Alguna de las formas de obtención de datos es a través de **APIs (Application Programming Interfaces)**. Las APIs son una forma eficiente de acceder a datos y servicios en línea. Aprenderemos a realizar solicitudes a través de Python utilizando la popular biblioteca `requests`.

# %% [markdown]
# ## Introducción a las APIs

# %% [markdown]
# Una API (Application Programming Interface) es un conjunto de reglas y protocolos que permiten a diferentes aplicaciones interactuar entre sí. Las APIs permiten a las aplicaciones solicitar datos o realizar acciones en un servidor remoto de manera estructurada y estandarizada.
#
# ![imagen](./img/http.PNG)

# %% [markdown]
# ## Protocolo HTTP

# %% [markdown]
# El Protocolo de Transferencia de Hipertexto (HTTP) es el protocolo subyacente utilizado en la World Wide Web. Se utiliza para solicitar y transmitir datos en la web.
#
# ![imagen](./img/peticion_respuesta.PNG)
#
# Aquí tienes un ejemplo de arquitectura:
#
# ![imagen](./img/arquitectura_servidor.PNG)
#
# Las solicitudes HTTP se pueden realizar utilizando varios métodos, siendo los más comunes:
#
# * **GET**: Para recuperar datos.
# * **POST**: Para enviar datos al servidor.
# * **PUT**: Para actualizar datos en el servidor.
# * **DELETE**: Para eliminar datos en el servidor.
#
#
# ![imagen](./img/documentacion_api.PNG)

# %% [markdown]
# Podemos hacer una petición:
#
# ![imagen](./img/parametros.PNG)
#
# y obtener como respuesta diferentes códigos:
#
# ![imagen](./img/status_codes.PNG)

# %% [markdown]
# ## Biblioteca ``requests``

# %% [markdown]
# La biblioteca requests es una de las más populares para realizar solicitudes HTTP en Python. Permite enviar solicitudes y procesar respuestas de una manera sencilla y eficiente.

# %%
# !pip install requests

# %%
# Importamos librerias
import requests
import zipfile
import pandas as pd

# %% [markdown]
# ## Primera petición

# %%
url = "https://pbs.twimg.com/profile_images/616689518968762368/rkhjKqNb.jpg"
image = requests.get(url)

# %%
image
# Out:
# <Response [200]>

# %%
image.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xe2\x02\xa0ICC_PROFILE\x00\x01\x01\x00\x00\x02\x90lcms\x040\x00\x00mntrRGB XYZ \x07\xdf\x00\x07\x00\x02\x00\x13\x00\x1a\x005acspAPPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-lcms\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x0bdesc\x00\x00\x01\x08\x00\x00\x008cprt\x00\x00\x01@\x00\x00\x00Nwtpt\x00\x00\x01\x90\x00\x00\x00\x14chad\x00\x00\x01\xa4\x00\x00\x00,rXYZ\x00\x00\x01\xd0\x00\x00\x00\x14bXYZ\x00\x00\x01\xe4\x00\x00\x00\x14gXYZ\x00\x00\x01\xf8\x00\x00\x00\x14rTRC\x00\x00\x02\x0c\x00\x00\x00 gTRC\x00\x00\x02,\x00\x00\x00 bTRC\x00\x00\x02L\x00\x00\x00 chrm\x00\x00\x02l\x00\x00\x00$mluc\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x0cenUS\x00\x00\x00\x1c\x00\x00\x00\x1c\x00s\x00R\x00G\x00B\x00 \x00b\x00u\x00i\x00l\x00t\x00-\x00i\x00n\x00\x00mluc\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x0cenUS\x00\x00\x002\x00\x00\x00\x1c\x00N\x00o\x00 \x00c\x00o\x00p\x00y\x00r\x00i\x00g\x00h\x00t\x00,\x00 \x00u\x00s\x00e\x00 \x00f\x00r\x00e\x00e\x00l\x00y\x00\x00\x00\x00XYZ \x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-sf32\x00\x00\x00\x00\x00\x01\x0cJ\x00\x00\x05\xe3\xff\xff\xf3*\x00\x00\x07\x9b\x00\x00\xfd\x87\xff\xff\xfb\xa2\xff\xff\xfd\xa3\x00\x00\x03\xd8\x00\x00\xc0\x94XYZ \x00\x00\x00\x00\x00\x00o\x94\x00\x008\xee\x00\x00\x03\x90XYZ \x00\x00\x00\x00\x00\x00$\x9d\x00\x00\x0f\x83\x00\x00\xb6\xbeXYZ \x00\x00\x00\x00\x00\x00b\xa5\x00\x00\xb7\x90\x00\x00\x18\xdepara\x00\x00\x00\x00\x00\x03\x00\x00\x00\x02ff\x00\x00\xf2\xa7\x00\x00\rY\x00\x00\x13\xd0\x00\x00\n[para\x00\x00\x00\x00\x00\x03\x00\x00\x00\x02ff\x00\x00\xf2\xa7\x00\x00\rY\x00\x00\x13\xd0\x00\x00\n[para\x00\x00\x00\x00\x00\x03\x00\x00\x00\x02ff\x00\x00\xf2\xa7\x00\x00\rY\x00\x00\x13\xd0\x00\x00\n[chrm\x00\x00\x00\x00\x00\x03\x00\x00\x00\x00\xa3\xd7\x00\x00T{\x00\x00L\xcd\x00\x00\x99\x9a\x00\x00&f\x00\x00\x0f\\\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x01\x90\x01\x08\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x02\x02\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x06\x05\x07\x02\x03\x04\x01\x08\xff\xc4\x00G\x10\x00\x02\x01\x03\x02\x04\x02\x06\x06\t\x02\x05\x03\x04\x03\x00\x01\x02\x03\x00\x04\x11\x05!\x06\x121AQa\x13"q\x81\x91\xa1\x07\x1426\xb1\xb2\x15#BRbrs\xc1\xd13\x82\x16$C\x92\xe1%\xa2\xc245\xf0\xf1Sc\xd2\xff\xc4\x00\x1b\x01\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x02\x03\x05\x06\x01\x07\xff\xc4\x003\x11\x00\x01\x04\x01\x03\x03\x03\x02\x05\x04\x01\x05\x00\x00\x00\x00\x01\x00\x02\x03\x11\x04\x12!1\x05AQ\x13aq"\x81\x14\x91\xa1\xb1\xc1\x062B\xd1#\x153\xa2\xe1\xf0\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\x92\xaa\xbf\x8d>\xf4O\xfc\x91\xfeQV\x85U\xfci\xf7\xa2\x7f\xe9\xc7\xf9E\x08P\x07\xe7E\x14P\x84QE\x14!\x07\xad\x1e\xda+\xa6\xca\xcd\xaf&\xe4\x19T]\xdd\xbc?\xf3Qs\x83A\'\x85&\xb4\xb8\xd0\\\xb5\xed:i\xda\x15\xab)g\x81Lgo[r\xde\xff\x00\n\xe3\xd5\xf8\\G\x1f\xa6\xd3\xc3\x1e_\xb7\x137o\x15\'\xf0\xa4\x99\xd4"s\xf4\x1d\x93N\xc3\x91\xad\xd47J\xf4\x1a\xd9,\x12\xdb\xb0Y\x91\x90\x9d\xc0=\xeb]<\xd2\x1c,\x14\xa1\x04\x1a(\xf6\xd1E\x02\xbd^"\x8a;yU\xa5\xc0\xdfC\xd7\xba\xda&\xa1\xafz[\x1b\x03\x86H\x06\xd3L<\xf3\xf6W\xdb\xb9\xf2\xa1\n\xb0\x8a\x19n&Xa\x8d\xe5\x91\xba$hY\x8f\xb0\r\xe9\x8a\xd3\xe8\xf7\x8b\xefB4\\=|\x15\xce\x03H\x821\xed<\xc4\x10+\xe8\x8d/L\xd2\xb8v\x0f\xabh\xbau\xbd\xa2\xaf\xaadU\xe6\x91\xbc\xd9\x8e\xe7\xdek\xa9\xa6\x95\xf2ZF>\xd3K\xbb!\xa3a\xbaa\xb8\xcep\xb3\xb2\xf9\xe2\x7f\xa2\xde4\xb7\x8f\x9c\xe8r\xb8\xce1\x1c\x88\xcd\xf0\rK7 ...

# %%
with open("data/mutenrroy.jpg", 'wb') as f:
    f.write(image.content)

# %% [markdown]
# ### Mediante pandas

# %%
df_inflation = pd.read_csv('https://raw.githubusercontent.com/datasets/inflation/master/data/inflation-gdp.csv')
df_inflation.head()
# Out:
#       Country Country Code  Year  Inflation
# 0  Arab World          ARB  1969   1.303790
# 1  Arab World          ARB  1970   2.602241
# 2  Arab World          ARB  1971   6.884719
# 3  Arab World          ARB  1972   2.496081
# 4  Arab World          ARB  1973  11.555281

# %%
df_inflation[df_inflation['Country'] == "Spain"]
# Out:
#      Country Country Code  Year  Inflation
# 9432   Spain          ESP  1961   2.466390
# 9433   Spain          ESP  1962   6.095842
# 9434   Spain          ESP  1963   7.845375
# 9435   Spain          ESP  1964   6.254320
# 9436   Spain          ESP  1965   9.164867
# 9437   Spain          ESP  1966   8.173743
# 9438   Spain          ESP  1967   8.537719
# 9439   Spain          ESP  1968   5.911130
# 9440   Spain          ESP  1969   5.133251
# 9441   Spain          ESP  1970   8.768999
# 9442   Spain          ESP  1971   7.846021
# 9443   Spain          ESP  1972   8.517925
# 9444   Spain          ESP  1973  11.849595
# 9445   Spain          ESP  1974  15.945109
# 9446   Spain          ESP  1975  16.781782
# 9447   Spain          ESP  1976  16.489922
# 9448   Spain          ESP  1977  23.383070
# 9449   Spain          ESP  1978  20.631042
# 9450   Spain          ESP  1979  16.931632
# 9451   Spain          ESP  1980  13.354827
# 9452   Spain          ESP  1981  12.351192
# 9453   Spain          ESP  1982  13.582323
# 9454   Spain          ESP  1983  11.884246
# 9455   Spain          ESP  1984  10.864734
# 9456   Spain          ESP  1985   8.595479
# 9457   Spain          ESP  1986  10.878816
# 9458   Spain          ESP  1987   5.944198
# 9459   Spain          ESP  1988   5.936126
# 9460   Spain          ESP  1989   6.896194
# 9461   Spain          ESP  1990   7.326251
# 9462   Spain          ESP  1991   6.935139
# 9463   Spain          ESP  1992   6.710771
# 9464   Spain          ESP  1993   4.537241
# 9465   Spain          ESP  1994   3.879842
# 9466   Spain          ESP  1995   4.933130
# 9467   Spain          ESP  1996   3.470721
# 9468   Spain          ESP  1997   2.381828
# 9469   Spain          ESP  1998   2.532760
# 9470   Spain          ESP  1999   2.664838
# 9471   Spain          ESP  2000   3.276074
# 9472   Spain          ESP  2001   4.079866
# 9473   Spain          ESP  2002   4.114985
# 9474   Spain          ESP  2003   3.918909
# 9475   Spain          ESP  2004   3.921276
# 9476   Spain          ESP  2005   4.149491
# 9477   Spain          ESP  2006   3.978200
# 9478   Spain          ESP  2007   3.331140
# 9479   Spain          ESP  2008   2.135441
# 9480   Spain          ESP  2009   0.252534
# 9481   Spain          ESP  2010   0.160419
# 9482   Spain          ESP  2011   0.028968
# 9483   Spain          ESP  2012   0.067950
# 9484   Spain          ESP  2013   0.353610
# 9485   Spain          ESP  2014  -0.194984
# 9486   Spain          ESP  2015   0.610876
# 9487   Spain          ESP  2016   0.283304

# %% [markdown]
# ## Bajar datos de Bicimad

# %%
url = 'https://opendata.emtmadrid.es/getattachment/c3383795-121b-4ebf-98b4-c7b05e902eaf/202106_movements.aspx'

r = requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
# Guardamos el zip
filename = 'data/bicis.zip'
with open(filename, 'wb') as f:
   f.write(r.content)

# %%
# Extraemos lo que hay dentro
filename = 'data/bicis.zip'
with zipfile.ZipFile(filename, 'r') as zip_ref:
    zip_ref.extractall("data/")

# %%
# Leemos los datos
datos_bicis = pd.read_json('data/202106_movements.json', lines=True, encoding='latin-1', nrows=10000)

# %%
# Vemos qué pinta tienen
datos_bicis.head()
# Out:
#                                     _id  \
# 0  {'$oid': '60bbf3f21b91311d90d568ad'}
# 1  {'$oid': '60bbf3f21b91311d90d568b2'}
# 2  {'$oid': '60bbf3f21b91311d90d568b3'}
# 3  {'$oid': '60bbf3f21b91311d90d568b4'}
# 4  {'$oid': '60bbf3f21b91311d90d568b5'}
#
#                                        user_day_code  idplug_base  user_type  \
# 0  b67ea824acf706087d5818ebc6f90821a5abaab17a0868...           15          1
# 1  364b1b99f1f9a1748f7abf1134c8d6a46197b583649308...            7          1
# 2  5cc17031cba02835dda4b6c153b56572beaade54d8ab91...           14          1
# 3  6e855acaaa17d6d14236598c0f1172c783e16950e39c01...            8          1
# 4  e93417502d55208995a61f4177956ab9289aba39044ce3...            1          1
#
#    idunplug_base  travel_time  idunplug_station  ageRange  idplug_station  \
# 0             13          319                38         0              54
# 1              1          386               185         0             126
# 2             10          465                15         0              91
# 3             22          613                84         0             236
# 4              4          751               131         5              94
#
#         unplug_hourTime zip_code
# 0  2021-06-01T00:00:00Z
# 1  2021-06-01T00:00:00Z
# 2  2021-06-01T00:00:00Z
# 3  2021-06-01T00:00:00Z
# 4  2021-06-01T00:00:00Z    28006

# %%
datos_bicis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               10000 non-null  object
#  1   user_day_code     10000 non-null  object
#  2   idplug_base       10000 non-null  int64
#  3   user_type         10000 non-null  int64
#  4   idunplug_base     10000 non-null  int64
#  5   travel_time       10000 non-null  int64
#  6   idunplug_station  10000 non-null  int64
#  7   ageRange          10000 non-null  int64
#  8   idplug_station    10000 non-null  int64
#  9   unplug_hourTime   10000 non-null  object
#  10  zip_code          10000 non-null  object
# dtypes: int64(7), object(4)
# memory usage: 859.5+ KB

# %%
datos_bicis['zip_code'].unique()
# Out:
# array(['', '28006', '28004', '28045', '28028', '28009', '28007', '28005',
#        '28010', '28034', '28012', '28001', '28008', '28015', '28002',
#        '28105', 'CODIGO_POSTAL_NOT_DEF', '28013', '39724', '28100',
#        '28800', '28027', '28020', '28011', '28014', '28850', '15002',
#        '28003', '45007', '28046', '28039', '28043', '28038', '28934',
#        '28016', '28945', '28221', '28033', '28030', '28029', '28048',
#        '28054', '28035', '35572', '28049', '28004 ', '28019', '28040',
#        '28941', '28523', '28380', '28933', '28026', '45600', '28938',
#        '28220', '28935', '28760', '28863', '28018', '28250', '28053',
#        '28017', '28024', '28823', '28021', '28922', '28210', '28022',
#        '28036', '28047', '28430', '28041', '46009', '28770', '28031',
#        '28200', '46026', '20540', '28232', '28042', '28071', '18006',
#        '28400', '62973', '2', '28521', '28822', '28411', '28229', '48520',
#        '29039', '28260', '28055', '28942', '28815', '28037', '28702',
#        '28707', '28701', '28290', '28691', '28460', '28936', '28915',
#        '28025', '28750', '28905', '28223', '75014', '28891', '28903',
#        '23009', '28023', '28660', '28006 ', '28924', '28911', '28032',
#        '28801', '10318', '28803', '29740', '28051', '28342', '28912',
#        '28064', '28299', '33206', '28791', '28028 ', '09006', '28917',
#        '19160', '28923', '28350', '29045', '23012', '28670', '28044',
#        '28909', '28450', '28906', '28231'], dtype=object)

# %% [markdown]
# # Acceso a archivos de la pagina de datos.gob.es
# Uno de los mayores catálogos de información pública descargable en España

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio datos.gob.es</h3>
#
# Descarga con pandas un dataset de la página https://datos.gob.es/es/catalogo acerca del empleo y guárdalo en un csv en la carpeta data. Puedes utilizar pandas.
#
#  </td></tr>
# </table>

# %%
# Aquí va vuestro código
response = requests.get("https://datos.gob.es/apidata/catalog/dataset?_sort=title&_pageSize=10&_page=0")
response.status_code
# Out:
# 200

# %%
json_data = response.json()
for item in json_data['result']['items']:
    print(item)
# Out:
# {'_about': 'https://datos.gob.es/catalogo/l01431482-actividades', 'accrualPeriodicity': {'_about': 'https://datos.gob.es/catalogo/l01431482-actividades/Frequency', 'value': {'_about': 'https://datos.gob.es/catalogo/l01431482-actividades/DurationDescription', 'days': 1.0}}, 'description': [{'_value': " Agenda d'Activitats Ciutat de Tarragona", '_lang': 'ca'}, {'_value': ' Agenda of Activities City of Tarragona', '_lang': 'en'}, {'_value': ' Axenda de Actividades Cidade de Tarragona', '_lang': 'gl'}, {'_value': 'Agenda de Actividades Ciudad de Tarragona', '_lang': 'es'}, {'_value': 'Jardueren agenda Tarragonako Udala', '_lang': 'eu'}], 'distribution': [{'_about': 'https://datos.gob.es/catalogo/l01431482-actividades/resource/16c04e07-30ce-4dfc-9345-b8939cce1923', 'accessURL': 'http://dadesobertes.seu-e.cat/api/aoc/action/odata/5368e11e-cfe3-4a8d-b3e9-936df0550d5b?$format=json', 'format': {'_about': 'https://datos.gob.es/catalogo/l01431482-actividades/resource/16c04e07-30ce-4dfc-9345-b8939cce1923/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/json'}, 'title': [{'_value': 'Agenda Actividades', '_lang': 'es'}, {'_value': "Agenda d'Activitats", '_lang': 'en'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/l01431482-actividades/resource/7ffa51f5-594e-4c21-8849-58a2c2e0e76a', 'accessURL': 'http://dadesobertes.seu-e.cat/csv/tarragona/00302.csv', 'format': {'_about': 'https://datos.gob.es/catalogo/l01431482-actividades/resource/7ffa51f5-594e-4c21-8849-58a2c2e0e76a/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'text/csv'}, 'title': [{'_value': 'Agenda Actividades', '_lang': 'es'}, {'_value': "Agenda d'Activitats", '_lang': 'ca'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}], 'keyword': [{'_value': 'Agenda', '_lang': 'es'}, {'_value': 'actividades', '_lang': 'es'}, {'_value': 'cultura', '_lang': 'es'}], 'language': ['ca', 'es'], 'license': 'https://www.boe.es/diario_boe/txt.php?id=BOE-A-2011-17560', 'publisher': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/L01431482', 'spatial': 'http://datos.gob.es/recurso/sector-publico/territorio/Provincia/Tarragona', 'theme': 'http://datos.gob.es/kos/sector-publico/sector/cultura-ocio', 'title': [{'_value': " Agenda d'Activitats Ciutat de Tarragona", '_lang': 'ca'}, {'_value': ' Agenda of Activities City of Tarragona', '_lang': 'en'}, {'_value': ' Axenda de Actividades Cidade de Tarragona', '_lang': 'gl'}, {'_value': ' Jardueren agenda Tarragonako Udala', '_lang': 'eu'}, {'_value': 'Agenda de Actividades Ciudad de Tarragona', '_lang': 'es'}], 'type': 'http://www.w3.org/ns/dcat#Dataset'}
# {'_about': 'https://datos.gob.es/catalogo/a09002970-catala947-la-lengua-catalana-en-los-municipios-de-cataluna', 'description': [{'_value': '#català947 és un projecte de la Secretaria de Política Lingüística per posar a disposició de les institucions, dels recercadors i de la ciutadania tota la informació sociolingüística i de política lingüística disponible de cada municipi de Catalunya.', '_lang': 'ca'}, {'_value': '#català947 és un projecte de la Secretaria de Política Lingüística per posar a disposició de les institucions, dels recercadors i de la ciutadania tota la informació sociolingüística i de política lingüística disponible de cada municipi de Catalunya.', '_lang': 'es'}, {'_value': '#català947 és un projecte de la Secretaria de Política Lingüística per posar a disposició de les institucions, dels recercadors i de la ciutadania tota la informació sociolingüística i de política lingüística disponible de cada municipi de Catalunya.', '_lang': 'en'}], 'distribution': [{'_about': 'https://datos.gob.es/catalogo/a09002970-catala947-la-lengua-catalana-en-los-municipios-de-cataluna/resource/020bfd53-497b-4707-b6e9-99240a2c7b82', 'accessURL': 'https://analisi.transparenciacatalunya.cat/api/views/374c-85cu/rows.xml?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a09002970-catala947-la-lengua-catalana-en-los-municipios-de-cataluna/resource/020bfd53-497b-4707-b6e9-99240a2c7b82/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/xml'}, 'identifier': 'https://analisi.transparenciacatalunya.cat/d/374c-85cu', 'title': [{'_value': '#català947. La lengua catalana en los municipios de Cataluña', '_lang': 'es'}, {'_value': '#català947. La llengua catalana als municipis de Catalunya', '_lang': 'ca'}, {'_value': '#català947. The Catalan language in the municipalities of Catalonia', '_lang': 'en'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/a09002970-catala947-la-lengua-catalana-en-los-municipios-de-cataluna/resource/9d6b9a4d-89bd-42d3-9ba3-d4d40ba0e7a4', 'accessURL': 'https://analisi.transparenciacatalunya.cat/api/views/374c-85cu/rows.json?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a09002970-catala947-la-lengua-catalana-en-los-municipios-de-cataluna/resource/9d6b9a4d-89bd-42d3-9ba3-d4d40ba0e7a4/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/json'}, 'identifier': 'https://analisi.transparenciacatalunya.cat/d/374c-85cu', 'title': [{'_value': '#català947. La lengua catalana en los municipios de Cataluña', '_lang': 'es'}, {'_value': '#català947. La llengua catalana als municipis de Catalunya', '_lang': 'ca'}, {'_value': '#català947. The Catalan language in the municipalities of Catalonia', '_lang': 'en'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/a09002970-catala947-la-lengua-catalana-en-los-municipios-de-cataluna/resource/dfb39975-2a38-440f-a5d8-39ad67ba0cc3', 'accessURL': 'https://analisi.transparenciacatalunya.cat/api/views/374c-85cu/rows.csv?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a09002970-catala947-la-lengua-catalana-en-los-municipios-de-cataluna/resource/dfb39975-2a38-440f-a5d8-39ad67ba0cc3/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'text/csv'}, 'identifier': 'https://analisi.transparenciacatalunya.cat/d/374c-85cu', 'title': [{'_value': '#català947. La lengua catalana en los municipios de Cataluña', '_lang': 'es'}, {'_value': '#català947. La llengua catalana als municipis de Catalunya', '_lang': 'ca'}, {'_value': '#català947. The Catalan language in the municipalities of Catalonia', '_lang': 'en'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/a09002970-catala947-la-lengua-catalana-en-los-municipios-de-cataluna/resource/fa985921-669f-4eaf-a0f3-52bb53739e74', 'accessURL': 'https://analisi.transparenciacatalunya.cat/api/views/374c-85cu/rows.rd ...
# {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-erosion', 'description': [{'_value': 'Area Prevención Riesgos Erosión', '_lang': 'es'}, {'_value': "Capa que delimita les àrees de prevenció de riscs d'erosió d'acord amb les determinacions de la normativa territorial i urbanística.", '_lang': 'ca'}, {'_value': 'Erosion Risk Prevention Area', '_lang': 'en'}], 'distribution': [{'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-erosion/resource/bc6c4638-3df5-48fb-8a1f-8dda820bba00', 'accessURL': 'https://catalegdades.caib.cat/api/views/74pf-baf9/rows.xml?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-erosion/resource/bc6c4638-3df5-48fb-8a1f-8dda820bba00/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/xml'}, 'identifier': 'https://catalegdades.caib.cat/api/views/74pf-baf9/rows.xml?accessType=DOWNLOAD', 'title': [{'_value': 'APR Erosió', '_lang': 'ca'}, {'_value': 'Area Prevención Riesgos Erosión', '_lang': 'es'}, {'_value': 'Erosion Risk Prevention Area', '_lang': 'en'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-erosion/resource/d645de33-6020-4e2d-8bef-05aac8cd17ba', 'accessURL': 'https://catalegdades.caib.cat/api/views/74pf-baf9/rows.csv?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-erosion/resource/d645de33-6020-4e2d-8bef-05aac8cd17ba/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'text/csv'}, 'identifier': 'https://catalegdades.caib.cat/api/views/74pf-baf9/rows.csv?accessType=DOWNLOAD', 'title': [{'_value': 'APR Erosió', '_lang': 'ca'}, {'_value': 'Area Prevención Riesgos Erosión', '_lang': 'es'}, {'_value': 'Erosion Risk Prevention Area', '_lang': 'en'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-erosion/resource/fa1a1534-eda9-4310-a6e0-7e058b2218c9', 'accessURL': 'https://catalegdades.caib.cat/api/views/74pf-baf9/rows.json?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-erosion/resource/fa1a1534-eda9-4310-a6e0-7e058b2218c9/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/json'}, 'identifier': 'https://catalegdades.caib.cat/api/views/74pf-baf9/rows.json?accessType=DOWNLOAD', 'title': [{'_value': 'APR Erosió', '_lang': 'ca'}, {'_value': 'Area Prevención Riesgos Erosión', '_lang': 'es'}, {'_value': 'Erosion Risk Prevention Area', '_lang': 'en'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-erosion/resource/fdbb1993-9f79-42ac-a317-0ed9bbb136af', 'accessURL': 'https://catalegdades.caib.cat/api/views/74pf-baf9/rows.rdf?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-erosion/resource/fdbb1993-9f79-42ac-a317-0ed9bbb136af/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/rdf+xml'}, 'identifier': 'https://catalegdades.caib.cat/api/views/74pf-baf9/rows.rdf?accessType=DOWNLOAD', 'title': [{'_value': 'APR Erosió', '_lang': 'ca'}, {'_value': 'Area Prevención Riesgos Erosión', '_lang': 'es'}, {'_value': 'Erosion Risk Prevention Area', '_lang': 'en'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}], 'identifier': 'https://catalegdades.caib.cat/d/74pf-baf9', 'issued': 'mié, 13 abr 2022 22:00:00 GMT+0000', 'keyword': [{'_value': 'erosion', '_lang': 'es'}, {'_value': 'erosió', '_lang': 'es'}, {'_value': 'erosión', '_lang': 'es'}, {'_value': 'illes balears', '_lang': 'es'}, {'_value': 'risk prevention areas', '_lang': 'es'}, {'_value': 'área prevenció riscs', '_lang': 'es'}, {'_value': 'áreas prevención riesgos', '_lang': 'es'}], 'language': ['ca', 'en', 'es'], 'license': 'http://creativecommons.org/licenses/by/4.0/legalcode', ' ...
# {'_about': 'https://datos.gob.es/catalogo/a04003003-areas-prevencion-riesgos-desprendimientos', 'description': [{'_value': "Capa que delimita les àrees de prevenció de riscs d'esllavissaments d'acord amb les determinacions de la normativa territorial i urbanística.", '_lang': 'ca'}, {'_value': 'Landslide risk prevention areas', '_lang': 'en'}, {'_value': 'Áreas Prevención Riesgos Desprendimientos', '_lang': 'es'}], 'distribution': [{'_about': 'https://datos.gob.es/catalogo/a04003003-areas-prevencion-riesgos-desprendimientos/resource/740ef10a-7c4a-431a-8550-82c777c1516b', 'accessURL': 'https://catalegdades.caib.cat/api/views/mr7i-5p69/rows.xml?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-areas-prevencion-riesgos-desprendimientos/resource/740ef10a-7c4a-431a-8550-82c777c1516b/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/xml'}, 'identifier': 'https://catalegdades.caib.cat/api/views/mr7i-5p69/rows.xml?accessType=DOWNLOAD', 'title': [{'_value': 'APR Esllevissaments', '_lang': 'ca'}, {'_value': 'Landslide risk prevention areas', '_lang': 'en'}, {'_value': 'Áreas Prevención Riesgos Desprendimientos', '_lang': 'es'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/a04003003-areas-prevencion-riesgos-desprendimientos/resource/8799c166-2a74-41c6-811d-6053cae36873', 'accessURL': 'https://catalegdades.caib.cat/api/views/mr7i-5p69/rows.json?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-areas-prevencion-riesgos-desprendimientos/resource/8799c166-2a74-41c6-811d-6053cae36873/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/json'}, 'identifier': 'https://catalegdades.caib.cat/api/views/mr7i-5p69/rows.json?accessType=DOWNLOAD', 'title': [{'_value': 'APR Esllevissaments', '_lang': 'ca'}, {'_value': 'Landslide risk prevention areas', '_lang': 'en'}, {'_value': 'Áreas Prevención Riesgos Desprendimientos', '_lang': 'es'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/a04003003-areas-prevencion-riesgos-desprendimientos/resource/96f0b58c-a23b-49ec-8207-0ae6d5ac53e8', 'accessURL': 'https://catalegdades.caib.cat/api/views/mr7i-5p69/rows.csv?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-areas-prevencion-riesgos-desprendimientos/resource/96f0b58c-a23b-49ec-8207-0ae6d5ac53e8/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'text/csv'}, 'identifier': 'https://catalegdades.caib.cat/api/views/mr7i-5p69/rows.csv?accessType=DOWNLOAD', 'title': [{'_value': 'APR Esllevissaments', '_lang': 'ca'}, {'_value': 'Landslide risk prevention areas', '_lang': 'en'}, {'_value': 'Áreas Prevención Riesgos Desprendimientos', '_lang': 'es'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/a04003003-areas-prevencion-riesgos-desprendimientos/resource/e7ef395e-b1fe-4207-9aa6-c477a79b2797', 'accessURL': 'https://catalegdades.caib.cat/api/views/mr7i-5p69/rows.rdf?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-areas-prevencion-riesgos-desprendimientos/resource/e7ef395e-b1fe-4207-9aa6-c477a79b2797/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/rdf+xml'}, 'identifier': 'https://catalegdades.caib.cat/api/views/mr7i-5p69/rows.rdf?accessType=DOWNLOAD', 'title': [{'_value': 'APR Esllevissaments', '_lang': 'ca'}, {'_value': 'Landslide risk prevention areas', '_lang': 'en'}, {'_value': 'Áreas Prevención Riesgos Desprendimientos', '_lang': 'es'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}], 'identifier': 'https://catalegdades.caib.cat/d/mr7i-5p69', 'issued': 'mié, 13 abr 2022 22:00:00 GMT+0000', 'keyword': [{'_value': 'desprendimientos', '_lang': 'es'}, {'_value': 'esllevissaments', '_lang': 'es'}, {'_value': 'illes balears', '_lang': 'es'}, {'_value': 'landslide', '_lang': 'es'}, {'_value': 'risk prevention areas', '_l ...
# {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-inundaciones', 'description': [{'_value': 'Area Prevención Riesgos Inundaciones', '_lang': 'es'}, {'_value': "Capa que delimita les àrees de prevenció de riscs d'inundació d'acord amb les determinacions de la normativa territorial i urbanística.", '_lang': 'ca'}, {'_value': 'Flood Risk Prevention Area', '_lang': 'en'}], 'distribution': [{'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-inundaciones/resource/669502c0-3b56-4299-a0c1-c4bd09be691f', 'accessURL': 'https://catalegdades.caib.cat/api/views/ngdb-fd8p/rows.rdf?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-inundaciones/resource/669502c0-3b56-4299-a0c1-c4bd09be691f/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/rdf+xml'}, 'identifier': 'https://catalegdades.caib.cat/api/views/ngdb-fd8p/rows.rdf?accessType=DOWNLOAD', 'title': [{'_value': 'APR Inundació', '_lang': 'ca'}, {'_value': 'Area Prevención Riesgos Inundaciones', '_lang': 'es'}, {'_value': 'Flood Risk Prevention Area', '_lang': 'en'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-inundaciones/resource/739623c1-abef-4ec2-8412-bbe41e868871', 'accessURL': 'https://catalegdades.caib.cat/api/views/ngdb-fd8p/rows.xml?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-inundaciones/resource/739623c1-abef-4ec2-8412-bbe41e868871/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/xml'}, 'identifier': 'https://catalegdades.caib.cat/api/views/ngdb-fd8p/rows.xml?accessType=DOWNLOAD', 'title': [{'_value': 'APR Inundació', '_lang': 'ca'}, {'_value': 'Area Prevención Riesgos Inundaciones', '_lang': 'es'}, {'_value': 'Flood Risk Prevention Area', '_lang': 'en'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-inundaciones/resource/8417038b-9f41-4efb-a0bf-c18a4922f71f', 'accessURL': 'https://catalegdades.caib.cat/api/views/ngdb-fd8p/rows.json?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-inundaciones/resource/8417038b-9f41-4efb-a0bf-c18a4922f71f/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/json'}, 'identifier': 'https://catalegdades.caib.cat/api/views/ngdb-fd8p/rows.json?accessType=DOWNLOAD', 'title': [{'_value': 'APR Inundació', '_lang': 'ca'}, {'_value': 'Area Prevención Riesgos Inundaciones', '_lang': 'es'}, {'_value': 'Flood Risk Prevention Area', '_lang': 'en'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-inundaciones/resource/a31acc49-2dd5-4314-9836-07dec3e827f4', 'accessURL': 'https://catalegdades.caib.cat/api/views/ngdb-fd8p/rows.csv?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-area-prevencion-riesgos-inundaciones/resource/a31acc49-2dd5-4314-9836-07dec3e827f4/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'text/csv'}, 'identifier': 'https://catalegdades.caib.cat/api/views/ngdb-fd8p/rows.csv?accessType=DOWNLOAD', 'title': [{'_value': 'APR Inundació', '_lang': 'ca'}, {'_value': 'Area Prevención Riesgos Inundaciones', '_lang': 'es'}, {'_value': 'Flood Risk Prevention Area', '_lang': 'en'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}], 'identifier': 'https://catalegdades.caib.cat/d/ngdb-fd8p', 'issued': 'mié, 13 abr 2022 22:00:00 GMT+0000', 'keyword': [{'_value': 'flood', '_lang': 'es'}, {'_value': 'illes balears', '_lang': 'es'}, {'_value': 'inundació', '_lang': 'es'}, {'_value': 'inundación', '_lang': 'es'}, {'_value': 'risk prevention areas', '_lang': 'es'}, {'_value': 'área prevenció riscs', '_lang': 'es'}, {'_value': 'áreas prevención riesgos', '_lang': 'es'}], 'language': ['ca', 'e ...
# {'_about': 'https://datos.gob.es/catalogo/a04003003-apt', 'description': [{'_value': 'APT', '_lang': 'en'}, {'_value': 'APT', '_lang': 'es'}, {'_value': "Capa que delimita les àrees de protecció territorial d'acord amb les determinacions de la normativa territorial i urbanística", '_lang': 'ca'}], 'distribution': [{'_about': 'https://datos.gob.es/catalogo/a04003003-apt/resource/0984c807-3c58-4363-9e13-b58e42aa1a4c', 'accessURL': 'https://catalegdades.caib.cat/api/views/nsmi-29dr/rows.json?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-apt/resource/0984c807-3c58-4363-9e13-b58e42aa1a4c/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/json'}, 'identifier': 'https://catalegdades.caib.cat/api/views/nsmi-29dr/rows.json?accessType=DOWNLOAD', 'title': [{'_value': 'APT', '_lang': 'en'}, {'_value': 'APT', '_lang': 'es'}, {'_value': 'APT', '_lang': 'ca'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/a04003003-apt/resource/61c1f1c7-a556-44b6-8a0d-12c70892d389', 'accessURL': 'https://catalegdades.caib.cat/api/views/nsmi-29dr/rows.csv?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-apt/resource/61c1f1c7-a556-44b6-8a0d-12c70892d389/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'text/csv'}, 'identifier': 'https://catalegdades.caib.cat/api/views/nsmi-29dr/rows.csv?accessType=DOWNLOAD', 'title': [{'_value': 'APT', '_lang': 'en'}, {'_value': 'APT', '_lang': 'es'}, {'_value': 'APT', '_lang': 'ca'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/a04003003-apt/resource/d1e5d177-29c2-45ee-9fc2-78bcfb113a21', 'accessURL': 'https://catalegdades.caib.cat/api/views/nsmi-29dr/rows.rdf?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-apt/resource/d1e5d177-29c2-45ee-9fc2-78bcfb113a21/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/rdf+xml'}, 'identifier': 'https://catalegdades.caib.cat/api/views/nsmi-29dr/rows.rdf?accessType=DOWNLOAD', 'title': [{'_value': 'APT', '_lang': 'en'}, {'_value': 'APT', '_lang': 'es'}, {'_value': 'APT', '_lang': 'ca'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}, {'_about': 'https://datos.gob.es/catalogo/a04003003-apt/resource/ef1862a4-a449-404a-adfc-c4e0d4e36b85', 'accessURL': 'https://catalegdades.caib.cat/api/views/nsmi-29dr/rows.xml?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-apt/resource/ef1862a4-a449-404a-adfc-c4e0d4e36b85/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/xml'}, 'identifier': 'https://catalegdades.caib.cat/api/views/nsmi-29dr/rows.xml?accessType=DOWNLOAD', 'title': [{'_value': 'APT', '_lang': 'en'}, {'_value': 'APT', '_lang': 'es'}, {'_value': 'APT', '_lang': 'ca'}], 'type': 'http://www.w3.org/ns/dcat#Distribution'}], 'identifier': 'https://catalegdades.caib.cat/d/nsmi-29dr', 'issued': 'mié, 13 abr 2022 22:00:00 GMT+0000', 'language': ['ca', 'en', 'es'], 'license': 'http://creativecommons.org/licenses/by/4.0/legalcode', 'modified': 'jue, 09 may 2024 22:00:00 GMT+0000', 'publisher': 'http://datos.gob.es/recurso/sector-publico/org/Organismo/A04003003', 'spatial': 'http://datos.gob.es/recurso/sector-publico/territorio/Autonomia/Illes-Balears', 'theme': 'http://datos.gob.es/kos/sector-publico/sector/urbanismo-infraestructuras', 'title': [{'_value': 'APT', '_lang': 'ca'}, {'_value': 'APT', '_lang': 'en'}, {'_value': 'APT', '_lang': 'es'}], 'type': 'http://www.w3.org/ns/dcat#Dataset'}
# {'_about': 'https://datos.gob.es/catalogo/a04003003-arpsi-avinguda-10-anys', 'description': [{'_value': '<DIV STYLE="text-align:Left;font-size:12pt"><P><SPAN>Avinguda 10 anys de la delimitació gràfica de la superfície negada per les aigües per l\'ocurrència d\'avingudes amb períodes de retorn de 10, 100 i 500 anys, valors que s\'han convingut com a referència per als esdeveniments d\'alta, mitja i baixa probabilitat, respectivament (en aplicació de l\'article 8.1 del Reial Decret 903/2010). Aquesta informació, acompanyada de l\'estimació de les variables que caracteritzen l\'efecte potencial advers de les crescudes, permet establir el grau d\'exposició al fenòmen de les diferents parts del territori.Aquest CDE està format perles zones d\'avinguda i els calats per avinguda. Els 11 trams ARPSI són dels torrents de Na Bàrbara (Palma), Gros (Palma), Coanegre (Palma/Marratxí), Campos, Es Riuet (Manacor/Sant Llorenç des Cardassar), ses Planes (Sant Llorenç des Cardassar), Vall den Marc/Sant Jordi (Pollença), Major de Sóller, Peguera (Calvià), Santa Ponça (Calvià) i Llavanera (Eivissa/Santa Eulària del Riu).</SPAN></P></DIV>', '_lang': 'ca'}, {'_value': '<DIV STYLE="text-align:Left;font-size:12pt"><P><SPAN>Avinguda 10 anys de la delimitació gràfica de la superfície negada per les aigües per l\'ocurrència d\'avingudes amb períodes de retorn de 10, 100 i 500 anys, valors que s\'han convingut com a referència per als esdeveniments d\'alta, mitja i baixa probabilitat, respectivament (en aplicació de l\'article 8.1 del Reial Decret 903/2010). Aquesta informació, acompanyada de l\'estimació de les variables que caracteritzen l\'efecte potencial advers de les crescudes, permet establir el grau d\'exposició al fenòmen de les diferents parts del territori.Aquest CDE està format perles zones d\'avinguda i els calats per avinguda. Els 11 trams ARPSI són dels torrents de Na Bàrbara (Palma), Gros (Palma), Coanegre (Palma/Marratxí), Campos, Es Riuet (Manacor/Sant Llorenç des Cardassar), ses Planes (Sant Llorenç des Cardassar), Vall den Marc/Sant Jordi (Pollença), Major de Sóller, Peguera (Calvià), Santa Ponça (Calvià) i Llavanera (Eivissa/Santa Eulària del Riu).</SPAN></P></DIV>', '_lang': 'en'}, {'_value': '<DIV STYLE="text-align:Left;font-size:12pt"><P><SPAN>Avinguda 10 anys de la delimitació gràfica de la superfície negada per les aigües per l\'ocurrència d\'avingudes amb períodes de retorn de 10, 100 i 500 anys, valors que s\'han convingut com a referència per als esdeveniments d\'alta, mitja i baixa probabilitat, respectivament (en aplicació de l\'article 8.1 del Reial Decret 903/2010). Aquesta informació, acompanyada de l\'estimació de les variables que caracteritzen l\'efecte potencial advers de les crescudes, permet establir el grau d\'exposició al fenòmen de les diferents parts del territori.Aquest CDE està format perles zones d\'avinguda i els calats per avinguda. Els 11 trams ARPSI són dels torrents de Na Bàrbara (Palma), Gros (Palma), Coanegre (Palma/Marratxí), Campos, Es Riuet (Manacor/Sant Llorenç des Cardassar), ses Planes (Sant Llorenç des Cardassar), Vall den Marc/Sant Jordi (Pollença), Major de Sóller, Peguera (Calvià), Santa Ponça (Calvià) i Llavanera (Eivissa/Santa Eulària del Riu).</SPAN></P></DIV>', '_lang': 'es'}], 'distribution': [{'_about': 'https://datos.gob.es/catalogo/a04003003-arpsi-avinguda-10-anys/resource/02e27f2c-f127-48e9-8883-205c93730b26', 'accessURL': 'https://catalegdades.caib.cat/api/views/8zk4-j2w5/rows.rdf?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-arpsi-avinguda-10-anys/resource/02e27f2c-f127-48e9-8883-205c93730b26/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/rdf+xml'}, 'identifier': 'https://catalegdades.caib.cat/api/views/8zk4-j2w5/rows.rdf?accessType=DOWNLOAD', 'title': [{'_value': 'ARPSI Avinguda 10 anys', '_lang': 'en'}, {'_value': 'ARPSI Avinguda 10 anys', '_lang': 'es'}, {'_value': 'ARPSI Avinguda 10 anys', '_lang': 'ca'}], 'type': ' ...
# {'_about': 'https://datos.gob.es/catalogo/a04003003-arpsi-avinguda-100-anys', 'description': [{'_value': '<DIV STYLE="text-align:Left;font-size:12pt"><P><SPAN>Avinguda 100 anys de la delimitació gràfica de la superfície negada per les aigües per l\'ocurrència d\'avingudes amb períodes de retorn de 10, 100 i 500 anys, valors que s\'han convingut com a referència per als esdeveniments d\'alta, mitja i baixa probabilitat, respectivament (en aplicació de l\'article 8.1 del Reial Decret 903/2010). Aquesta informació, acompanyada de l\'estimació de les variables que caracteritzen l\'efecte potencial advers de les crescudes, permet establir el grau d\'exposició al fenòmen de les diferents parts del territori.Aquest CDE està format perles zones d\'avinguda i els calats per avinguda. Els 11 trams ARPSI són dels torrents de Na Bàrbara (Palma), Gros (Palma), Coanegre (Palma/Marratxí), Campos, Es Riuet (Manacor/Sant Llorenç des Cardassar), ses Planes (Sant Llorenç des Cardassar), Vall den Marc/Sant Jordi (Pollença), Major de Sóller, Peguera (Calvià), Santa Ponça (Calvià) i Llavanera (Eivissa/Santa Eulària del Riu).</SPAN></P></DIV>', '_lang': 'ca'}, {'_value': '<DIV STYLE="text-align:Left;font-size:12pt"><P><SPAN>Avinguda 100 anys de la delimitació gràfica de la superfície negada per les aigües per l\'ocurrència d\'avingudes amb períodes de retorn de 10, 100 i 500 anys, valors que s\'han convingut com a referència per als esdeveniments d\'alta, mitja i baixa probabilitat, respectivament (en aplicació de l\'article 8.1 del Reial Decret 903/2010). Aquesta informació, acompanyada de l\'estimació de les variables que caracteritzen l\'efecte potencial advers de les crescudes, permet establir el grau d\'exposició al fenòmen de les diferents parts del territori.Aquest CDE està format perles zones d\'avinguda i els calats per avinguda. Els 11 trams ARPSI són dels torrents de Na Bàrbara (Palma), Gros (Palma), Coanegre (Palma/Marratxí), Campos, Es Riuet (Manacor/Sant Llorenç des Cardassar), ses Planes (Sant Llorenç des Cardassar), Vall den Marc/Sant Jordi (Pollença), Major de Sóller, Peguera (Calvià), Santa Ponça (Calvià) i Llavanera (Eivissa/Santa Eulària del Riu).</SPAN></P></DIV>', '_lang': 'en'}, {'_value': '<DIV STYLE="text-align:Left;font-size:12pt"><P><SPAN>Avinguda 100 anys de la delimitació gràfica de la superfície negada per les aigües per l\'ocurrència d\'avingudes amb períodes de retorn de 10, 100 i 500 anys, valors que s\'han convingut com a referència per als esdeveniments d\'alta, mitja i baixa probabilitat, respectivament (en aplicació de l\'article 8.1 del Reial Decret 903/2010). Aquesta informació, acompanyada de l\'estimació de les variables que caracteritzen l\'efecte potencial advers de les crescudes, permet establir el grau d\'exposició al fenòmen de les diferents parts del territori.Aquest CDE està format perles zones d\'avinguda i els calats per avinguda. Els 11 trams ARPSI són dels torrents de Na Bàrbara (Palma), Gros (Palma), Coanegre (Palma/Marratxí), Campos, Es Riuet (Manacor/Sant Llorenç des Cardassar), ses Planes (Sant Llorenç des Cardassar), Vall den Marc/Sant Jordi (Pollença), Major de Sóller, Peguera (Calvià), Santa Ponça (Calvià) i Llavanera (Eivissa/Santa Eulària del Riu).</SPAN></P></DIV>', '_lang': 'es'}], 'distribution': [{'_about': 'https://datos.gob.es/catalogo/a04003003-arpsi-avinguda-100-anys/resource/1522f329-91f5-4030-9f03-4747d13e1052', 'accessURL': 'https://catalegdades.caib.cat/api/views/9bsd-2732/rows.json?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-arpsi-avinguda-100-anys/resource/1522f329-91f5-4030-9f03-4747d13e1052/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/json'}, 'identifier': 'https://catalegdades.caib.cat/api/views/9bsd-2732/rows.json?accessType=DOWNLOAD', 'title': [{'_value': 'ARPSI Avinguda 100 anys', '_lang': 'ca'}, {'_value': 'ARPSI Avinguda 100 anys', '_lang': 'en'}, {'_value': 'ARPSI Avinguda 100 anys', '_lang': 'es'}], ' ...
# {'_about': 'https://datos.gob.es/catalogo/a04003003-arpsi-avinguda-500-anys', 'description': [{'_value': '<DIV STYLE="text-align:Left;font-size:12pt"><P><SPAN>Avinguda 500 anys de la delimitació gràfica de la superfície negada per les aigües per l\'ocurrència d\'avingudes amb períodes de retorn de 10, 100 i 500 anys, valors que s\'han convingut com a referència per als esdeveniments d\'alta, mitja i baixa probabilitat, respectivament (en aplicació de l\'article 8.1 del Reial Decret 903/2010). Aquesta informació, acompanyada de l\'estimació de les variables que caracteritzen l\'efecte potencial advers de les crescudes, permet establir el grau d\'exposició al fenòmen de les diferents parts del territori.Aquest CDE està format perles zones d\'avinguda i els calats per avinguda. Els 11 trams ARPSI són dels torrents de Na Bàrbara (Palma), Gros (Palma), Coanegre (Palma/Marratxí), Campos, Es Riuet (Manacor/Sant Llorenç des Cardassar), ses Planes (Sant Llorenç des Cardassar), Vall den Marc/Sant Jordi (Pollença), Major de Sóller, Peguera (Calvià), Santa Ponça (Calvià) i Llavanera (Eivissa/Santa Eulària del Riu).</SPAN></P></DIV>', '_lang': 'en'}, {'_value': '<DIV STYLE="text-align:Left;font-size:12pt"><P><SPAN>Avinguda 500 anys de la delimitació gràfica de la superfície negada per les aigües per l\'ocurrència d\'avingudes amb períodes de retorn de 10, 100 i 500 anys, valors que s\'han convingut com a referència per als esdeveniments d\'alta, mitja i baixa probabilitat, respectivament (en aplicació de l\'article 8.1 del Reial Decret 903/2010). Aquesta informació, acompanyada de l\'estimació de les variables que caracteritzen l\'efecte potencial advers de les crescudes, permet establir el grau d\'exposició al fenòmen de les diferents parts del territori.Aquest CDE està format perles zones d\'avinguda i els calats per avinguda. Els 11 trams ARPSI són dels torrents de Na Bàrbara (Palma), Gros (Palma), Coanegre (Palma/Marratxí), Campos, Es Riuet (Manacor/Sant Llorenç des Cardassar), ses Planes (Sant Llorenç des Cardassar), Vall den Marc/Sant Jordi (Pollença), Major de Sóller, Peguera (Calvià), Santa Ponça (Calvià) i Llavanera (Eivissa/Santa Eulària del Riu).</SPAN></P></DIV>', '_lang': 'es'}, {'_value': '<DIV STYLE="text-align:Left;font-size:12pt"><P><SPAN>Avinguda 500 anys de la delimitació gràfica de la superfície negada per les aigües per l\'ocurrència d\'avingudes amb períodes de retorn de 10, 100 i 500 anys, valors que s\'han convingut com a referència per als esdeveniments d\'alta, mitja i baixa probabilitat, respectivament (en aplicació de l\'article 8.1 del Reial Decret 903/2010). Aquesta informació, acompanyada de l\'estimació de les variables que caracteritzen l\'efecte potencial advers de les crescudes, permet establir el grau d\'exposició al fenòmen de les diferents parts del territori.Aquest CDE està format perles zones d\'avinguda i els calats per avinguda. Els 11 trams ARPSI són dels torrents de Na Bàrbara (Palma), Gros (Palma), Coanegre (Palma/Marratxí), Campos, Es Riuet (Manacor/Sant Llorenç des Cardassar), ses Planes (Sant Llorenç des Cardassar), Vall den Marc/Sant Jordi (Pollença), Major de Sóller, Peguera (Calvià), Santa Ponça (Calvià) i Llavanera (Eivissa/Santa Eulària del Riu).</SPAN></P></DIV>', '_lang': 'ca'}], 'distribution': [{'_about': 'https://datos.gob.es/catalogo/a04003003-arpsi-avinguda-500-anys/resource/5c7b96ce-a3d8-48bf-afec-9172a5fc62b3', 'accessURL': 'https://catalegdades.caib.cat/api/views/8tqv-3caf/rows.csv?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-arpsi-avinguda-500-anys/resource/5c7b96ce-a3d8-48bf-afec-9172a5fc62b3/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'text/csv'}, 'identifier': 'https://catalegdades.caib.cat/api/views/8tqv-3caf/rows.csv?accessType=DOWNLOAD', 'title': [{'_value': 'ARPSI Avinguda 500 anys', '_lang': 'en'}, {'_value': 'ARPSI Avinguda 500 anys', '_lang': 'es'}, {'_value': 'ARPSI Avinguda 500 anys', '_lang': 'ca'}], 'type': 'ht ...
# {'_about': 'https://datos.gob.es/catalogo/a04003003-arpsi-domini-public-hidraulic-cartografic', 'description': [{'_value': '<DIV STYLE="text-align:Left;font-size:12pt"><P><SPAN>Domini públic hidràulic cartogràfic de la delimitació gràfica de la superfície negada per les aigües per l\'ocurrència d\'avingudes amb períodes de retorn de 10, 100 i 500 anys, valors que s\'han convingut com a referència per als esdeveniments d\'alta, mitja i baixa probabilitat, respectivament (en aplicació de l\'article 8.1 del Reial Decret 903/2010). Aquesta informació, acompanyada de l\'estimació de les variables que caracteritzen l\'efecte potencial advers de les crescudes, permet establir el grau d\'exposició al fenòmen de les diferents parts del territori.Aquest CDE està format perles zones d\'avinguda i els calats per avinguda. Els 11 trams ARPSI són dels torrents de Na Bàrbara (Palma), Gros (Palma), Coanegre (Palma/Marratxí), Campos, Es Riuet (Manacor/Sant Llorenç des Cardassar), ses Planes (Sant Llorenç des Cardassar), Vall den Marc/Sant Jordi (Pollença), Major de Sóller, Peguera (Calvià), Santa Ponça (Calvià) i Llavanera (Eivissa/Santa Eulària del Riu).</SPAN></P></DIV>', '_lang': 'ca'}, {'_value': '<DIV STYLE="text-align:Left;font-size:12pt"><P><SPAN>Domini públic hidràulic cartogràfic de la delimitació gràfica de la superfície negada per les aigües per l\'ocurrència d\'avingudes amb períodes de retorn de 10, 100 i 500 anys, valors que s\'han convingut com a referència per als esdeveniments d\'alta, mitja i baixa probabilitat, respectivament (en aplicació de l\'article 8.1 del Reial Decret 903/2010). Aquesta informació, acompanyada de l\'estimació de les variables que caracteritzen l\'efecte potencial advers de les crescudes, permet establir el grau d\'exposició al fenòmen de les diferents parts del territori.Aquest CDE està format perles zones d\'avinguda i els calats per avinguda. Els 11 trams ARPSI són dels torrents de Na Bàrbara (Palma), Gros (Palma), Coanegre (Palma/Marratxí), Campos, Es Riuet (Manacor/Sant Llorenç des Cardassar), ses Planes (Sant Llorenç des Cardassar), Vall den Marc/Sant Jordi (Pollença), Major de Sóller, Peguera (Calvià), Santa Ponça (Calvià) i Llavanera (Eivissa/Santa Eulària del Riu).</SPAN></P></DIV>', '_lang': 'en'}, {'_value': '<DIV STYLE="text-align:Left;font-size:12pt"><P><SPAN>Domini públic hidràulic cartogràfic de la delimitació gràfica de la superfície negada per les aigües per l\'ocurrència d\'avingudes amb períodes de retorn de 10, 100 i 500 anys, valors que s\'han convingut com a referència per als esdeveniments d\'alta, mitja i baixa probabilitat, respectivament (en aplicació de l\'article 8.1 del Reial Decret 903/2010). Aquesta informació, acompanyada de l\'estimació de les variables que caracteritzen l\'efecte potencial advers de les crescudes, permet establir el grau d\'exposició al fenòmen de les diferents parts del territori.Aquest CDE està format perles zones d\'avinguda i els calats per avinguda. Els 11 trams ARPSI són dels torrents de Na Bàrbara (Palma), Gros (Palma), Coanegre (Palma/Marratxí), Campos, Es Riuet (Manacor/Sant Llorenç des Cardassar), ses Planes (Sant Llorenç des Cardassar), Vall den Marc/Sant Jordi (Pollença), Major de Sóller, Peguera (Calvià), Santa Ponça (Calvià) i Llavanera (Eivissa/Santa Eulària del Riu).</SPAN></P></DIV>', '_lang': 'es'}], 'distribution': [{'_about': 'https://datos.gob.es/catalogo/a04003003-arpsi-domini-public-hidraulic-cartografic/resource/1dcf1463-66b8-4338-a698-ce1d890a1a61', 'accessURL': 'https://catalegdades.caib.cat/api/views/5vcb-psjt/rows.xml?accessType=DOWNLOAD', 'format': {'_about': 'https://datos.gob.es/catalogo/a04003003-arpsi-domini-public-hidraulic-cartografic/resource/1dcf1463-66b8-4338-a698-ce1d890a1a61/format', 'type': 'http://purl.org/dc/terms/IMT', 'value': 'application/xml'}, 'identifier': 'https://catalegdades.caib.cat/api/views/5vcb-psjt/rows.xml?accessType=DOWNLOAD', 'title': [{'_value': 'ARPSI Domini Públic Hidràulic Cartogràfic', '_l ...

# %%
requests.get("http://dadesobertes.seu-e.cat/api/aoc/action/odata/5368e11e-cfe3-4a8d-b3e9-936df0550d5b?$format=csv")
# Out:
# <Response [200]>

# %%
pd.read_csv("http://dadesobertes.seu-e.cat/api/aoc/action/odata/5368e11e-cfe3-4a8d-b3e9-936df0550d5b?$format=csv")
# Out:
# Empty DataFrame
# Columns: [{"error": "DataStore resource not found"}]
# Index: []

# %%
response = requests.get("https://www.opendatabizkaia.eus/es/dump/e9c5f672-ec3f-4094-a230-9dd022b28705/elecciones-europeas-2019?format=json")
response.content
# Out:
# b'{\n  "fields": [{"type":"int","id":"_id"},{"type":"text","id":"EREMUAK/AMBITOS"},{"type":"text","id":"AZALPENA/CONCEPTO"},{"type":"numeric","id":"ZENTSUA/CENSO"},{"type":"numeric","id":"ZENBATUTA %/% ESCRUTADO"},{"type":"text","id":"ADN"},{"type":"text","id":"ALTER"},{"type":"text","id":"AXSI"},{"type":"text","id":"CEX-CREX-PR"},{"type":"text","id":"CONTIGO"},{"type":"text","id":"CPE"},{"type":"text","id":"CS"},{"type":"text","id":"CV-EC"},{"type":"text","id":"CXE"},{"type":"text","id":"EAJ-PNV"},{"type":"text","id":"EH-BILDU OR"},{"type":"text","id":"FAC"},{"type":"text","id":"I.FEM"},{"type":"text","id":"IGRE"},{"type":"text","id":"IZQP"},{"type":"text","id":"JUNTS"},{"type":"text","id":"M.C.R."},{"type":"text","id":"MIEL"},{"type":"text","id":"PACMA/ATTAA"},{"type":"text","id":"PACT"},{"type":"text","id":"PCPE-PCPC-P"},{"type":"text","id":"PCTE-ELAK"},{"type":"text","id":"PH"},{"type":"text","id":"PIRATES/EP"},{"type":"text","id":"PODEMOS-IU"},{"type":"text","id":"PP"},{"type":"text","id":"PSE-EE/PSOE"},{"type":"text","id":"PUM+J"},{"type":"text","id":"R0-LV-GVE"},{"type":"text","id":"SAIN"},{"type":"text","id":"VOLT"},{"type":"text","id":"VOX"},{"type":"text","id":"ZURIAK/BLANCOS"},{"type":"text","id":"BALIOGABEAK/NULOS"},{"type":"text","id":"ABSTENTZIOA %/% ABSTENCION"}],\n  "records": [\n    {"ZENTSUA/CENSO":911770,"M.C.R.":"110","EREMUAK/AMBITOS":"BIZKAIA","CPE":"507","ADN":"121","IGRE":"153","PCPE-PCPC-P":"619","ALTER":"339","PCTE-ELAK":"384","I.FEM":"1238","ABSTENTZIOA %/% ABSTENCION":"0","MIEL":"79","ZENBATUTA %/% ESCRUTADO":100,"BALIOGABEAK/NULOS":"3015","FAC":"156","PH":"189","ZURIAK/BLANCOS":"4490","PIRATES/EP":"309","PSE-EE/PSOE":"109843","AXSI":"71","EH-BILDU OR":"108462","IZQP":"181","CEX-CREX-PR":"115","EAJ-PNV":"226515","VOLT":"381","PACMA/ATTAA":"5051","CV-EC":"1520","CS":"15838","CONTIGO":"125","JUNTS":"2201","PACT":"242","AZALPENA/CONCEPTO":"BOTOAK/VOTOS","PP":"36178","SAIN":"99","PODEMOS-IU":"67161","PUM+J":"549","R0-LV-GVE":"994","CXE":"575","_id":1,"VOX":"7118"},\n    {"ZENTSUA/CENSO":911770,"M.C.R.":"0,02","EREMUAK/AMBITOS":"BIZKAIA","CPE":"0,09","ADN":"0,02","IGRE":"0,03","PCPE-PCPC-P":"0,1","ALTER":"0,06","PCTE-ELAK":"0,06","I.FEM":"0,21","ABSTENTZIOA %/% ABSTENCION":"34,75","MIEL":"0,01","ZENBATUTA %/% ESCRUTADO":100,"BALIOGABEAK/NULOS":"0,51","FAC":"0,03","PH":"0,03","ZURIAK/BLANCOS":"0,76","PIRATES/EP":"0,05","PSE-EE/PSOE":"18,56","AXSI":"0,01","EH-BILDU OR":"18,32","IZQP":"0,03","CEX-CREX-PR":"0,02","EAJ-PNV":"38,27","VOLT":"0,06","PACMA/ATTAA":"0,85","CV-EC":"0,26","CS":"2,68","CONTIGO":"0,02","JUNTS":"0,37","PACT":"0,04","AZALPENA/CONCEPTO":"BOTOEN %/% DE VOTOS","PP":"6,11","SAIN":"0,02","PODEMOS-IU":"11,35","PUM+J":"0,09","R0-LV-GVE":"0,17","CXE":"0,1","_id":2,"VOX":"1,2"},\n    {"ZENTSUA/CENSO":5900,"M.C.R.":"17","EREMUAK/AMBITOS":"ABADI\xc3\x91O","CPE":"2","ADN":"1","IGRE":"0","PCPE-PCPC-P":"1","ALTER":"0","PCTE-ELAK":"1","I.FEM":"5","ABSTENTZIOA %/% ABSTENCION":"0","MIEL":"2","ZENBATUTA %/% ESCRUTADO":100,"BALIOGABEAK/NULOS":"26","FAC":"0","PH":"3","ZURIAK/BLANCOS":"51","PIRATES/EP":"0","PSE-EE/PSOE":"643","AXSI":"0","EH-BILDU OR":"1278","IZQP":"1","CEX-CREX-PR":"1","EAJ-PNV":"1267","VOLT":"1","PACMA/ATTAA":"38","CV-EC":"11","CS":"81","CONTIGO":"1","JUNTS":"10","PACT":"2","AZALPENA/CONCEPTO":"BOTOAK/VOTOS","PP":"155","SAIN":"0","PODEMOS-IU":"403","PUM+J":"2","R0-LV-GVE":"7","CXE":"0","_id":3,"VOX":"35"},\n    {"ZENTSUA/CENSO":5900,"M.C.R.":"0,42","EREMUAK/AMBITOS":"ABADI\xc3\x91O","CPE":"0,05","ADN":"0,02","IGRE":"0","PCPE-PCPC-P":"0,02","ALTER":"0","PCTE-ELAK":"0,02","I.FEM":"0,12","ABSTENTZIOA %/% ABSTENCION":"31,44","MIEL":"0,05","ZENBATUTA %/% ESCRUTADO":100,"BALIOGABEAK/NULOS":"0,64","FAC":"0","PH":"0,07","ZURIAK/BLANCOS":"1,27","PIRATES/EP":"0","PSE-EE/PSOE":"16","AXSI":"0","EH-BILDU OR":"31,8","IZQP":"0,02","CEX-CREX-PR":"0,02","EAJ-PNV":"31,53","VOLT":"0,02","PACMA/ATTAA":"0,95","CV-EC":"0,27","CS":"2,02","CONTIGO":"0,02","JUNTS":"0,25","PACT":"0,05","AZALPENA/CONCEPTO":"BOTOEN %/ ...

# %%
response.json()
# Out:
# {'fields': [{'type': 'int', 'id': '_id'},
#   {'type': 'text', 'id': 'EREMUAK/AMBITOS'},
#   {'type': 'text', 'id': 'AZALPENA/CONCEPTO'},
#   {'type': 'numeric', 'id': 'ZENTSUA/CENSO'},
#   {'type': 'numeric', 'id': 'ZENBATUTA %/% ESCRUTADO'},
#   {'type': 'text', 'id': 'ADN'},
#   {'type': 'text', 'id': 'ALTER'},
#   {'type': 'text', 'id': 'AXSI'},
#   {'type': 'text', 'id': 'CEX-CREX-PR'},
#   {'type': 'text', 'id': 'CONTIGO'},
#   {'type': 'text', 'id': 'CPE'},
#   {'type': 'text', 'id': 'CS'},
#   {'type': 'text', 'id': 'CV-EC'},
#   {'type': 'text', 'id': 'CXE'},
#   {'type': 'text', 'id': 'EAJ-PNV'},
#   {'type': 'text', 'id': 'EH-BILDU OR'},
#   {'type': 'text', 'id': 'FAC'},
#   {'type': 'text', 'id': 'I.FEM'},
#   {'type': 'text', 'id': 'IGRE'},
#   {'type': 'text', 'id': 'IZQP'},
#   {'type': 'text', 'id': 'JUNTS'},
#   {'type': 'text', 'id': 'M.C.R.'},
#   {'type': 'text', 'id': 'MIEL'},
#   {'type': 'text', 'id': 'PACMA/ATTAA'},
#   {'type': 'text', 'id': 'PACT'},
#   {'type': 'text', 'id': 'PCPE-PCPC-P'},
#   {'type': 'text', 'id': 'PCTE-ELAK'},
#   {'type': 'text', 'id': 'PH'},
#   {'type': 'text', 'id': 'PIRATES/EP'},
#   {'type': 'text', 'id': 'PODEMOS-IU'},
#   {'type': 'text', 'id': 'PP'},
#   {'type': 'text', 'id': 'PSE-EE/PSOE'},
#   {'type': 'text', 'id': 'PUM+J'},
#   {'type': 'text', 'id': 'R0-LV-GVE'},
#   {'type': 'text', 'id': 'SAIN'},
#   {'type': 'text', 'id': 'VOLT'},
#   {'type': 'text', 'id': 'VOX'},
#   {'type': 'text', 'id': 'ZURIAK/BLANCOS'},
#   {'type': 'text', 'id': 'BALIOGABEAK/NULOS'},
#   {'type': 'text', 'id': 'ABSTENTZIOA %/% ABSTENCION'}],
#  'records': [{'ZENTSUA/CENSO': 911770,
#    'M.C.R.': '110',
#    'EREMUAK/AMBITOS': 'BIZKAIA',
#    'CPE': '507',
#    'ADN': '121',
#    'IGRE': '153',
#    'PCPE-PCPC-P': '619',
#    'ALTER': '339',
#    'PCTE-ELAK': '384',
#    'I.FEM': '1238',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '79',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '3015',
#    'FAC': '156',
#    'PH': '189',
#    'ZURIAK/BLANCOS': '4490',
#    'PIRATES/EP': '309',
#    'PSE-EE/PSOE': '109843',
#    'AXSI': '71',
#    'EH-BILDU OR': '108462',
#    'IZQP': '181',
#    'CEX-CREX-PR': '115',
#    'EAJ-PNV': '226515',
#    'VOLT': '381',
#    'PACMA/ATTAA': '5051',
#    'CV-EC': '1520',
#    'CS': '15838',
#    'CONTIGO': '125',
#    'JUNTS': '2201',
#    'PACT': '242',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '36178',
#    'SAIN': '99',
#    'PODEMOS-IU': '67161',
#    'PUM+J': '549',
#    'R0-LV-GVE': '994',
#    'CXE': '575',
#    '_id': 1,
#    'VOX': '7118'},
#   {'ZENTSUA/CENSO': 911770,
#    'M.C.R.': '0,02',
#    'EREMUAK/AMBITOS': 'BIZKAIA',
#    'CPE': '0,09',
#    'ADN': '0,02',
#    'IGRE': '0,03',
#    'PCPE-PCPC-P': '0,1',
#    'ALTER': '0,06',
#    'PCTE-ELAK': '0,06',
#    'I.FEM': '0,21',
#    'ABSTENTZIOA %/% ABSTENCION': '34,75',
#    'MIEL': '0,01',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,51',
#    'FAC': '0,03',
#    'PH': '0,03',
#    'ZURIAK/BLANCOS': '0,76',
#    'PIRATES/EP': '0,05',
#    'PSE-EE/PSOE': '18,56',
#    'AXSI': '0,01',
#    'EH-BILDU OR': '18,32',
#    'IZQP': '0,03',
#    'CEX-CREX-PR': '0,02',
#    'EAJ-PNV': '38,27',
#    'VOLT': '0,06',
#    'PACMA/ATTAA': '0,85',
#    'CV-EC': '0,26',
#    'CS': '2,68',
#    'CONTIGO': '0,02',
#    'JUNTS': '0,37',
#    'PACT': '0,04',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '6,11',
#    'SAIN': '0,02',
#    'PODEMOS-IU': '11,35',
#    'PUM+J': '0,09',
#    'R0-LV-GVE': '0,17',
#    'CXE': '0,1',
#    '_id': 2,
#    'VOX': '1,2'},
#   {'ZENTSUA/CENSO': 5900,
#    'M.C.R.': '17',
#    'EREMUAK/AMBITOS': 'ABADIÑO',
#    'CPE': '2',
#    'ADN': '1',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '1',
#    'ALTER': '0',
#    'PCTE-ELAK': '1',
#    'I.FEM': '5',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '2',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '26',
#    'FAC': '0',
#    'PH': '3',
#    'ZURIAK/BLANCOS': '51',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '643',
#    'AXSI': '0',
#    'EH-BILDU OR': '1278',
#    'IZQP': '1',
#    'CEX-CREX-PR': '1',
#    'EAJ-PNV': '1267',
#    'VOLT': '1',
#    'PACMA/ATTAA': '38',
#    'CV-EC': '11',
#    'CS': '81',
#    'CONTIGO': '1',
#    'JUNTS': '10',
#    'PACT': '2',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '155',
#    'SAIN': '0',
#    'PODEMOS-IU': '403',
#    'PUM+J': '2',
#    'R0-LV-GVE': '7',
#    'CXE': '0',
#    '_id': 3,
#    'VOX': '35'},
#   {'ZENTSUA/CENSO': 5900,
#    'M.C.R.': '0,42',
#    'EREMUAK/AMBITOS': 'ABADIÑO',
#    'CPE': '0,05',
#    'ADN': '0,02',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0,02',
#    'ALTER': '0',
#    'PCTE-ELAK': '0,02',
#    'I.FEM': '0,12',
#    'ABSTENTZIOA %/% ABSTENCION': '31,44',
#    'MIEL': '0,05',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,64',
#    'FAC': '0',
#    'PH': '0,07',
#    'ZURIAK/BLANCOS': '1,27',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '16',
#    'AXSI': '0',
#    'EH-BILDU OR': '31,8',
#    'IZQP': '0,02',
#    'CEX-CREX-PR': '0,02',
#    'EAJ-PNV': '31,53',
#    'VOLT': '0,02',
#    'PACMA/ATTAA': '0,95',
#    'CV-EC': '0,27',
#    'CS': '2,02',
#    'CONTIGO': '0,02',
#    'JUNTS': '0,25',
#    'PACT': '0,05',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '3,86',
#    'SAIN': '0',
#    'PODEMOS-IU': '10,03',
#    'PUM+J': '0,05',
#    'R0-LV-GVE': '0,17',
#    'CXE': '0',
#    '_id': 4,
#    'VOX': '0,87'},
#   {'ZENTSUA/CENSO': 7769,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ABANTO Y CIERVANA-ABANTO ZIERBENA',
#    'CPE': '1',
#    'ADN': '2',
#    'IGRE': '1',
#    'PCPE-PCPC-P': '3',
#    'ALTER': '1',
#    'PCTE-ELAK': '3',
#    'I.FEM': '3',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '1',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '36',
#    'FAC': '0',
#    'PH': '2',
#    'ZURIAK/BLANCOS': '47',
#    'PIRATES/EP': '1',
#    'PSE-EE/PSOE': '996',
#    'AXSI': '0',
#    'EH-BILDU OR': '972',
#    'IZQP': '1',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '2134',
#    'VOLT': '0',
#    'PACMA/ATTAA': '51',
#    'CV-EC': '12',
#    'CS': '75',
#    'CONTIGO': '0',
#    'JUNTS': '8',
#    'PACT': '6',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '94',
#    'SAIN': '1',
#    'PODEMOS-IU': '844',
#    'PUM+J': '4',
#    'R0-LV-GVE': '7',
#    'CXE': '3',
#    '_id': 5,
#    'VOX': '46'},
#   {'ZENTSUA/CENSO': 7769,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ABANTO Y CIERVANA-ABANTO ZIERBENA',
#    'CPE': '0,02',
#    'ADN': '0,04',
#    'IGRE': '0,02',
#    'PCPE-PCPC-P': '0,06',
#    'ALTER': '0,02',
#    'PCTE-ELAK': '0,06',
#    'I.FEM': '0,06',
#    'ABSTENTZIOA %/% ABSTENCION': '31,07',
#    'MIEL': '0,02',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,67',
#    'FAC': '0',
#    'PH': '0,04',
#    'ZURIAK/BLANCOS': '0,88',
#    'PIRATES/EP': '0,02',
#    'PSE-EE/PSOE': '18,73',
#    'AXSI': '0',
#    'EH-BILDU OR': '18,27',
#    'IZQP': '0,02',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '40,12',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,96',
#    'CV-EC': '0,23',
#    'CS': '1,41',
#    'CONTIGO': '0',
#    'JUNTS': '0,15',
#    'PACT': '0,11',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '1,77',
#    'SAIN': '0,02',
#    'PODEMOS-IU': '15,87',
#    'PUM+J': '0,08',
#    'R0-LV-GVE': '0,13',
#    'CXE': '0,06',
#    '_id': 6,
#    'VOX': '0,86'},
#   {'ZENTSUA/CENSO': 388,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'AJANGIZ',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '1',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '1',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '3',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '3',
#    'AXSI': '0',
#    'EH-BILDU OR': '181',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '114',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0',
#    'CV-EC': '0',
#    'CS': '0',
#    'CONTIGO': '0',
#    'JUNTS': '0',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '2',
#    'SAIN': '0',
#    'PODEMOS-IU': '12',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 7,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 388,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'AJANGIZ',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0,32',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '18,3',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,32',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,95',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '0,95',
#    'AXSI': '0',
#    'EH-BILDU OR': '57,28',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '36,08',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0',
#    'CV-EC': '0',
#    'CS': '0',
#    'CONTIGO': '0',
#    'JUNTS': '0',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '0,63',
#    'SAIN': '0',
#    'PODEMOS-IU': '3,8',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 8,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 2328,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ALONSOTEGI',
#    'CPE': '1',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '1',
#    'ALTER': '57',
#    'PCTE-ELAK': '2',
#    'I.FEM': '1',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '12',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '13',
#    'PIRATES/EP': '2',
#    'PSE-EE/PSOE': '222',
#    'AXSI': '0',
#    'EH-BILDU OR': '416',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '744',
#    'VOLT': '3',
#    'PACMA/ATTAA': '10',
#    'CV-EC': '1',
#    'CS': '25',
#    'CONTIGO': '0',
#    'JUNTS': '1',
#    'PACT': '1',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '34',
#    'SAIN': '0',
#    'PODEMOS-IU': '166',
#    'PUM+J': '1',
#    'R0-LV-GVE': '2',
#    'CXE': '1',
#    '_id': 9,
#    'VOX': '10'},
#   {'ZENTSUA/CENSO': 2328,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ALONSOTEGI',
#    'CPE': '0,06',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0,06',
#    'ALTER': '3,33',
#    'PCTE-ELAK': '0,12',
#    'I.FEM': '0,06',
#    'ABSTENTZIOA %/% ABSTENCION': '25,86',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,7',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,76',
#    'PIRATES/EP': '0,12',
#    'PSE-EE/PSOE': '12,95',
#    'AXSI': '0',
#    'EH-BILDU OR': '24,27',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '43,41',
#    'VOLT': '0,18',
#    'PACMA/ATTAA': '0,58',
#    'CV-EC': '0,06',
#    'CS': '1,46',
#    'CONTIGO': '0',
#    'JUNTS': '0,06',
#    'PACT': '0,06',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '1,98',
#    'SAIN': '0',
#    'PODEMOS-IU': '9,68',
#    'PUM+J': '0,06',
#    'R0-LV-GVE': '0,12',
#    'CXE': '0,06',
#    '_id': 10,
#    'VOX': '0,58'},
#   {'ZENTSUA/CENSO': 14633,
#    'M.C.R.': '4',
#    'EREMUAK/AMBITOS': 'AMOREBIETA-ETXANO',
#    'CPE': '10',
#    'ADN': '0',
#    'IGRE': '4',
#    'PCPE-PCPC-P': '17',
#    'ALTER': '10',
#    'PCTE-ELAK': '3',
#    'I.FEM': '149',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '5',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '59',
#    'FAC': '1',
#    'PH': '1',
#    'ZURIAK/BLANCOS': '72',
#    'PIRATES/EP': '2',
#    'PSE-EE/PSOE': '1125',
#    'AXSI': '1',
#    'EH-BILDU OR': '2831',
#    'IZQP': '3',
#    'CEX-CREX-PR': '2',
#    'EAJ-PNV': '4313',
#    'VOLT': '0',
#    'PACMA/ATTAA': '72',
#    'CV-EC': '11',
#    'CS': '135',
#    'CONTIGO': '0',
#    'JUNTS': '25',
#    'PACT': '1',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '202',
#    'SAIN': '0',
#    'PODEMOS-IU': '1001',
#    'PUM+J': '5',
#    'R0-LV-GVE': '28',
#    'CXE': '5',
#    '_id': 11,
#    'VOX': '47'},
#   {'ZENTSUA/CENSO': 14633,
#    'M.C.R.': '0,04',
#    'EREMUAK/AMBITOS': 'AMOREBIETA-ETXANO',
#    'CPE': '0,1',
#    'ADN': '0',
#    'IGRE': '0,04',
#    'PCPE-PCPC-P': '0,17',
#    'ALTER': '0,1',
#    'PCTE-ELAK': '0,03',
#    'I.FEM': '1,48',
#    'ABSTENTZIOA %/% ABSTENCION': '30,68',
#    'MIEL': '0,05',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,58',
#    'FAC': '0,01',
#    'PH': '0,01',
#    'ZURIAK/BLANCOS': '0,71',
#    'PIRATES/EP': '0,02',
#    'PSE-EE/PSOE': '11,16',
#    'AXSI': '0,01',
#    'EH-BILDU OR': '28,07',
#    'IZQP': '0,03',
#    'CEX-CREX-PR': '0,02',
#    'EAJ-PNV': '42,77',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,71',
#    'CV-EC': '0,11',
#    'CS': '1,34',
#    'CONTIGO': '0',
#    'JUNTS': '0,25',
#    'PACT': '0,01',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '2',
#    'SAIN': '0',
#    'PODEMOS-IU': '9,93',
#    'PUM+J': '0,05',
#    'R0-LV-GVE': '0,28',
#    'CXE': '0,05',
#    '_id': 12,
#    'VOX': '0,47'},
#   {'ZENTSUA/CENSO': 323,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'AMOROTO',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '1',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '2',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '2',
#    'AXSI': '0',
#    'EH-BILDU OR': '110',
#    'IZQP': '0',
#    'CEX-CREX-PR': '1',
#    'EAJ-PNV': '116',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0',
#    'CV-EC': '0',
#    'CS': '0',
#    'CONTIGO': '0',
#    'JUNTS': '0',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '0',
#    'SAIN': '1',
#    'PODEMOS-IU': '4',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '1',
#    '_id': 13,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 323,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'AMOROTO',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '26,32',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,42',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,84',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '0,84',
#    'AXSI': '0',
#    'EH-BILDU OR': '46,41',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0,42',
#    'EAJ-PNV': '48,95',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0',
#    'CV-EC': '0',
#    'CS': '0',
#    'CONTIGO': '0',
#    'JUNTS': '0',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '0',
#    'SAIN': '0,42',
#    'PODEMOS-IU': '1,69',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0,42',
#    '_id': 14,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 112,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARAKALDO',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '1',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '7',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '5',
#    'AXSI': '0',
#    'EH-BILDU OR': '30',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '35',
#    'VOLT': '0',
#    'PACMA/ATTAA': '1',
#    'CV-EC': '0',
#    'CS': '0',
#    'CONTIGO': '0',
#    'JUNTS': '1',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '1',
#    'SAIN': '0',
#    'PODEMOS-IU': '7',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 15,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 112,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARAKALDO',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '21,43',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '1,14',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '8,05',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '5,75',
#    'AXSI': '0',
#    'EH-BILDU OR': '34,48',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '40,23',
#    'VOLT': '0',
#    'PACMA/ATTAA': '1,15',
#    'CV-EC': '0',
#    'CS': '0',
#    'CONTIGO': '0',
#    'JUNTS': '1,15',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '1,15',
#    'SAIN': '0',
#    'PODEMOS-IU': '8,05',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 16,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 312,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARANTZAZU',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '1',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '1',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '3',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '5',
#    'AXSI': '0',
#    'EH-BILDU OR': '123',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '119',
#    'VOLT': '0',
#    'PACMA/ATTAA': '1',
#    'CV-EC': '1',
#    'CS': '1',
#    'CONTIGO': '0',
#    'JUNTS': '1',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '0',
#    'SAIN': '0',
#    'PODEMOS-IU': '11',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 17,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 682,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'GALDAMES',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '1',
#    'I.FEM': '1',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '12',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '8',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '34',
#    'AXSI': '0',
#    'EH-BILDU OR': '164',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '260',
#    'VOLT': '0',
#    'PACMA/ATTAA': '1',
#    'CV-EC': '2',
#    'CS': '2',
#    'CONTIGO': '0',
#    'JUNTS': '3',
#    'PACT': '1',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '4',
#    'SAIN': '0',
#    'PODEMOS-IU': '35',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 91,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 312,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARANTZAZU',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0,38',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '14,42',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,37',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '1,13',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '1,88',
#    'AXSI': '0',
#    'EH-BILDU OR': '46,24',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '44,74',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,38',
#    'CV-EC': '0,38',
#    'CS': '0,38',
#    'CONTIGO': '0',
#    'JUNTS': '0,38',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '0',
#    'SAIN': '0',
#    'PODEMOS-IU': '4,14',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 18,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 897,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'AREATZA',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '1',
#    'PCTE-ELAK': '1',
#    'I.FEM': '1',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '6',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '15',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '24',
#    'AXSI': '0',
#    'EH-BILDU OR': '305',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '312',
#    'VOLT': '0',
#    'PACMA/ATTAA': '6',
#    'CV-EC': '0',
#    'CS': '4',
#    'CONTIGO': '0',
#    'JUNTS': '11',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '24',
#    'SAIN': '0',
#    'PODEMOS-IU': '29',
#    'PUM+J': '0',
#    'R0-LV-GVE': '1',
#    'CXE': '0',
#    '_id': 19,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 897,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'AREATZA',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0,14',
#    'PCTE-ELAK': '0,14',
#    'I.FEM': '0,14',
#    'ABSTENTZIOA %/% ABSTENCION': '17,5',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,81',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '2,04',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '3,27',
#    'AXSI': '0',
#    'EH-BILDU OR': '41,55',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '42,51',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,82',
#    'CV-EC': '0',
#    'CS': '0,54',
#    'CONTIGO': '0',
#    'JUNTS': '1,5',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '3,27',
#    'SAIN': '0',
#    'PODEMOS-IU': '3,95',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0,14',
#    'CXE': '0',
#    '_id': 20,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 769,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARRANKUDIAGA',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '1',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '4',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '18',
#    'AXSI': '0',
#    'EH-BILDU OR': '286',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '297',
#    'VOLT': '0',
#    'PACMA/ATTAA': '4',
#    'CV-EC': '0',
#    'CS': '9',
#    'CONTIGO': '0',
#    'JUNTS': '1',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '7',
#    'SAIN': '0',
#    'PODEMOS-IU': '22',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 21,
#    'VOX': '2'},
#   {'ZENTSUA/CENSO': 769,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARRANKUDIAGA',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '15,34',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,15',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,62',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '2,77',
#    'AXSI': '0',
#    'EH-BILDU OR': '44',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '45,69',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,62',
#    'CV-EC': '0',
#    'CS': '1,38',
#    'CONTIGO': '0',
#    'JUNTS': '0,15',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '1,08',
#    'SAIN': '0',
#    'PODEMOS-IU': '3,38',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 22,
#    'VOX': '0,31'},
#   {'ZENTSUA/CENSO': 324,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARRATZU',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '1',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '1',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '4',
#    'AXSI': '0',
#    'EH-BILDU OR': '119',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '150',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0',
#    'CV-EC': '0',
#    'CS': '0',
#    'CONTIGO': '0',
#    'JUNTS': '3',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '0',
#    'SAIN': '0',
#    'PODEMOS-IU': '8',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 23,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 324,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARRATZU',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0,35',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '11,73',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,35',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '1,4',
#    'AXSI': '0',
#    'EH-BILDU OR': '41,75',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '52,63',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0',
#    'CV-EC': '0',
#    'CS': '0',
#    'CONTIGO': '0',
#    'JUNTS': '1,05',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '0',
#    'SAIN': '0',
#    'PODEMOS-IU': '2,81',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 24,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 483,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARRIETA',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '2',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '2',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '1',
#    'PIRATES/EP': '1',
#    'PSE-EE/PSOE': '9',
#    'AXSI': '0',
#    'EH-BILDU OR': '118',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '198',
#    'VOLT': '0',
#    'PACMA/ATTAA': '2',
#    'CV-EC': '2',
#    'CS': '2',
#    'CONTIGO': '0',
#    'JUNTS': '2',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '0',
#    'SAIN': '0',
#    'PODEMOS-IU': '25',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 25,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 483,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARRIETA',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0,55',
#    'ABSTENTZIOA %/% ABSTENCION': '24,64',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,55',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,28',
#    'PIRATES/EP': '0,28',
#    'PSE-EE/PSOE': '2,49',
#    'AXSI': '0',
#    'EH-BILDU OR': '32,6',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '54,7',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,55',
#    'CV-EC': '0,55',
#    'CS': '0,55',
#    'CONTIGO': '0',
#    'JUNTS': '0,55',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '0',
#    'SAIN': '0',
#    'PODEMOS-IU': '6,91',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 26,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 9657,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARRIGORRIAGA',
#    'CPE': '2',
#    'ADN': '1',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '7',
#    'ALTER': '0',
#    'PCTE-ELAK': '2',
#    'I.FEM': '7',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '1',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '36',
#    'FAC': '0',
#    'PH': '3',
#    'ZURIAK/BLANCOS': '56',
#    'PIRATES/EP': '2',
#    'PSE-EE/PSOE': '1064',
#    'AXSI': '0',
#    'EH-BILDU OR': '1549',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '2267',
#    'VOLT': '2',
#    'PACMA/ATTAA': '77',
#    'CV-EC': '16',
#    'CS': '139',
#    'CONTIGO': '3',
#    'JUNTS': '28',
#    'PACT': '2',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '193',
#    'SAIN': '0',
#    'PODEMOS-IU': '766',
#    'PUM+J': '5',
#    'R0-LV-GVE': '5',
#    'CXE': '3',
#    '_id': 27,
#    'VOX': '40'},
#   {'ZENTSUA/CENSO': 9657,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARRIGORRIAGA',
#    'CPE': '0,03',
#    'ADN': '0,02',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0,11',
#    'ALTER': '0',
#    'PCTE-ELAK': '0,03',
#    'I.FEM': '0,11',
#    'ABSTENTZIOA %/% ABSTENCION': '35,01',
#    'MIEL': '0,02',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,57',
#    'FAC': '0',
#    'PH': '0,05',
#    'ZURIAK/BLANCOS': '0,9',
#    'PIRATES/EP': '0,03',
#    'PSE-EE/PSOE': '17,05',
#    'AXSI': '0',
#    'EH-BILDU OR': '24,82',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '36,33',
#    'VOLT': '0,03',
#    'PACMA/ATTAA': '1,23',
#    'CV-EC': '0,26',
#    'CS': '2,23',
#    'CONTIGO': '0,05',
#    'JUNTS': '0,45',
#    'PACT': '0,03',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '3,09',
#    'SAIN': '0',
#    'PODEMOS-IU': '12,28',
#    'PUM+J': '0,08',
#    'R0-LV-GVE': '0,08',
#    'CXE': '0,05',
#    '_id': 28,
#    'VOX': '0,64'},
#   {'ZENTSUA/CENSO': 579,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARTEA',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '6',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '2',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '8',
#    'AXSI': '0',
#    'EH-BILDU OR': '196',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '236',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0',
#    'CV-EC': '0',
#    'CS': '4',
#    'CONTIGO': '0',
#    'JUNTS': '0',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '10',
#    'SAIN': '0',
#    'PODEMOS-IU': '31',
#    'PUM+J': '1',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 29,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 579,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARTEA',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '14,68',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '1,21',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,41',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '1,64',
#    'AXSI': '0',
#    'EH-BILDU OR': '40,16',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '48,36',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0',
#    'CV-EC': '0',
#    'CS': '0,82',
#    'CONTIGO': '0',
#    'JUNTS': '0',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '2,05',
#    'SAIN': '0',
#    'PODEMOS-IU': '6,35',
#    'PUM+J': '0,2',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 30,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 614,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARTZENTALES',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '1',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '2',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '10',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '7',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '20',
#    'AXSI': '0',
#    'EH-BILDU OR': '108',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '255',
#    'VOLT': '0',
#    'PACMA/ATTAA': '2',
#    'CV-EC': '1',
#    'CS': '5',
#    'CONTIGO': '0',
#    'JUNTS': '5',
#    'PACT': '1',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '3',
#    'SAIN': '0',
#    'PODEMOS-IU': '36',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 31,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 614,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ARTZENTALES',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0,22',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0,45',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '25,73',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '2,19',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '1,57',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '4,48',
#    'AXSI': '0',
#    'EH-BILDU OR': '24,22',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '57,17',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,45',
#    'CV-EC': '0,22',
#    'CS': '1,12',
#    'CONTIGO': '0',
#    'JUNTS': '1,12',
#    'PACT': '0,22',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '0,67',
#    'SAIN': '0',
#    'PODEMOS-IU': '8,07',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 32,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 1086,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ATXONDO',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '1',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '4',
#    'FAC': '1',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '5',
#    'PIRATES/EP': '1',
#    'PSE-EE/PSOE': '56',
#    'AXSI': '0',
#    'EH-BILDU OR': '341',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '370',
#    'VOLT': '0',
#    'PACMA/ATTAA': '4',
#    'CV-EC': '0',
#    'CS': '6',
#    'CONTIGO': '0',
#    'JUNTS': '6',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '10',
#    'SAIN': '0',
#    'PODEMOS-IU': '41',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 33,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 1086,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ATXONDO',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0,12',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '22,1',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,47',
#    'FAC': '0,12',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,59',
#    'PIRATES/EP': '0,12',
#    'PSE-EE/PSOE': '6,65',
#    'AXSI': '0',
#    'EH-BILDU OR': '40,5',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '43,94',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,48',
#    'CV-EC': '0',
#    'CS': '0,71',
#    'CONTIGO': '0',
#    'JUNTS': '0,71',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '1,19',
#    'SAIN': '0',
#    'PODEMOS-IU': '4,87',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 34,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 531,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'AULESTI',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '2',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '3',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '4',
#    'AXSI': '0',
#    'EH-BILDU OR': '274',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '101',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0',
#    'CV-EC': '0',
#    'CS': '0',
#    'CONTIGO': '0',
#    'JUNTS': '2',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '0',
#    'SAIN': '0',
#    'PODEMOS-IU': '7',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 35,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 531,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'AULESTI',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '25,99',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,51',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,77',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '1,02',
#    'AXSI': '0',
#    'EH-BILDU OR': '70,08',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '25,83',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0',
#    'CV-EC': '0',
#    'CS': '0',
#    'CONTIGO': '0',
#    'JUNTS': '0,51',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '0',
#    'SAIN': '0',
#    'PODEMOS-IU': '1,79',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 36,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 2072,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'BAKIO',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '8',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '1',
#    'I.FEM': '3',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '1',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '10',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '4',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '59',
#    'AXSI': '0',
#    'EH-BILDU OR': '602',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '761',
#    'VOLT': '0',
#    'PACMA/ATTAA': '10',
#    'CV-EC': '3',
#    'CS': '15',
#    'CONTIGO': '0',
#    'JUNTS': '18',
#    'PACT': '2',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '19',
#    'SAIN': '0',
#    'PODEMOS-IU': '102',
#    'PUM+J': '3',
#    'R0-LV-GVE': '2',
#    'CXE': '0',
#    '_id': 37,
#    'VOX': '1'},
#   {'ZENTSUA/CENSO': 2072,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'BAKIO',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0,5',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0,06',
#    'I.FEM': '0,19',
#    'ABSTENTZIOA %/% ABSTENCION': '21,62',
#    'MIEL': '0,06',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,62',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,25',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '3,66',
#    'AXSI': '0',
#    'EH-BILDU OR': '37,3',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '47,15',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,62',
#    'CV-EC': '0,19',
#    'CS': '0,93',
#    'CONTIGO': '0',
#    'JUNTS': '1,12',
#    'PACT': '0,12',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '1,18',
#    'SAIN': '0',
#    'PODEMOS-IU': '6,32',
#    'PUM+J': '0,19',
#    'R0-LV-GVE': '0,12',
#    'CXE': '0',
#    '_id': 38,
#    'VOX': '0,06'},
#   {'ZENTSUA/CENSO': 6018,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'BALMASEDA',
#    'CPE': '3',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '2',
#    'ALTER': '1',
#    'PCTE-ELAK': '5',
#    'I.FEM': '1',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '68',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '39',
#    'PIRATES/EP': '2',
#    'PSE-EE/PSOE': '879',
#    'AXSI': '0',
#    'EH-BILDU OR': '636',
#    'IZQP': '1',
#    'CEX-CREX-PR': '1',
#    'EAJ-PNV': '2045',
#    'VOLT': '0',
#    'PACMA/ATTAA': '22',
#    'CV-EC': '9',
#    'CS': '91',
#    'CONTIGO': '0',
#    'JUNTS': '18',
#    'PACT': '1',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '163',
#    'SAIN': '0',
#    'PODEMOS-IU': '398',
#    'PUM+J': '2',
#    'R0-LV-GVE': '6',
#    'CXE': '2',
#    '_id': 39,
#    'VOX': '47'},
#   {'ZENTSUA/CENSO': 6018,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'BALMASEDA',
#    'CPE': '0,07',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0,05',
#    'ALTER': '0,02',
#    'PCTE-ELAK': '0,11',
#    'I.FEM': '0,02',
#    'ABSTENTZIOA %/% ABSTENCION': '26,19',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '1,53',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,89',
#    'PIRATES/EP': '0,05',
#    'PSE-EE/PSOE': '20,1',
#    'AXSI': '0',
#    'EH-BILDU OR': '14,54',
#    'IZQP': '0,02',
#    'CEX-CREX-PR': '0,02',
#    'EAJ-PNV': '46,75',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,5',
#    'CV-EC': '0,21',
#    'CS': '2,08',
#    'CONTIGO': '0',
#    'JUNTS': '0,41',
#    'PACT': '0,02',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '3,73',
#    'SAIN': '0',
#    'PODEMOS-IU': '9,1',
#    'PUM+J': '0,05',
#    'R0-LV-GVE': '0,14',
#    'CXE': '0,05',
#    '_id': 40,
#    'VOX': '1,07'},
#   {'ZENTSUA/CENSO': 79482,
#    'M.C.R.': '6',
#    'EREMUAK/AMBITOS': 'BARAKALDO',
#    'CPE': '35',
#    'ADN': '12',
#    'IGRE': '18',
#    'PCPE-PCPC-P': '57',
#    'ALTER': '111',
#    'PCTE-ELAK': '54',
#    'I.FEM': '200',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '5',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '219',
#    'FAC': '18',
#    'PH': '19',
#    'ZURIAK/BLANCOS': '318',
#    'PIRATES/EP': '33',
#    'PSE-EE/PSOE': '14530',
#    'AXSI': '8',
#    'EH-BILDU OR': '5198',
#    'IZQP': '12',
#    'CEX-CREX-PR': '11',
#    'EAJ-PNV': '14995',
#    'VOLT': '32',
#    'PACMA/ATTAA': '503',
#    'CV-EC': '97',
#    'CS': '1343',
#    'CONTIGO': '16',
#    'JUNTS': '90',
#    'PACT': '26',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '3038',
#    'SAIN': '9',
#    'PODEMOS-IU': '7434',
#    'PUM+J': '53',
#    'R0-LV-GVE': '90',
#    'CXE': '43',
#    '_id': 41,
#    'VOX': '699'},
#   {'ZENTSUA/CENSO': 79482,
#    'M.C.R.': '0,01',
#    'EREMUAK/AMBITOS': 'BARAKALDO',
#    'CPE': '0,07',
#    'ADN': '0,02',
#    'IGRE': '0,04',
#    'PCPE-PCPC-P': '0,12',
#    'ALTER': '0,23',
#    'PCTE-ELAK': '0,11',
#    'I.FEM': '0,41',
#    'ABSTENTZIOA %/% ABSTENCION': '37,93',
#    'MIEL': '0,01',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,44',
#    'FAC': '0,04',
#    'PH': '0,04',
#    'ZURIAK/BLANCOS': '0,65',
#    'PIRATES/EP': '0,07',
#    'PSE-EE/PSOE': '29,58',
#    'AXSI': '0,02',
#    'EH-BILDU OR': '10,58',
#    'IZQP': '0,02',
#    'CEX-CREX-PR': '0,02',
#    'EAJ-PNV': '30,53',
#    'VOLT': '0,07',
#    'PACMA/ATTAA': '1,02',
#    'CV-EC': '0,2',
#    'CS': '2,73',
#    'CONTIGO': '0,03',
#    'JUNTS': '0,18',
#    'PACT': '0,05',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '6,19',
#    'SAIN': '0,02',
#    'PODEMOS-IU': '15,14',
#    'PUM+J': '0,11',
#    'R0-LV-GVE': '0,18',
#    'CXE': '0,09',
#    '_id': 42,
#    'VOX': '1,42'},
#   {'ZENTSUA/CENSO': 1238,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'BARRIKA',
#    'CPE': '1',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '1',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '4',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '12',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '86',
#    'AXSI': '0',
#    'EH-BILDU OR': '220',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '353',
#    'VOLT': '0',
#    'PACMA/ATTAA': '14',
#    'CV-EC': '3',
#    'CS': '21',
#    'CONTIGO': '0',
#    'JUNTS': '7',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '22',
#    'SAIN': '0',
#    'PODEMOS-IU': '59',
#    'PUM+J': '1',
#    'R0-LV-GVE': '2',
#    'CXE': '0',
#    '_id': 43,
#    'VOX': '3'},
#   {'ZENTSUA/CENSO': 1238,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'BARRIKA',
#    'CPE': '0,12',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '34,65',
#    'MIEL': '0,12',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,49',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '1,49',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '10,68',
#    'AXSI': '0',
#    'EH-BILDU OR': '27,33',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '43,85',
#    'VOLT': '0',
#    'PACMA/ATTAA': '1,74',
#    'CV-EC': '0,37',
#    'CS': '2,61',
#    'CONTIGO': '0',
#    'JUNTS': '0,87',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '2,73',
#    'SAIN': '0',
#    'PODEMOS-IU': '7,33',
#    'PUM+J': '0,12',
#    'R0-LV-GVE': '0,25',
#    'CXE': '0',
#    '_id': 44,
#    'VOX': '0,37'},
#   {'ZENTSUA/CENSO': 33175,
#    'M.C.R.': '2',
#    'EREMUAK/AMBITOS': 'BASAURI',
#    'CPE': '8',
#    'ADN': '3',
#    'IGRE': '5',
#    'PCPE-PCPC-P': '12',
#    'ALTER': '6',
#    'PCTE-ELAK': '20',
#    'I.FEM': '19',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '3',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '95',
#    'FAC': '3',
#    'PH': '24',
#    'ZURIAK/BLANCOS': '147',
#    'PIRATES/EP': '26',
#    'PSE-EE/PSOE': '5302',
#    'AXSI': '1',
#    'EH-BILDU OR': '2592',
#    'IZQP': '6',
#    'CEX-CREX-PR': '6',
#    'EAJ-PNV': '7598',
#    'VOLT': '17',
#    'PACMA/ATTAA': '199',
#    'CV-EC': '59',
#    'CS': '434',
#    'CONTIGO': '3',
#    'JUNTS': '35',
#    'PACT': '11',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '1131',
#    'SAIN': '2',
#    'PODEMOS-IU': '2682',
#    'PUM+J': '6',
#    'R0-LV-GVE': '17',
#    'CXE': '8',
#    '_id': 45,
#    'VOX': '182'},
#   {'ZENTSUA/CENSO': 33175,
#    'M.C.R.': '0,01',
#    'EREMUAK/AMBITOS': 'BASAURI',
#    'CPE': '0,04',
#    'ADN': '0,01',
#    'IGRE': '0,02',
#    'PCPE-PCPC-P': '0,06',
#    'ALTER': '0,03',
#    'PCTE-ELAK': '0,1',
#    'I.FEM': '0,09',
#    'ABSTENTZIOA %/% ABSTENCION': '37,71',
#    'MIEL': '0,01',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,46',
#    'FAC': '0,01',
#    'PH': '0,12',
#    'ZURIAK/BLANCOS': '0,71',
#    'PIRATES/EP': '0,13',
#    'PSE-EE/PSOE': '25,78',
#    'AXSI': '0',
#    'EH-BILDU OR': '12,6',
#    'IZQP': '0,03',
#    'CEX-CREX-PR': '0,03',
#    'EAJ-PNV': '36,94',
#    'VOLT': '0,08',
#    'PACMA/ATTAA': '0,97',
#    'CV-EC': '0,29',
#    'CS': '2,11',
#    'CONTIGO': '0,01',
#    'JUNTS': '0,17',
#    'PACT': '0,05',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '5,5',
#    'SAIN': '0,01',
#    'PODEMOS-IU': '13,04',
#    'PUM+J': '0,03',
#    'R0-LV-GVE': '0,08',
#    'CXE': '0,04',
#    '_id': 46,
#    'VOX': '0,88'},
#   {'ZENTSUA/CENSO': 874,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'BEDIA',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '1',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '3',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '14',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '40',
#    'AXSI': '0',
#    'EH-BILDU OR': '162',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '375',
#    'VOLT': '0',
#    'PACMA/ATTAA': '4',
#    'CV-EC': '1',
#    'CS': '6',
#    'CONTIGO': '0',
#    'JUNTS': '0',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '12',
#    'SAIN': '0',
#    'PODEMOS-IU': '29',
#    'PUM+J': '0',
#    'R0-LV-GVE': '1',
#    'CXE': '1',
#    '_id': 47,
#    'VOX': '6'},
#   {'ZENTSUA/CENSO': 874,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'BEDIA',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0,15',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '25,06',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,46',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '2,15',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '6,13',
#    'AXSI': '0',
#    'EH-BILDU OR': '24,85',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '57,52',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,61',
#    'CV-EC': '0,15',
#    'CS': '0,92',
#    'CONTIGO': '0',
#    'JUNTS': '0',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '1,84',
#    'SAIN': '0',
#    'PODEMOS-IU': '4,45',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0,15',
#    'CXE': '0,15',
#    '_id': 48,
#    'VOX': '0,92'},
#   {'ZENTSUA/CENSO': 5452,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'BERANGO',
#    'CPE': '2',
#    'ADN': '0',
#    'IGRE': '1',
#    'PCPE-PCPC-P': '2',
#    'ALTER': '0',
#    'PCTE-ELAK': '1',
#    'I.FEM': '2',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '24',
#    'FAC': '0',
#    'PH': '2',
#    'ZURIAK/BLANCOS': '24',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '548',
#    'AXSI': '0',
#    'EH-BILDU OR': '777',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '1432',
#    'VOLT': '1',
#    'PACMA/ATTAA': '45',
#    'CV-EC': '15',
#    'CS': '149',
#    'CONTIGO': '2',
#    'JUNTS': '12',
#    'PACT': '1',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '217',
#    'SAIN': '0',
#    'PODEMOS-IU': '415',
#    'PUM+J': '3',
#    'R0-LV-GVE': '5',
#    'CXE': '2',
#    '_id': 49,
#    'VOX': '44'},
#   {'ZENTSUA/CENSO': 5452,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'BERANGO',
#    'CPE': '0,05',
#    'ADN': '0',
#    'IGRE': '0,03',
#    'PCPE-PCPC-P': '0,05',
#    'ALTER': '0',
#    'PCTE-ELAK': '0,03',
#    'I.FEM': '0,05',
#    'ABSTENTZIOA %/% ABSTENCION': '31,66',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,64',
#    'FAC': '0',
#    'PH': '0,05',
#    'ZURIAK/BLANCOS': '0,65',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '14,8',
#    'AXSI': '0',
#    'EH-BILDU OR': '20,99',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '38,68',
#    'VOLT': '0,03',
#    'PACMA/ATTAA': '1,22',
#    'CV-EC': '0,41',
#    'CS': '4,02',
#    'CONTIGO': '0,05',
#    'JUNTS': '0,32',
#    'PACT': '0,03',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '5,86',
#    'SAIN': '0',
#    'PODEMOS-IU': '11,21',
#    'PUM+J': '0,08',
#    'R0-LV-GVE': '0,14',
#    'CXE': '0,05',
#    '_id': 50,
#    'VOX': '1,19'},
#   {'ZENTSUA/CENSO': 13222,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'BERMEO',
#    'CPE': '5',
#    'ADN': '0',
#    'IGRE': '1',
#    'PCPE-PCPC-P': '4',
#    'ALTER': '2',
#    'PCTE-ELAK': '3',
#    'I.FEM': '8',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '99',
#    'FAC': '2',
#    'PH': '2',
#    'ZURIAK/BLANCOS': '43',
#    'PIRATES/EP': '4',
#    'PSE-EE/PSOE': '375',
#    'AXSI': '1',
#    'EH-BILDU OR': '2683',
#    'IZQP': '1',
#    'CEX-CREX-PR': '2',
#    'EAJ-PNV': '4795',
#    'VOLT': '3',
#    'PACMA/ATTAA': '42',
#    'CV-EC': '18',
#    'CS': '39',
#    'CONTIGO': '2',
#    'JUNTS': '41',
#    'PACT': '1',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '72',
#    'SAIN': '1',
#    'PODEMOS-IU': '514',
#    'PUM+J': '3',
#    'R0-LV-GVE': '3',
#    'CXE': '0',
#    '_id': 51,
#    'VOX': '15'},
#   {'ZENTSUA/CENSO': 13222,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'BERMEO',
#    'CPE': '0,06',
#    'ADN': '0',
#    'IGRE': '0,01',
#    'PCPE-PCPC-P': '0,05',
#    'ALTER': '0,02',
#    'PCTE-ELAK': '0,03',
#    'I.FEM': '0,09',
#    'ABSTENTZIOA %/% ABSTENCION': '33,57',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '1,13',
#    'FAC': '0,02',
#    'PH': '0,02',
#    'ZURIAK/BLANCOS': '0,5',
#    'PIRATES/EP': '0,05',
#    'PSE-EE/PSOE': '4,32',
#    'AXSI': '0,01',
#    'EH-BILDU OR': '30,89',
#    'IZQP': '0,01',
#    'CEX-CREX-PR': '0,02',
#    'EAJ-PNV': '55,21',
#    'VOLT': '0,03',
#    'PACMA/ATTAA': '0,48',
#    'CV-EC': '0,21',
#    'CS': '0,45',
#    'CONTIGO': '0,02',
#    'JUNTS': '0,47',
#    'PACT': '0,01',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '0,83',
#    'SAIN': '0,01',
#    'PODEMOS-IU': '5,92',
#    'PUM+J': '0,03',
#    'R0-LV-GVE': '0,03',
#    'CXE': '0',
#    '_id': 52,
#    'VOX': '0,17'},
#   {'ZENTSUA/CENSO': 865,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'BERRIATUA',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '1',
#    'PCTE-ELAK': '0',
#    'I.FEM': '2',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '3',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '8',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '16',
#    'AXSI': '0',
#    'EH-BILDU OR': '280',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '248',
#    'VOLT': '0',
#    'PACMA/ATTAA': '2',
#    'CV-EC': '0',
#    'CS': '1',
#    'CONTIGO': '0',
#    'JUNTS': '3',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '1',
#    'SAIN': '0',
#    'PODEMOS-IU': '27',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 53,
#    'VOX': '1'},
#   {'ZENTSUA/CENSO': 865,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'BERRIATUA',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0,17',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0,34',
#    'ABSTENTZIOA %/% ABSTENCION': '31,45',
# ...
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,83',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '1,08',
#    'PIRATES/EP': '0,13',
#    'PSE-EE/PSOE': '9,39',
#    'AXSI': '0',
#    'EH-BILDU OR': '31,62',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '45,01',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,21',
#    'CV-EC': '0,17',
#    'CS': '1,5',
#    'CONTIGO': '0',
#    'JUNTS': '0,08',
#    'PACT': '0,04',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '3,17',
#    'SAIN': '0,04',
#    'PODEMOS-IU': '6,47',
#    'PUM+J': '0,04',
#    'R0-LV-GVE': '0,17',
#    'CXE': '0',
#    '_id': 208,
#    'VOX': '0,58'},
#   {'ZENTSUA/CENSO': 9953,
#    'M.C.R.': '1',
#    'EREMUAK/AMBITOS': 'VALLE DE TRAPAGA-TRAPAGARAN',
#    'CPE': '2',
#    'ADN': '2',
#    'IGRE': '2',
#    'PCPE-PCPC-P': '4',
#    'ALTER': '1',
#    'PCTE-ELAK': '4',
#    'I.FEM': '2',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '44',
#    'FAC': '0',
#    'PH': '3',
#    'ZURIAK/BLANCOS': '43',
#    'PIRATES/EP': '5',
#    'PSE-EE/PSOE': '1752',
#    'AXSI': '0',
#    'EH-BILDU OR': '1101',
#    'IZQP': '2',
#    'CEX-CREX-PR': '2',
#    'EAJ-PNV': '2359',
#    'VOLT': '5',
#    'PACMA/ATTAA': '61',
#    'CV-EC': '20',
#    'CS': '93',
#    'CONTIGO': '2',
#    'JUNTS': '15',
#    'PACT': '5',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '196',
#    'SAIN': '0',
#    'PODEMOS-IU': '834',
#    'PUM+J': '6',
#    'R0-LV-GVE': '8',
#    'CXE': '0',
#    '_id': 209,
#    'VOX': '51'},
#   {'ZENTSUA/CENSO': 9953,
#    'M.C.R.': '0,02',
#    'EREMUAK/AMBITOS': 'VALLE DE TRAPAGA-TRAPAGARAN',
#    'CPE': '0,03',
#    'ADN': '0,03',
#    'IGRE': '0,03',
#    'PCPE-PCPC-P': '0,06',
#    'ALTER': '0,02',
#    'PCTE-ELAK': '0,06',
#    'I.FEM': '0,03',
#    'ABSTENTZIOA %/% ABSTENCION': '33,44',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,66',
#    'FAC': '0',
#    'PH': '0,05',
#    'ZURIAK/BLANCOS': '0,65',
#    'PIRATES/EP': '0,08',
#    'PSE-EE/PSOE': '26,62',
#    'AXSI': '0',
#    'EH-BILDU OR': '16,73',
#    'IZQP': '0,03',
#    'CEX-CREX-PR': '0,03',
#    'EAJ-PNV': '35,85',
#    'VOLT': '0,08',
#    'PACMA/ATTAA': '0,93',
#    'CV-EC': '0,3',
#    'CS': '1,41',
#    'CONTIGO': '0,03',
#    'JUNTS': '0,23',
#    'PACT': '0,08',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '2,98',
#    'SAIN': '0',
#    'PODEMOS-IU': '12,67',
#    'PUM+J': '0,09',
#    'R0-LV-GVE': '0,12',
#    'CXE': '0',
#    '_id': 210,
#    'VOX': '0,77'},
#   {'ZENTSUA/CENSO': 2335,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZALDIBAR',
#    'CPE': '2',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '1',
#    'PCTE-ELAK': '0',
#    'I.FEM': '1',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '5',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '11',
#    'PIRATES/EP': '2',
#    'PSE-EE/PSOE': '282',
#    'AXSI': '0',
#    'EH-BILDU OR': '459',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '501',
#    'VOLT': '0',
#    'PACMA/ATTAA': '6',
#    'CV-EC': '1',
#    'CS': '26',
#    'CONTIGO': '0',
#    'JUNTS': '6',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '75',
#    'SAIN': '0',
#    'PODEMOS-IU': '165',
#    'PUM+J': '0',
#    'R0-LV-GVE': '5',
#    'CXE': '1',
#    '_id': 211,
#    'VOX': '1'},
#   {'ZENTSUA/CENSO': 2335,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZALDIBAR',
#    'CPE': '0,13',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0,06',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0,06',
#    'ABSTENTZIOA %/% ABSTENCION': '33,62',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,32',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,71',
#    'PIRATES/EP': '0,13',
#    'PSE-EE/PSOE': '18,25',
#    'AXSI': '0',
#    'EH-BILDU OR': '29,71',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '32,43',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,39',
#    'CV-EC': '0,06',
#    'CS': '1,68',
#    'CONTIGO': '0',
#    'JUNTS': '0,39',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '4,85',
#    'SAIN': '0',
#    'PODEMOS-IU': '10,68',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0,32',
#    'CXE': '0,06',
#    '_id': 212,
#    'VOX': '0,06'},
#   {'ZENTSUA/CENSO': 6563,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZALLA',
#    'CPE': '1',
#    'ADN': '0',
#    'IGRE': '1',
#    'PCPE-PCPC-P': '5',
#    'ALTER': '1',
#    'PCTE-ELAK': '4',
#    'I.FEM': '6',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '62',
#    'FAC': '0',
#    'PH': '6',
#    'ZURIAK/BLANCOS': '47',
#    'PIRATES/EP': '2',
#    'PSE-EE/PSOE': '666',
#    'AXSI': '0',
#    'EH-BILDU OR': '730',
#    'IZQP': '2',
#    'CEX-CREX-PR': '1',
#    'EAJ-PNV': '2725',
#    'VOLT': '4',
#    'PACMA/ATTAA': '45',
#    'CV-EC': '13',
#    'CS': '82',
#    'CONTIGO': '2',
#    'JUNTS': '10',
#    'PACT': '2',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '105',
#    'SAIN': '0',
#    'PODEMOS-IU': '494',
#    'PUM+J': '6',
#    'R0-LV-GVE': '5',
#    'CXE': '1',
#    '_id': 213,
#    'VOX': '31'},
#   {'ZENTSUA/CENSO': 6563,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZALLA',
#    'CPE': '0,02',
#    'ADN': '0',
#    'IGRE': '0,02',
#    'PCPE-PCPC-P': '0,1',
#    'ALTER': '0,02',
#    'PCTE-ELAK': '0,08',
#    'I.FEM': '0,12',
#    'ABSTENTZIOA %/% ABSTENCION': '22,92',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '1,23',
#    'FAC': '0',
#    'PH': '0,12',
#    'ZURIAK/BLANCOS': '0,94',
#    'PIRATES/EP': '0,04',
#    'PSE-EE/PSOE': '13,33',
#    'AXSI': '0',
#    'EH-BILDU OR': '14,61',
#    'IZQP': '0,04',
#    'CEX-CREX-PR': '0,02',
#    'EAJ-PNV': '54,53',
#    'VOLT': '0,08',
#    'PACMA/ATTAA': '0,9',
#    'CV-EC': '0,26',
#    'CS': '1,64',
#    'CONTIGO': '0,04',
#    'JUNTS': '0,2',
#    'PACT': '0,04',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '2,1',
#    'SAIN': '0',
#    'PODEMOS-IU': '9,89',
#    'PUM+J': '0,12',
#    'R0-LV-GVE': '0,1',
#    'CXE': '0,02',
#    '_id': 214,
#    'VOX': '0,62'},
#   {'ZENTSUA/CENSO': 2498,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZAMUDIO',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '4',
#    'I.FEM': '2',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '18',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '14',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '178',
#    'AXSI': '0',
#    'EH-BILDU OR': '480',
#    'IZQP': '0',
#    'CEX-CREX-PR': '1',
#    'EAJ-PNV': '905',
#    'VOLT': '0',
#    'PACMA/ATTAA': '6',
#    'CV-EC': '5',
#    'CS': '21',
#    'CONTIGO': '0',
#    'JUNTS': '7',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '32',
#    'SAIN': '0',
#    'PODEMOS-IU': '130',
#    'PUM+J': '1',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 215,
#    'VOX': '6'},
#   {'ZENTSUA/CENSO': 2498,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZAMUDIO',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0,22',
#    'I.FEM': '0,11',
#    'ABSTENTZIOA %/% ABSTENCION': '27,54',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,99',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,78',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '9,93',
#    'AXSI': '0',
#    'EH-BILDU OR': '26,79',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0,06',
#    'EAJ-PNV': '50,5',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,33',
#    'CV-EC': '0,28',
#    'CS': '1,17',
#    'CONTIGO': '0',
#    'JUNTS': '0,39',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '1,79',
#    'SAIN': '0',
#    'PODEMOS-IU': '7,25',
#    'PUM+J': '0,06',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 216,
#    'VOX': '0,33'},
#   {'ZENTSUA/CENSO': 1313,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZARATAMO',
#    'CPE': '0',
#    'ADN': '1',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '8',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '7',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '114',
#    'AXSI': '0',
#    'EH-BILDU OR': '260',
#    'IZQP': '1',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '365',
#    'VOLT': '0',
#    'PACMA/ATTAA': '17',
#    'CV-EC': '1',
#    'CS': '15',
#    'CONTIGO': '0',
#    'JUNTS': '1',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '25',
#    'SAIN': '0',
#    'PODEMOS-IU': '90',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 217,
#    'VOX': '4'},
#   {'ZENTSUA/CENSO': 1313,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZARATAMO',
#    'CPE': '0',
#    'ADN': '0,11',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '30,77',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,88',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,78',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '12,65',
#    'AXSI': '0',
#    'EH-BILDU OR': '28,86',
#    'IZQP': '0,11',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '40,51',
#    'VOLT': '0',
#    'PACMA/ATTAA': '1,89',
#    'CV-EC': '0,11',
#    'CS': '1,66',
#    'CONTIGO': '0',
#    'JUNTS': '0,11',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '2,77',
#    'SAIN': '0',
#    'PODEMOS-IU': '9,99',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 218,
#    'VOX': '0,44'},
#   {'ZENTSUA/CENSO': 1005,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZEANURI',
#    'CPE': '1',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '1',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '8',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '2',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '7',
#    'AXSI': '0',
#    'EH-BILDU OR': '350',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '389',
#    'VOLT': '0',
#    'PACMA/ATTAA': '1',
#    'CV-EC': '0',
#    'CS': '8',
#    'CONTIGO': '0',
#    'JUNTS': '5',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '6',
#    'SAIN': '0',
#    'PODEMOS-IU': '31',
#    'PUM+J': '0',
#    'R0-LV-GVE': '1',
#    'CXE': '0',
#    '_id': 219,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 1005,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZEANURI',
#    'CPE': '0,12',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0,12',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '19,4',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,99',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,25',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '0,87',
#    'AXSI': '0',
#    'EH-BILDU OR': '43,64',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '48,5',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,12',
#    'CV-EC': '0',
#    'CS': '1',
#    'CONTIGO': '0',
#    'JUNTS': '0,62',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '0,75',
#    'SAIN': '0',
#    'PODEMOS-IU': '3,87',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0,12',
#    'CXE': '0',
#    '_id': 220,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 860,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZEBERIO',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '1',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '3',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '3',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '13',
#    'AXSI': '0',
#    'EH-BILDU OR': '273',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '364',
#    'VOLT': '0',
#    'PACMA/ATTAA': '2',
#    'CV-EC': '0',
#    'CS': '3',
#    'CONTIGO': '0',
#    'JUNTS': '2',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '3',
#    'SAIN': '0',
#    'PODEMOS-IU': '35',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 221,
#    'VOX': '2'},
#   {'ZENTSUA/CENSO': 860,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZEBERIO',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0,14',
#    'ABSTENTZIOA %/% ABSTENCION': '18,14',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0,43',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,43',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '1,85',
#    'AXSI': '0',
#    'EH-BILDU OR': '38,94',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '51,93',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,29',
#    'CV-EC': '0',
#    'CS': '0,43',
#    'CONTIGO': '0',
#    'JUNTS': '0,29',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '0,43',
#    'SAIN': '0',
#    'PODEMOS-IU': '4,99',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 222,
#    'VOX': '0,29'},
#   {'ZENTSUA/CENSO': 1226,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZIERBENA',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '1',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '9',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '8',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '64',
#    'AXSI': '0',
#    'EH-BILDU OR': '220',
#    'IZQP': '0',
#    'CEX-CREX-PR': '1',
#    'EAJ-PNV': '486',
#    'VOLT': '0',
#    'PACMA/ATTAA': '3',
#    'CV-EC': '1',
#    'CS': '12',
#    'CONTIGO': '0',
#    'JUNTS': '8',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '13',
#    'SAIN': '0',
#    'PODEMOS-IU': '69',
#    'PUM+J': '0',
#    'R0-LV-GVE': '1',
#    'CXE': '0',
#    '_id': 223,
#    'VOX': '3'},
#   {'ZENTSUA/CENSO': 1226,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZIERBENA',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0,11',
#    'ABSTENTZIOA %/% ABSTENCION': '26,67',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '1',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,9',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '7,19',
#    'AXSI': '0',
#    'EH-BILDU OR': '24,72',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0,11',
#    'EAJ-PNV': '54,61',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0,34',
#    'CV-EC': '0,11',
#    'CS': '1,35',
#    'CONTIGO': '0',
#    'JUNTS': '0,9',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '1,46',
#    'SAIN': '0',
#    'PODEMOS-IU': '7,75',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0,11',
#    'CXE': '0',
#    '_id': 224,
#    'VOX': '0,34'},
#   {'ZENTSUA/CENSO': 346,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZIORTZA-BOLIBAR',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '0',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '1',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '2',
#    'AXSI': '0',
#    'EH-BILDU OR': '153',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '95',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0',
#    'CV-EC': '0',
#    'CS': '1',
#    'CONTIGO': '0',
#    'JUNTS': '0',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOAK/VOTOS',
#    'PP': '2',
#    'SAIN': '0',
#    'PODEMOS-IU': '8',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 225,
#    'VOX': '0'},
#   {'ZENTSUA/CENSO': 346,
#    'M.C.R.': '0',
#    'EREMUAK/AMBITOS': 'ZIORTZA-BOLIBAR',
#    'CPE': '0',
#    'ADN': '0',
#    'IGRE': '0',
#    'PCPE-PCPC-P': '0',
#    'ALTER': '0',
#    'PCTE-ELAK': '0',
#    'I.FEM': '0',
#    'ABSTENTZIOA %/% ABSTENCION': '24,28',
#    'MIEL': '0',
#    'ZENBATUTA %/% ESCRUTADO': 100,
#    'BALIOGABEAK/NULOS': '0',
#    'FAC': '0',
#    'PH': '0',
#    'ZURIAK/BLANCOS': '0,38',
#    'PIRATES/EP': '0',
#    'PSE-EE/PSOE': '0,76',
#    'AXSI': '0',
#    'EH-BILDU OR': '58,4',
#    'IZQP': '0',
#    'CEX-CREX-PR': '0',
#    'EAJ-PNV': '36,26',
#    'VOLT': '0',
#    'PACMA/ATTAA': '0',
#    'CV-EC': '0',
#    'CS': '0,38',
#    'CONTIGO': '0',
#    'JUNTS': '0',
#    'PACT': '0',
#    'AZALPENA/CONCEPTO': 'BOTOEN %/% DE VOTOS',
#    'PP': '0,76',
#    'SAIN': '0',
#    'PODEMOS-IU': '3,05',
#    'PUM+J': '0',
#    'R0-LV-GVE': '0',
#    'CXE': '0',
#    '_id': 226,
#    'VOX': '0'}]}

# %%
pd.read_csv("https://www.opendatabizkaia.eus/es/dump/e9c5f672-ec3f-4094-a230-9dd022b28705/elecciones-europeas-2019?format=csv", encoding="latin-1")
# Out:
#      ï»¿_id                    EREMUAK/AMBITOS    AZALPENA/CONCEPTO  \
# 0         1                            BIZKAIA         BOTOAK/VOTOS
# 1         2                            BIZKAIA  BOTOEN %/% DE VOTOS
# 2         3                         ABADIÃÂO         BOTOAK/VOTOS
# 3         4                         ABADIÃÂO  BOTOEN %/% DE VOTOS
# 4         5  ABANTO Y CIERVANA-ABANTO ZIERBENA         BOTOAK/VOTOS
# ..      ...                                ...                  ...
# 221     222                            ZEBERIO  BOTOEN %/% DE VOTOS
# 222     223                           ZIERBENA         BOTOAK/VOTOS
# 223     224                           ZIERBENA  BOTOEN %/% DE VOTOS
# 224     225                    ZIORTZA-BOLIBAR         BOTOAK/VOTOS
# 225     226                    ZIORTZA-BOLIBAR  BOTOEN %/% DE VOTOS
#
#      ZENTSUA/CENSO  ZENBATUTA %/% ESCRUTADO   ADN ALTER  AXSI CEX-CREX-PR  \
# 0           911770                      100   121   339    71         115
# 1           911770                      100  0,02  0,06  0,01        0,02
# 2             5900                      100     1     0     0           1
# 3             5900                      100  0,02     0     0        0,02
# 4             7769                      100     2     1     0           0
# ..             ...                      ...   ...   ...   ...         ...
# 221            860                      100     0     0     0           0
# 222           1226                      100     0     0     0           1
# 223           1226                      100     0     0     0        0,11
# 224            346                      100     0     0     0           0
# 225            346                      100     0     0     0           0
#
#     CONTIGO  ...     PP PSE-EE/PSOE PUM+J R0-LV-GVE  SAIN  VOLT   VOX  \
# 0       125  ...  36178      109843   549       994    99   381  7118
# 1      0,02  ...   6,11       18,56  0,09      0,17  0,02  0,06   1,2
# 2         1  ...    155         643     2         7     0     1    35
# 3      0,02  ...   3,86          16  0,05      0,17     0  0,02  0,87
# 4         0  ...     94         996     4         7     1     0    46
# ..      ...  ...    ...         ...   ...       ...   ...   ...   ...
# 221       0  ...   0,43        1,85     0         0     0     0  0,29
# 222       0  ...     13          64     0         1     0     0     3
# 223       0  ...   1,46        7,19     0      0,11     0     0  0,34
# 224       0  ...      2           2     0         0     0     0     0
# 225       0  ...   0,76        0,76     0         0     0     0     0
#
#     ZURIAK/BLANCOS BALIOGABEAK/NULOS ABSTENTZIOA %/% ABSTENCION
# 0             4490              3015                          0
# 1             0,76              0,51                      34,75
# 2               51                26                          0
# 3             1,27              0,64                      31,44
# 4               47                36                          0
# ..             ...               ...                        ...
# 221           0,43              0,43                      18,14
# 222              8                 9                          0
# 223            0,9                 1                      26,67
# 224              1                 0                          0
# 225           0,38                 0                      24,28
#
# [226 rows x 40 columns]

# %% [markdown]
# ## Api chucknorris

# %% [markdown]
# [Enlace API](https://api.chucknorris.io/)

# %%
url = "https://api.chucknorris.io/jokes/random"  # Reemplaza con la URL de la API que deseas acceder.

response = requests.get(url)

if response.status_code == 200:  # Código 200 indica una respuesta exitosa.
    data = response.json()  # Analizar la respuesta JSON.
    print(data["value"])
else:
    print("Error en la solicitud: ", response.status_code)
# Out:
# Kids wear Super Man pajamas, but Super Man wears Chuck Norris pajamas

# %%
def get_joke(url):
    response = requests.get(url)

    if response.status_code == 200:  # Código 200 indica una respuesta exitosa.
        data = response.json()  # Analizar la respuesta JSON.
        return data
    else:
        print("Error en la solicitud: ", response.status_code)

# %%
url = "https://api.chucknorris.io/jokes/categories"
get_joke(url)
# Out:
# ['animal',
#  'career',
#  'celebrity',
#  'dev',
#  'explicit',
#  'fashion',
#  'food',
#  'history',
#  'money',
#  'movie',
#  'music',
#  'political',
#  'religion',
#  'science',
#  'sport',
#  'travel']

# %% [markdown]
# Añadiendo `?` damos inicio a la secuencia de parámetros a ingresar que serán una consecución de `clave=valor` separados por `&` para cada parámetro que debamos introducir.

# %%
url = "https://api.chucknorris.io/jokes/random?category=animal"
get_joke(url)
# Out:
# {'categories': ['animal'],
#  'created_at': '2020-01-05 13:42:19.576875',
#  'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#  'id': 'bmom6jqftpqgokh8adtolw',
#  'updated_at': '2020-01-05 13:42:19.576875',
#  'url': 'https://api.chucknorris.io/jokes/bmom6jqftpqgokh8adtolw',
#  'value': 'Chuck Norris once rode a nine foot grizzly bear through an automatic car wash, instead of taking a shower.'}

# %%
get_joke("https://api.chucknorris.io/jokes/search?query=god")
# Out:
# {'total': 169,
#  'result': [{'categories': [],
#    'created_at': '2020-01-05 13:42:18.823766',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '1OEbwlF5Tti4INZDt4ocjQ',
#    'updated_at': '2020-01-05 13:42:18.823766',
#    'url': 'https://api.chucknorris.io/jokes/1OEbwlF5Tti4INZDt4ocjQ',
#    'value': 'GOD said he created humans in his image he did not say anything about Chuck Norris'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:18.823766',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'y-bNIK9GScaNSMWewihm0w',
#    'updated_at': '2020-01-05 13:42:18.823766',
#    'url': 'https://api.chucknorris.io/jokes/y-bNIK9GScaNSMWewihm0w',
#    'value': "Who knows what evil lurks in the hearts of men? Goddamn Chuck Norris, that's who."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:19.104863',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'VU5friiSScSKok3T_VTwjg',
#    'updated_at': '2020-01-05 13:42:19.104863',
#    'url': 'https://api.chucknorris.io/jokes/VU5friiSScSKok3T_VTwjg',
#    'value': "God used to make frequent trips to earth to talk to various people. Upon seeing Chuck Norris' manly good looks God vanquished himself to heaven, never to be seen again out of embarassment of his own self image. It's rumored Chuck is currently God's personal fitness trainer."},
#   {'categories': ['dev'],
#    'created_at': '2020-01-05 13:42:19.324003',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'o8a2hwedsl229fyvwikkxq',
#    'updated_at': '2020-01-05 13:42:19.324003',
#    'url': 'https://api.chucknorris.io/jokes/o8a2hwedsl229fyvwikkxq',
#    'value': 'The only pattern Chuck Norris knows is God Object.'},
#   {'categories': ['religion'],
#    'created_at': '2020-01-05 13:42:19.324003',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'bv5nh4jrrpwa7t6tul3p9q',
#    'updated_at': '2020-01-05 13:42:19.324003',
#    'url': 'https://api.chucknorris.io/jokes/bv5nh4jrrpwa7t6tul3p9q',
#    'value': 'According to the Bible, God created the universe in six days. Before that, Chuck Norris created God by snapping his fingers.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:19.324003',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'zqrZacQfRDW9hE4PTyyyPQ',
#    'updated_at': '2020-01-05 13:42:19.324003',
#    'url': 'https://api.chucknorris.io/jokes/zqrZacQfRDW9hE4PTyyyPQ',
#    'value': 'life < existence < Infinite power < God < Chuck Norris.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:19.324003',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'KOaqrHmKQgiKfzHIF_q4JA',
#    'updated_at': '2020-01-05 13:42:19.324003',
#    'url': 'https://api.chucknorris.io/jokes/KOaqrHmKQgiKfzHIF_q4JA',
#    'value': "Chuck Norris doesn't believe in god, god believes in Chuck Norris."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:19.324003',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '_nHrivZuTuOebVVya0e2LA',
#    'updated_at': '2020-01-05 13:42:19.324003',
#    'url': 'https://api.chucknorris.io/jokes/_nHrivZuTuOebVVya0e2LA',
#    'value': "Godzilla is lucky that Chuck Norris doesn't live in Japan"},
#   {'categories': ['religion'],
#    'created_at': '2020-01-05 13:42:19.324003',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'defxwux_t-wond-zfhoicq',
#    'updated_at': '2020-01-05 13:42:19.324003',
#    'url': 'https://api.chucknorris.io/jokes/defxwux_t-wond-zfhoicq',
#    'value': "Chuck Norris doesn't play god. Playing is for children."},
#   {'categories': ['religion'],
#    'created_at': '2020-01-05 13:42:19.324003',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '3kf42nr6qhkll8hucjbhow',
#    'updated_at': '2020-01-05 13:42:19.324003',
#    'url': 'https://api.chucknorris.io/jokes/3kf42nr6qhkll8hucjbhow',
#    'value': 'Chuck Norris has never been accused of murder because his roundhouse kicks are recognized as "acts of God."'},
#   {'categories': ['movie'],
#    'created_at': '2020-01-05 13:42:19.324003',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'hy1jtzj8svq3mpr6pv6lfg',
#    'updated_at': '2020-01-05 13:42:19.324003',
#    'url': 'https://api.chucknorris.io/jokes/hy1jtzj8svq3mpr6pv6lfg',
#    'value': "Godzilla is a Japanese rendition of Chuck Norris' first visit to Tokyo."},
#   {'categories': ['religion'],
#    'created_at': '2020-01-05 13:42:19.324003',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'bxj_mvi2re-nlis970ejga',
#    'updated_at': '2020-01-05 13:42:19.324003',
#    'url': 'https://api.chucknorris.io/jokes/bxj_mvi2re-nlis970ejga',
#    'value': 'When God said, "let there be light", Chuck Norris said, "say \'please\'."'},
#   {'categories': ['religion'],
#    'created_at': '2020-01-05 13:42:19.576875',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '-fa7rpzlr2iafe1pmq7xaa',
#    'updated_at': '2020-01-05 13:42:19.576875',
#    'url': 'https://api.chucknorris.io/jokes/-fa7rpzlr2iafe1pmq7xaa',
#    'value': 'A high tide means Chuck Norris is flying over your coast. The tide is caused by God pissing his pants.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:19.576875',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'kQjF-09oT6aWBfP3jK7Q6A',
#    'updated_at': '2020-01-05 13:42:19.576875',
#    'url': 'https://api.chucknorris.io/jokes/kQjF-09oT6aWBfP3jK7Q6A',
#    'value': 'Proof that Chuck Norris is not God: It took God 7 days to create the world. The new "Super Earth\'s" found were round-housed into existence by Chuck in seconds.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:19.897976',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'kCKncKP3TUai-BuYoLfkKw',
#    'updated_at': '2020-01-05 13:42:19.897976',
#    'url': 'https://api.chucknorris.io/jokes/kCKncKP3TUai-BuYoLfkKw',
#    'value': 'The guy that God prays to goes to Chuck Norris for forgiveness!'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:19.897976',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'tPIj_A3_QE6VzPxVZeoakQ',
#    'updated_at': '2020-01-05 13:42:19.897976',
#    'url': 'https://api.chucknorris.io/jokes/tPIj_A3_QE6VzPxVZeoakQ',
#    'value': 'God created Chuck Norris because Chuck Norris allowed him.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:19.897976',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'Gm6_f4cdSuKV47nAn8-RUQ',
#    'updated_at': '2020-01-05 13:42:19.897976',
#    'url': 'https://api.chucknorris.io/jokes/Gm6_f4cdSuKV47nAn8-RUQ',
#    'value': 'If God knows all, sees all, and hears all, then God must be Chuck Norris.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.262289',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'WewlqvNETdassu_V1JmATA',
#    'updated_at': '2020-01-05 13:42:20.262289',
#    'url': 'https://api.chucknorris.io/jokes/WewlqvNETdassu_V1JmATA',
#    'value': 'On Day Zero, Chuck Norris created God.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.262289',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'UlCHS2ppSme40EmQ7cKYlw',
#    'updated_at': '2020-01-05 13:42:20.262289',
#    'url': 'https://api.chucknorris.io/jokes/UlCHS2ppSme40EmQ7cKYlw',
#    'value': "Don't bother praying to be saved from Chuck Norris; God was about to ask you the same thing."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.568859',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '-t85y0gySYOHB6Z7N8FKlQ',
#    'updated_at': '2020-01-05 13:42:20.568859',
#    'url': 'https://api.chucknorris.io/jokes/-t85y0gySYOHB6Z7N8FKlQ',
#    'value': 'People pray to God. God prays to Chuck Norris'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.568859',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'NPVUfHvJTfmUW-TjkD8hBA',
#    'updated_at': '2020-01-05 13:42:20.568859',
#    'url': 'https://api.chucknorris.io/jokes/NPVUfHvJTfmUW-TjkD8hBA',
#    'value': 'God help anyone who dares play a Wii game against Chuck Norris when the nunchuck is involved.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.568859',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'xkSTD3EdQcOXh_1nWUzZOg',
#    'updated_at': '2020-01-05 13:42:20.568859',
#    'url': 'https://api.chucknorris.io/jokes/xkSTD3EdQcOXh_1nWUzZOg',
#    'value': 'God help any Chuck Norris impersonator'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.568859',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'zSuDyeBLSg6nqCaIV_dmJQ',
#    'updated_at': '2020-01-05 13:42:20.568859',
#    'url': 'https://api.chucknorris.io/jokes/zSuDyeBLSg6nqCaIV_dmJQ',
#    'value': 'Chuck Norris is my godfather. As he is yours.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.841843',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '9zcJlGVOSYWOeQjRMcTlFA',
#    'updated_at': '2020-01-05 13:42:20.841843',
#    'url': 'https://api.chucknorris.io/jokes/9zcJlGVOSYWOeQjRMcTlFA',
#    'value': 'Genesis 32:30- I have seen the face of God Chuck Norris 1:1- I punched the shit out of it'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.841843',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'HKqgK-ZQS7yuk9MvtsrmVg',
#    'updated_at': '2020-01-05 13:42:20.841843',
#    'url': 'https://api.chucknorris.io/jokes/HKqgK-ZQS7yuk9MvtsrmVg',
#    'value': "Of course God is a woman, she's Chuck Norris' bitch"},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.841843',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'nddKnLB4R-qPJeMNyvQTgw',
#    'updated_at': '2020-01-05 13:42:20.841843',
#    'url': 'https://api.chucknorris.io/jokes/nddKnLB4R-qPJeMNyvQTgw',
#    'value': 'God said to the world, "Let there be light!" Chuck Norris said, "Say Please"'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.841843',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'lcHOB8pBRe6bdewQNAAXRw',
#    'updated_at': '2020-01-05 13:42:20.841843',
#    'url': 'https://api.chucknorris.io/jokes/lcHOB8pBRe6bdewQNAAXRw',
#    'value': 'If you slap Chuck Norris......oh god i just cant say it...hes behind me.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.841843',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'EButAyN5R2WfeCoblLFhAw',
#    'updated_at': '2020-01-05 13:42:20.841843',
#    'url': 'https://api.chucknorris.io/jokes/EButAyN5R2WfeCoblLFhAw',
#    'value': "Some of Chuck Norris' favorite comedies include Reservoir Dogs, 300, Scarface, The Wild Bunch, Terminator II, Rambo III, Natural Born Killers, Conan the Barbarian, The Godfather, and Apocalypse Now."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.841843',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'G44Ocrk4QbquE5rNbUBowg',
#    'updated_at': '2020-01-05 13:42:20.841843',
#    'url': 'https://api.chucknorris.io/jokes/G44Ocrk4QbquE5rNbUBowg',
#    'value': 'Chuck Norris makes Bear Grylls look like a goddamn shut-in.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.841843',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'IoUTD8G7Te28Yq1S0c0_lQ',
#    'updated_at': '2020-01-05 13:42:20.841843',
#    'url': 'https://api.chucknorris.io/jokes/IoUTD8G7Te28Yq1S0c0_lQ',
#    'value': 'We\'re taught Jesus died for the redemption of our sins: past, present and future. If Chuck Norris sins, we\'re totally screwed. We\'ll need a bus full of Jesuses, for something as minor as when Chuck Norris says "God dammit".'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.841843',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'PVf3ljyzRWCjYu_7ZBtinQ',
#    'updated_at': '2020-01-05 13:42:20.841843',
#    'url': 'https://api.chucknorris.io/jokes/PVf3ljyzRWCjYu_7ZBtinQ',
#    'value': "When he was a kid, Chuck Norris invented an imaginary friend, whom he called 'God'. Everyone got in on the act, and religion was born."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.841843',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'E6Y_i3CXRhKfyWR04UNd0w',
#    'updated_at': '2020-01-05 13:42:20.841843',
#    'url': 'https://api.chucknorris.io/jokes/E6Y_i3CXRhKfyWR04UNd0w',
#    'value': 'Greek Gods fled to Mount Olympus they saw Chuck Norris wandered on earth.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.841843',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'ypmUlfxUQSGh8VqMSUJUwQ',
#    'updated_at': '2020-01-05 13:42:20.841843',
#    'url': 'https://api.chucknorris.io/jokes/ypmUlfxUQSGh8VqMSUJUwQ',
#    'value': 'Chuck Norris never needs toilet paper to wipe his ass,his Godly ass wipes it himself.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:20.841843',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'XR9RaXneS2OJqqaTCqeFkw',
#    'updated_at': '2020-01-05 13:42:20.841843',
#    'url': 'https://api.chucknorris.io/jokes/XR9RaXneS2OJqqaTCqeFkw',
#    'value': "Chuck Norris don't need no academy award, he owns the goddamn academy."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.179347',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'Vjm0wyg8QzK0M31IwGVK6Q',
#    'updated_at': '2020-01-05 13:42:21.179347',
#    'url': 'https://api.chucknorris.io/jokes/Vjm0wyg8QzK0M31IwGVK6Q',
#    'value': 'When Chuck norris gave birth to himself god said "O\' my chuck!"'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.179347',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'fSe4CfeNR0a9BMHKUdZvmw',
#    'updated_at': '2020-01-05 13:42:21.179347',
#    'url': 'https://api.chucknorris.io/jokes/fSe4CfeNR0a9BMHKUdZvmw',
#    'value': 'If you dont believe God exists, he doesnt believe you exist, and soon you should expect an explosive roundhouse kick to the face....(Chuck Norris is God.)'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.179347',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'ty07kwuOQNiKFCs-uiKLmQ',
#    'updated_at': '2020-01-05 13:42:21.179347',
#    'url': 'https://api.chucknorris.io/jokes/ty07kwuOQNiKFCs-uiKLmQ',
#    'value': 'Chuck Norris was not made by god.God was made by Chuck Norris'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.179347',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'VST-DaSZQcqGJAhgwqVMWw',
#    'updated_at': '2020-01-05 13:42:21.179347',
#    'url': 'https://api.chucknorris.io/jokes/VST-DaSZQcqGJAhgwqVMWw',
#    'value': 'God creates dinosaurs, God destroys dinosaurs, God creates man, man destroys God, Chuck Norris drinks beer and fucks strippers and shit.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.179347',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'LC7CrYXvTXm2tYIVPYL0xA',
#    'updated_at': '2020-01-05 13:42:21.179347',
#    'url': 'https://api.chucknorris.io/jokes/LC7CrYXvTXm2tYIVPYL0xA',
#    'value': "God rested on the seventh day because Chuck Norris isn't that much of a slave driver."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.179347',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'qs0a15v6TwWHNOEso2SQBA',
#    'updated_at': '2020-01-05 13:42:21.179347',
#    'url': 'https://api.chucknorris.io/jokes/qs0a15v6TwWHNOEso2SQBA',
#    'value': 'The Incas used to sacrifice their most beautiful women to the Sun God. The Sun God was their title for Chuck Norris.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.179347',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'IrXXuX4pTc2MeF_x_gsPdQ',
#    'updated_at': '2020-01-05 13:42:21.179347',
#    'url': 'https://api.chucknorris.io/jokes/IrXXuX4pTc2MeF_x_gsPdQ',
#    'value': "Chuck Norris is God's secret cousin"},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.455187',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'ZMmIfKkxQtCBOnX4Io5vfw',
#    'updated_at': '2020-01-05 13:42:21.455187',
#    'url': 'https://api.chucknorris.io/jokes/ZMmIfKkxQtCBOnX4Io5vfw',
#    'value': 'Once god asked Chuck Norris "what do you want?". Chuck Norris retorted "what the fuck do YOU want?" and proceeded to roundhouse kick him mercilessly. Ever since god went into hiding and is rarely seen by anyone ever again.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.455187',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'j2X8Ej2yRFS2HyV5FBw_Iw',
#    'updated_at': '2020-01-05 13:42:21.455187',
#    'url': 'https://api.chucknorris.io/jokes/j2X8Ej2yRFS2HyV5FBw_Iw',
#    'value': 'God modeled his beard look after Chuck Norris.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.455187',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'Z-szoBUuTqGaukJJY2y0KA',
#    'updated_at': '2020-01-05 13:42:21.455187',
#    'url': 'https://api.chucknorris.io/jokes/Z-szoBUuTqGaukJJY2y0KA',
#    'value': 'Only God can judge the whole mankind. Only Chuck Norris can judge God'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.455187',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'KEsPZmb4QnyzTwj4-axquA',
#    'updated_at': '2020-01-05 13:42:21.455187',
#    'url': 'https://api.chucknorris.io/jokes/KEsPZmb4QnyzTwj4-axquA',
#    'value': 'Chuck Norris drinks his whiskey with a goddamn funnel.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.795084',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '4t5ClhHHSvaM6dKEPYQGRQ',
#    'updated_at': '2020-01-05 13:42:21.795084',
#    'url': 'https://api.chucknorris.io/jokes/4t5ClhHHSvaM6dKEPYQGRQ',
#    'value': 'God said "Let there be light!" Chuck Norris said "Say please."'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.795084',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '2eVjkYtCTeiGjb3DiSw6zQ',
#    'updated_at': '2020-01-05 13:42:21.795084',
#    'url': 'https://api.chucknorris.io/jokes/2eVjkYtCTeiGjb3DiSw6zQ',
#    'value': "There is great debate over whether The Book Of Chuck (written by Chuck Norris in 1989) should be included in the Bible. It mostly contains stories of Norris' sexual conquests and his overall Godliness, but the occasional philosophy contained within easily renders the rest of the books obsolete."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.795084',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'cDe_bUNgRqe0qOKJDaftMg',
#    'updated_at': '2020-01-05 13:42:21.795084',
#    'url': 'https://api.chucknorris.io/jokes/cDe_bUNgRqe0qOKJDaftMg',
#    'value': 'God is Chuck Norris 3rd cousin'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.795084',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '-bKsKntBStuKDYOWT-tHaA',
#    'updated_at': '2020-01-05 13:42:21.795084',
#    'url': 'https://api.chucknorris.io/jokes/-bKsKntBStuKDYOWT-tHaA',
#    'value': 'When Chuck Norris gets the munchies, God help any 7-11'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.795084',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'uDHecvfPQ5ePeQnb0GZKkw',
#    'updated_at': '2020-01-05 13:42:21.795084',
#    'url': 'https://api.chucknorris.io/jokes/uDHecvfPQ5ePeQnb0GZKkw',
#    'value': 'Chuck Norris\' fairy godparents do not use "Da Rules book". He can wish for anything he wants no matter if its bad or not.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:21.795084',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'wDRyXyVOSuKelw9nlUe5Mg',
#    'updated_at': '2020-01-05 13:42:21.795084',
#    'url': 'https://api.chucknorris.io/jokes/wDRyXyVOSuKelw9nlUe5Mg',
#    'value': 'Can God create a rock so heavy he himself cannot lift? Yes, he created Chuck Norris.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:22.089095',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'zZQvpjk6TAi46HkarLFInA',
#    'updated_at': '2020-01-05 13:42:22.089095',
#    'url': 'https://api.chucknorris.io/jokes/zZQvpjk6TAi46HkarLFInA',
#    'value': 'Chuck Norris killed godzilla in his dream'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:22.089095',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'ALMkqOz_TQKjMK1QRHDa6Q',
#    'updated_at': '2020-01-05 13:42:22.089095',
#    'url': 'https://api.chucknorris.io/jokes/ALMkqOz_TQKjMK1QRHDa6Q',
#    'value': "A reporter once referred to Chuck Norris as a 'God-fearing patriot'. Upon reading the article, Chuck Norris immediately sprinted to the fucker's bomb shelter and turned him into hummous. Chuck Norris fears nothing."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:22.089095',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'Llen9qggRseZ5U5fIfCCAg',
#    'updated_at': '2020-01-05 13:42:22.089095',
#    'url': 'https://api.chucknorris.io/jokes/Llen9qggRseZ5U5fIfCCAg',
#    'value': 'God is just a fake name Chuck Norris uses.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:22.089095',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'BUmvu__NSX2mivfyYCXTpw',
#    'updated_at': '2020-01-05 13:42:22.089095',
#    'url': 'https://api.chucknorris.io/jokes/BUmvu__NSX2mivfyYCXTpw',
#    'value': "God help the man who disagrees with Chuck Norris. Or not, because God's afraid of him, too."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:22.701402',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'DDlwxNGOS3eJnQPtcEAWjQ',
#    'updated_at': '2020-01-05 13:42:22.701402',
#    'url': 'https://api.chucknorris.io/jokes/DDlwxNGOS3eJnQPtcEAWjQ',
#    'value': 'God breathed life into Adam. Chuck Norris sneezed life into God.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:22.701402',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'Wc_oEq8xRayGEodJ0c-mIA',
#    'updated_at': '2020-01-05 13:42:22.701402',
#    'url': 'https://api.chucknorris.io/jokes/Wc_oEq8xRayGEodJ0c-mIA',
#    'value': 'Chuck Norris makes Uncle Sam look like a goddamn chinaman.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:22.701402',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'n8dV0wpVTV-tC_QItYsP7Q',
#    'updated_at': '2020-01-05 13:42:22.701402',
#    'url': 'https://api.chucknorris.io/jokes/n8dV0wpVTV-tC_QItYsP7Q',
#    'value': 'Chuck Norris had to take over on the 7th day of creating whilst God was resting.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:22.701402',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'Z7ItfmPVQiCPPwQAQ0CYQQ',
#    'updated_at': '2020-01-05 13:42:22.701402',
#    'url': 'https://api.chucknorris.io/jokes/Z7ItfmPVQiCPPwQAQ0CYQQ',
#    'value': 'The big bang theory: Chuck Norris winning a arm wrestle with godd'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:22.980058',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'lx5mMleKQ_OjYAN6ZU3BNw',
#    'updated_at': '2020-01-05 13:42:22.980058',
#    'url': 'https://api.chucknorris.io/jokes/lx5mMleKQ_OjYAN6ZU3BNw',
#    'value': 'God offered Chuck Norris the gift to fly, which he swiftly declined for super strength roundhouse ability.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:22.980058',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'eOW3joW5R1aO6QTnlks7BA',
#    'updated_at': '2020-01-05 13:42:22.980058',
#    'url': 'https://api.chucknorris.io/jokes/eOW3joW5R1aO6QTnlks7BA',
#    'value': 'Odin, king of the viking gods, hung himself for 9 days and survived. Chuck Norris has made fun of him ever since for being a pussy and not going longer.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:22.980058',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'FTY24i1oQUaRO1jmbJKaXA',
#    'updated_at': '2020-01-05 13:42:22.980058',
#    'url': 'https://api.chucknorris.io/jokes/FTY24i1oQUaRO1jmbJKaXA',
#    'value': 'God didnt create Chuck Norris, Chuck Norris created God'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:22.980058',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'L-SI09W7SW67vSFb_oVN0g',
#    'updated_at': '2020-01-05 13:42:22.980058',
#    'url': 'https://api.chucknorris.io/jokes/L-SI09W7SW67vSFb_oVN0g',
#    'value': 'How come so many Godzilla movies were made? Because they never hired Chuck Norris to kill him off once and for all.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:22.980058',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'e3J62YU6RSyS4AUEq3KUOQ',
#    'updated_at': '2020-01-05 13:42:22.980058',
#    'url': 'https://api.chucknorris.io/jokes/e3J62YU6RSyS4AUEq3KUOQ',
#    'value': 'A deadly Texas Tornardo knows better than to damage or destroy any property or anything that belongs to Chuck Norris or any of his family if the Tornardo knows what is best for it because Chuck Norris is God.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:22.980058',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'qqup395TSoaeIyPVU0RHeA',
#    'updated_at': '2020-01-05 13:42:22.980058',
#    'url': 'https://api.chucknorris.io/jokes/qqup395TSoaeIyPVU0RHeA',
#    'value': 'God help anyone who attends a Chuck Norris poetry slam.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.880601',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'dVAQECWtQZS6IOAwzDN0yg',
#    'updated_at': '2020-01-05 13:42:23.880601',
#    'url': 'https://api.chucknorris.io/jokes/dVAQECWtQZS6IOAwzDN0yg',
#    'value': 'CHUCK NORRIS IS BIGGER THAN GODZILLA'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:22.980058',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'YsUbavl-Q42YatsiBS-AGw',
#    'updated_at': '2020-01-05 13:42:22.980058',
#    'url': 'https://api.chucknorris.io/jokes/YsUbavl-Q42YatsiBS-AGw',
#    'value': 'God prays to Chuck Norris.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.240175',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'OGaPNbUZQ9KpDf6JZPjtwQ',
#    'updated_at': '2020-01-05 13:42:23.240175',
#    'url': 'https://api.chucknorris.io/jokes/OGaPNbUZQ9KpDf6JZPjtwQ',
#    'value': "When God said, ''Let there be light''. Chuck Norris said ''Say Please''"},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.240175',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'KDcABQMuSEax_hoRLXdj5Q',
#    'updated_at': '2020-01-05 13:42:23.240175',
#    'url': 'https://api.chucknorris.io/jokes/KDcABQMuSEax_hoRLXdj5Q',
#    'value': 'The Aboriginal witch doctors of Australia consider Chuck Norris a godlike spirit-man for his ability to fart loud didgeridoo-like tones that paralyze wambats and other indigenous tablefare.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.240175',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'vJ-yBlRgS1SWXdqUUoZNng',
#    'updated_at': '2020-01-05 13:42:23.240175',
#    'url': 'https://api.chucknorris.io/jokes/vJ-yBlRgS1SWXdqUUoZNng',
#    'value': 'John Denver wrote "Thank God I\'m A Country Boy" when Chuck Norris moved to the city.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.240175',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'KihYSpPNSImCmiARlOhVKw',
#    'updated_at': '2020-01-05 13:42:23.240175',
#    'url': 'https://api.chucknorris.io/jokes/KihYSpPNSImCmiARlOhVKw',
#    'value': 'Chuck Norris was actually the one who made the world, he was just modest and let god take the credit.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.240175',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '-mSK9uCdTBCUYqKAQUtzCw',
#    'updated_at': '2020-01-05 13:42:23.240175',
#    'url': 'https://api.chucknorris.io/jokes/-mSK9uCdTBCUYqKAQUtzCw',
#    'value': "Despite popular belief God didn't rest on the seventh day...He created Chuck Norris!"},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.240175',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'cRJ_ZWg_QD-23YN7YPiMKA',
#    'updated_at': '2020-01-05 13:42:23.240175',
#    'url': 'https://api.chucknorris.io/jokes/cRJ_ZWg_QD-23YN7YPiMKA',
#    'value': "God is still slightly pissed off at Chuck Norris for using his halo to kill so many people... but he won't say anything about it."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.484083',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'HOKETRqNQEiPwnvtIUSA5g',
#    'updated_at': '2020-01-05 13:42:23.484083',
#    'url': 'https://api.chucknorris.io/jokes/HOKETRqNQEiPwnvtIUSA5g',
#    'value': 'Chuck Norris has never been accused of murder for the simple fact that his roundhouse kicks are recognized world-wide as "acts of God."'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.484083',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'AGcoEeS9TwOp52pXruIygw',
#    'updated_at': '2020-01-05 13:42:23.484083',
#    'url': 'https://api.chucknorris.io/jokes/AGcoEeS9TwOp52pXruIygw',
#    'value': 'GOD created the world in 6 days, what did he do on his rest day? HE CREATED CHUCK NORRIS'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.484083',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'YdnEsTugRI-kW1sH7z0-GA',
#    'updated_at': '2020-01-05 13:42:23.484083',
#    'url': 'https://api.chucknorris.io/jokes/YdnEsTugRI-kW1sH7z0-GA',
#    'value': 'If Chuck Norris was God, there would be no sand but only concrete, no water but only Liquir.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.484083',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '-37rCRWlT_aSPhWNZZygGg',
#    'updated_at': '2020-01-05 13:42:23.484083',
#    'url': 'https://api.chucknorris.io/jokes/-37rCRWlT_aSPhWNZZygGg',
#    'value': 'When God told Chuck Norris he was going to create the earth in six days Chuck Norris said you better or else.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.484083',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'MFtGxNQtQaegwl0WlnLagw',
#    'updated_at': '2020-01-05 13:42:23.484083',
#    'url': 'https://api.chucknorris.io/jokes/MFtGxNQtQaegwl0WlnLagw',
#    'value': 'There are ancient tribes in the Amazon, as yet untouched by modern civilization, who worship Chuck Norris as their god of gods.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.484083',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '1lqKdidUTLu1pEl4Oow7MA',
#    'updated_at': '2020-01-05 13:42:23.484083',
#    'url': 'https://api.chucknorris.io/jokes/1lqKdidUTLu1pEl4Oow7MA',
#    'value': 'When Chuck Norris wants something, the person standing next to him better goddamn give it to him within the next two seconds or die by the roundhouse kick.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.880601',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '4EUoSeW7Q9y_ikOrDleiyQ',
#    'updated_at': '2020-01-05 13:42:23.880601',
#    'url': 'https://api.chucknorris.io/jokes/4EUoSeW7Q9y_ikOrDleiyQ',
#    'value': 'When God walked in the sea ... Chuck Norris was swimming in the land!!'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.880601',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'XTeoZh0WSCC17NF9sjQYOA',
#    'updated_at': '2020-01-05 13:42:23.880601',
#    'url': 'https://api.chucknorris.io/jokes/XTeoZh0WSCC17NF9sjQYOA',
#    'value': 'Only Chuck Norris knows the truth about Extraterrestial life, God told him, but God also told them about Chuck which is why we never see them.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.880601',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '6N1nctxFTnui1dn9JqcAUQ',
#    'updated_at': '2020-01-05 13:42:23.880601',
#    'url': 'https://api.chucknorris.io/jokes/6N1nctxFTnui1dn9JqcAUQ',
#    'value': 'Chuck Norris. A man of goddamn action.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:23.880601',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'eDSGFh3UR92As2IB2jOztA',
#    'updated_at': '2020-01-05 13:42:23.880601',
#    'url': 'https://api.chucknorris.io/jokes/eDSGFh3UR92As2IB2jOztA',
#    'value': 'When God said: "LET THERE BE LIGHT!" Chuck Norris said: "Say please."'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:24.40636',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '1fQ9opiATFKTEtte8-Jthg',
#    'updated_at': '2020-01-05 13:42:24.40636',
#    'url': 'https://api.chucknorris.io/jokes/1fQ9opiATFKTEtte8-Jthg',
#    'value': 'Some people say that god can walk on water. Chuck Norris can swim on land'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:24.40636',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'J19rkQG_RnqGvgvzT_seAw',
#    'updated_at': '2020-01-05 13:42:24.40636',
#    'url': 'https://api.chucknorris.io/jokes/J19rkQG_RnqGvgvzT_seAw',
#    'value': "You bet your ass Chuck Norris' penny-farthing is the size of a goddamn ferris wheel"},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:24.40636',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'zAiZkkH6TGGB_GihlXTqpQ',
#    'updated_at': '2020-01-05 13:42:24.40636',
#    'url': 'https://api.chucknorris.io/jokes/zAiZkkH6TGGB_GihlXTqpQ',
#    'value': "Just before killing someone, Chuck Norris likes to say 'where's your god now?'"},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:24.40636',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'dfdbbSZvTr6A_ngYXaI5yw',
#    'updated_at': '2020-01-05 13:42:24.40636',
#    'url': 'https://api.chucknorris.io/jokes/dfdbbSZvTr6A_ngYXaI5yw',
#    'value': 'Chuck Norris met God once, God said "my son you have sinned" to which Chuck replied "Impossible, God doesn\'t make mistakes"...'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:24.696555',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'CSB0V4SeQdiCGtYpcIj5OA',
#    'updated_at': '2020-01-05 13:42:24.696555',
#    'url': 'https://api.chucknorris.io/jokes/CSB0V4SeQdiCGtYpcIj5OA',
#    'value': "We were created in Gods image, But God was created in Chuck Norris's image."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:24.696555',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'zkGTrtTWT729fIICudwpCw',
#    'updated_at': '2020-01-05 13:42:24.696555',
#    'url': 'https://api.chucknorris.io/jokes/zkGTrtTWT729fIICudwpCw',
#    'value': 'Chuck Norris eventually found God, terrified and in phoetal position. NO ONE hides from Chuck Norris.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:24.696555',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '5QfcNnoATqq0JvgewpRr5Q',
#    'updated_at': '2020-01-05 13:42:24.696555',
#    'url': 'https://api.chucknorris.io/jokes/5QfcNnoATqq0JvgewpRr5Q',
#    'value': 'Humans believe in GOD.GOd believes in DEATH.DEATH believes in CHUCK NORRIS'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:24.696555',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '-L_razZiToK4lL1GSSqPyg',
#    'updated_at': '2020-01-05 13:42:24.696555',
#    'url': 'https://api.chucknorris.io/jokes/-L_razZiToK4lL1GSSqPyg',
#    'value': 'The timeless movie classic "Clash of the Titans" is actually based on a 1974 Detroit Bar Fight involving Chuck Norris, Bruce Lee, God, and all five members of AC/DC.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:25.099703',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'h3Olx9rESdO0OluGQzKqaw',
#    'updated_at': '2020-01-05 13:42:25.099703',
#    'url': 'https://api.chucknorris.io/jokes/h3Olx9rESdO0OluGQzKqaw',
#    'value': 'On the day before the first day, Chuck Norris said, "Let there be God."'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:25.099703',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'Q5VKxnLRSE-srNtkGgH1MA',
#    'updated_at': '2020-01-05 13:42:25.099703',
#    'url': 'https://api.chucknorris.io/jokes/Q5VKxnLRSE-srNtkGgH1MA',
#    'value': 'It took God 1 week to create the earth and the heavens, it took him 2 weeks to create Chuck Norris!'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:25.099703',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'FdF56x_BQvOldvCqSZa78g',
#    'updated_at': '2020-01-05 13:42:25.099703',
#    'url': 'https://api.chucknorris.io/jokes/FdF56x_BQvOldvCqSZa78g',
#    'value': 'Chuck Norris\' Doctor does physicals and normally says "turn your head and cough". When Chuck drops his pants the Doctor says "oh my god"!!'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:25.099703',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'uzfjFsYiQDics_IUasKeCg',
#    'updated_at': '2020-01-05 13:42:25.099703',
#    'url': 'https://api.chucknorris.io/jokes/uzfjFsYiQDics_IUasKeCg',
#    'value': "Who'd win in a wrestling match, Chuck Norris or God? Trick question, Chuck Norris is God."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:25.099703',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'Mq2aglxZRfS-IMhtVlQFuw',
#    'updated_at': '2020-01-05 13:42:25.099703',
#    'url': 'https://api.chucknorris.io/jokes/Mq2aglxZRfS-IMhtVlQFuw',
#    'value': "Chuck Norris' tool is so huge that his wife thanks God he's having affairs."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:25.099703',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '0AdZScA2SbKPPZVgRuRQbQ',
#    'updated_at': '2020-01-05 13:42:25.099703',
#    'url': 'https://api.chucknorris.io/jokes/0AdZScA2SbKPPZVgRuRQbQ',
#    'value': 'In the beginning God created the Universe.. but who created God? - It was Chuck Norris!'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:25.352697',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'EPXXYQwVT16fq9PSBXWa0g',
#    'updated_at': '2020-01-05 13:42:25.352697',
#    'url': 'https://api.chucknorris.io/jokes/EPXXYQwVT16fq9PSBXWa0g',
#    'value': "Chuck Norris doesn't just bend space-time, he can turn it into a goddamn balloon animal."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:25.352697',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '8pgf5kg3T4-8wkPfh-4A3g',
#    'updated_at': '2020-01-05 13:42:25.352697',
#    'url': 'https://api.chucknorris.io/jokes/8pgf5kg3T4-8wkPfh-4A3g',
#    'value': 'Chuck Norris beat God in an arm-wrestle......with his feet.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:25.352697',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '_Rxhb-GaQIO-KWLhNrjOXA',
#    'updated_at': '2020-01-05 13:42:25.352697',
#    'url': 'https://api.chucknorris.io/jokes/_Rxhb-GaQIO-KWLhNrjOXA',
#    'value': "Chuck Norris applied for the position of 'God' but was rejected because of over-qualification."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:25.352697',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'ZyBcOij_TDmXyVQLlrKekA',
#    'updated_at': '2020-01-05 13:42:25.352697',
#    'url': 'https://api.chucknorris.io/jokes/ZyBcOij_TDmXyVQLlrKekA',
#    'value': 'God comes over to Chuck Norrises house to borrow sugar'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:25.628594',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'KmJpEStfTw-IjlR5xAHPhw',
#    'updated_at': '2020-01-05 13:42:25.628594',
#    'url': 'https://api.chucknorris.io/jokes/KmJpEStfTw-IjlR5xAHPhw',
#    'value': 'God is love. Chuck Norris is fucking awesome.q'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:25.628594',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'd9oq7U54RdGOvvGEROUi9Q',
#    'updated_at': '2020-01-05 13:42:25.628594',
#    'url': 'https://api.chucknorris.io/jokes/d9oq7U54RdGOvvGEROUi9Q',
#    'value': 'Chuck Norris was worshipped as a god by the Eskimos. That is why they had igloos modelled after his signature move.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:25.628594',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'owRlp4HqR7Wl1t6cH34u8w',
#    'updated_at': '2020-01-05 13:42:25.628594',
#    'url': 'https://api.chucknorris.io/jokes/owRlp4HqR7Wl1t6cH34u8w',
#    'value': 'You know why God took the name God? The name Chuck Norris was already taken.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:25.628594',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'KN3FvL55RC60tC1bDtI7sA',
#    'updated_at': '2020-01-05 13:42:25.628594',
#    'url': 'https://api.chucknorris.io/jokes/KN3FvL55RC60tC1bDtI7sA',
#    'value': "Most atheists agree that Chuck Norris is God's gift to mankind"},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:25.905626',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '1Uz3bpy_RyeBLcD5H4hzkA',
#    'updated_at': '2020-01-05 13:42:25.905626',
#    'url': 'https://api.chucknorris.io/jokes/1Uz3bpy_RyeBLcD5H4hzkA',
#    'value': 'Mr. T, Arnold Shcwarzzenger, and Chuck Norris are standing in front of God. God says to them,"I have call you three here because you are the greatest fighters in the world and I have a place for one of you at my right hand. You must prove to me whom of you it shall be." Mr. T steps and says "I pity the fool who doesn\'t let me sit at His right hand." God tells him that he was not good enough and sends Mr. T to hell. Arnold steps up and says "I was in predator, commando, the terminator. You must choose the governator." God tells him not good enough and sends Arnold to hell. God turns to Chuck Norris and say "Why should you sit beside me?" Chuck quickly proceeds to roundhouse kick God in the face and say "Bitch, your in my seat.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:26.194739',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '4JiABIF2Qxa3sU2eYiYg8w',
#    'updated_at': '2020-01-05 13:42:26.194739',
#    'url': 'https://api.chucknorris.io/jokes/4JiABIF2Qxa3sU2eYiYg8w',
#    'value': 'Chuck Norris\' licence plate reads "YOU\'RE GODDAMN RIGHT THIS IS THE BIGGEST AND LONGEST VANITY PLATE U EVA SEEN IN YOUR PATHETIC LIFE"'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:26.194739',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'v343ocCYRsSt_7g8ioePzA',
#    'updated_at': '2020-01-05 13:42:26.194739',
#    'url': 'https://api.chucknorris.io/jokes/v343ocCYRsSt_7g8ioePzA',
#    'value': 'When Chuck Norris cuts it Footloose, God help anyone within a three-mile radius.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:26.194739',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'DHr9wv48TbWEU_VULiYcvg',
#    'updated_at': '2020-01-05 13:42:26.194739',
#    'url': 'https://api.chucknorris.io/jokes/DHr9wv48TbWEU_VULiYcvg',
#    'value': 'The Father, Son, and Holy Ghost exist because Chuck Norris ripped God into three separate entities.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:26.194739',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'Z51v-Kg5Qveu6gLnoeGOpQ',
#    'updated_at': '2020-01-05 13:42:26.194739',
#    'url': 'https://api.chucknorris.io/jokes/Z51v-Kg5Qveu6gLnoeGOpQ',
#    'value': 'god created the world, because Chuck Norris let him'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:26.447675',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'kiK_COw5Q7aF1rPm8jVvEQ',
#    'updated_at': '2020-01-05 13:42:26.447675',
#    'url': 'https://api.chucknorris.io/jokes/kiK_COw5Q7aF1rPm8jVvEQ',
#    'value': 'When Chuck Norris kills you, you get a high-five from God.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:26.194739',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'K6Fw8PswRa-GJ_SfIv8HrQ',
#    'updated_at': '2020-01-05 13:42:26.194739',
#    'url': 'https://api.chucknorris.io/jokes/K6Fw8PswRa-GJ_SfIv8HrQ',
#    'value': 'God created the world in 7 days, Chuck Norris created the rest of the universe in one.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:26.447675',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'ytdg_SWOScigSheRyBWScg',
#    'updated_at': '2020-01-05 13:42:26.447675',
#    'url': 'https://api.chucknorris.io/jokes/ytdg_SWOScigSheRyBWScg',
#    'value': "Chuck Norris once counted to infinity- ininity times. For god's sake don't ask how that is possible."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:26.447675',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'qAuhskF_S92iXT2cIze08Q',
#    'updated_at': '2020-01-05 13:42:26.447675',
#    'url': 'https://api.chucknorris.io/jokes/qAuhskF_S92iXT2cIze08Q',
#    'value': "Yahweh strictly adheres to Chuck Norris' first commandment: having no other gods before him."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:26.447675',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '-CUZkT_fRFSAd9IbMq_iYQ',
#    'updated_at': '2020-01-05 13:42:26.447675',
#    'url': 'https://api.chucknorris.io/jokes/-CUZkT_fRFSAd9IbMq_iYQ',
#    'value': 'God said, "Let there be light!" to which Chuck Norris replied, "Shut the fuck up".'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:26.766831',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'HZSyXy5GS6i5dVtsNA9KWA',
#    'updated_at': '2020-01-05 13:42:26.766831',
#    'url': 'https://api.chucknorris.io/jokes/HZSyXy5GS6i5dVtsNA9KWA',
#    'value': 'When God said "let there be light", he first asked Chuck Norris if it was ok...'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:26.766831',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
# ...
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:28.420821',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'bk4ffpNHSLKVyfZ747pzWQ',
#    'updated_at': '2020-01-05 13:42:28.420821',
#    'url': 'https://api.chucknorris.io/jokes/bk4ffpNHSLKVyfZ747pzWQ',
#    'value': 'This is a web site for NEW AND ONLY NEW Chuck Norris Facts.If Chuck Norris finds out(and he will find out) you have posted one that you read or heard....Beg for Merciful God to take you and not Chuck Norris'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:28.664997',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'o3qCUVENRbG0kEiMzGojnQ',
#    'updated_at': '2020-01-05 13:42:28.664997',
#    'url': 'https://api.chucknorris.io/jokes/o3qCUVENRbG0kEiMzGojnQ',
#    'value': 'When the Bible said God made man in his own image, it did not mean all men. Just Chuck Norris.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:28.664997',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '_VBRL88ASyu1Z1mtpfQ0hA',
#    'updated_at': '2020-01-05 13:42:28.664997',
#    'url': 'https://api.chucknorris.io/jokes/_VBRL88ASyu1Z1mtpfQ0hA',
#    'value': 'DOTA: 1st kill- First Blood 2nd kill- Double Kill 3rd kill- Triple Kill 4th kill- Monster Kill 5th kill- god-like 6th kill- Beyond god-like 7th kill- Chuck Norris-like'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:28.984661',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'x-7AsA5NQsqCBejbbb8Ysw',
#    'updated_at': '2020-01-05 13:42:28.984661',
#    'url': 'https://api.chucknorris.io/jokes/x-7AsA5NQsqCBejbbb8Ysw',
#    'value': 'Chuck Norris is the only person to whom God has said," I did not know that!"'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:28.984661',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'S6Gh3HAZSDi_b6bqB_reSA',
#    'updated_at': '2020-01-05 13:42:28.984661',
#    'url': 'https://api.chucknorris.io/jokes/S6Gh3HAZSDi_b6bqB_reSA',
#    'value': "Chuck Norris is the inventor of the dreaded 'Big-Chuck-Butt-Fuck'. And may God help anyone subjected to it"},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:28.984661',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'PXOhzoVEQyquXqIalsF7mw',
#    'updated_at': '2020-01-05 13:42:28.984661',
#    'url': 'https://api.chucknorris.io/jokes/PXOhzoVEQyquXqIalsF7mw',
#    'value': "Only God is allowed to edit Chuck Norris' Wikipedia page."},
#   {'categories': ['explicit'],
#    'created_at': '2020-01-05 13:42:28.984661',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '8-xhj_T8QQmfqnTGNOON-w',
#    'updated_at': '2020-01-05 13:42:28.984661',
#    'url': 'https://api.chucknorris.io/jokes/8-xhj_T8QQmfqnTGNOON-w',
#    'value': 'when women r having sex with god they all scream out "Chuck Norris!!!"'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:28.984661',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'a5MKLZYKS3ePoggSd2YmTw',
#    'updated_at': '2020-01-05 13:42:28.984661',
#    'url': 'https://api.chucknorris.io/jokes/a5MKLZYKS3ePoggSd2YmTw',
#    'value': 'Cleanliness is next to godliness... and of course, godliness is nowhere near Chuck Norris-ness.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:29.296379',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'WU_TrLG6Ts-DrLefnFVivA',
#    'updated_at': '2020-01-05 13:42:29.296379',
#    'url': 'https://api.chucknorris.io/jokes/WU_TrLG6Ts-DrLefnFVivA',
#    'value': 'God said "Let there be light." Chuck Norris said, "Let there be God."'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:29.296379',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'YNyOFN7rT92WpfJqPPoqHw',
#    'updated_at': '2020-01-05 13:42:29.296379',
#    'url': 'https://api.chucknorris.io/jokes/YNyOFN7rT92WpfJqPPoqHw',
#    'value': "God stole Chuck Norris' job when he applied...God has been hiding ever since"},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:29.296379',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'SmSE4OsrSGmJ2wnxmHjrPQ',
#    'updated_at': '2020-01-05 13:42:29.296379',
#    'url': 'https://api.chucknorris.io/jokes/SmSE4OsrSGmJ2wnxmHjrPQ',
#    'value': "Chuck Norris doesn't believe in God, God believes in Chuck Norris."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:29.296379',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '3MJsZGFqQQGkMjcfmy5wQA',
#    'updated_at': '2020-01-05 13:42:29.296379',
#    'url': 'https://api.chucknorris.io/jokes/3MJsZGFqQQGkMjcfmy5wQA',
#    'value': "Chuck Norris once went into a church to ask God why Adam was created first instead of chuck. God's answer apparently was not to Chuck's liking, since no one has seen or heard from God sense..."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:29.569033',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'XoibRwgBS4mQkvTAdQEPkQ',
#    'updated_at': '2020-01-05 13:42:29.569033',
#    'url': 'https://api.chucknorris.io/jokes/XoibRwgBS4mQkvTAdQEPkQ',
#    'value': "Chuck Norris doesn't play God of War. He is the God of War."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:29.569033',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'uiJB1WShTr68KurA2CfMIg',
#    'updated_at': '2020-01-05 13:42:29.569033',
#    'url': 'https://api.chucknorris.io/jokes/uiJB1WShTr68KurA2CfMIg',
#    'value': "Chuck Norris made a set of boxing speed bags out of Abe Vigoda's earlobes."},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:29.569033',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'n1IlaSvCT0eE3Z-f_Qfb2Q',
#    'updated_at': '2020-01-05 13:42:29.569033',
#    'url': 'https://api.chucknorris.io/jokes/n1IlaSvCT0eE3Z-f_Qfb2Q',
#    'value': "If you ever hear that Chuck Norris has died, it's not true. He just went to heaven to show God how it's done. i.e. create the world in 2 days cos' he has better shit to do."},
#   {'categories': ['explicit'],
#    'created_at': '2020-01-05 13:42:29.855523',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '4ot5f_k2RzWfmAS2j8ZJbw',
#    'updated_at': '2020-01-05 13:42:29.855523',
#    'url': 'https://api.chucknorris.io/jokes/4ot5f_k2RzWfmAS2j8ZJbw',
#    'value': 'Chuck Norris is like God, sex and kung-fu put in a blender to create undiluted manliness.'},
#   {'categories': ['explicit'],
#    'created_at': '2020-01-05 13:42:29.855523',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'IQAFTYl7RLGc3xCB5QM2IA',
#    'updated_at': '2020-01-05 13:42:29.855523',
#    'url': 'https://api.chucknorris.io/jokes/IQAFTYl7RLGc3xCB5QM2IA',
#    'value': "On a recent survey form, Chuck Norris wrote his occupation as 'Chuck Norris', sex 'constantly' and pastimes 'Godliness, vigilance, and pimping'."},
#   {'categories': ['explicit'],
#    'created_at': '2020-01-05 13:42:29.855523',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'oI4rtgsSTFmi3u-6J42lBA',
#    'updated_at': '2020-01-05 13:42:29.855523',
#    'url': 'https://api.chucknorris.io/jokes/oI4rtgsSTFmi3u-6J42lBA',
#    'value': 'Justin Bieber, God and Chuck Norris are all on a tall building. Underneath is a very busy road. They all pull their trousers down to measure their dick size. Bieber had no dick, so he fell off. Norris started swinging, so God asked why. He replied "I am dodging traffic".'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.177068',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'K1KjBhDIRqSWh7e7iIJxdw',
#    'updated_at': '2020-01-05 13:42:30.177068',
#    'url': 'https://api.chucknorris.io/jokes/K1KjBhDIRqSWh7e7iIJxdw',
#    'value': 'Eminem Sings about a Tornado meeting a Volcano, However we all know this is what happened when Chuck Norris created god.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.177068',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '5XFMhaHxRJCzP8pOQxd2iQ',
#    'updated_at': '2020-01-05 13:42:30.177068',
#    'url': 'https://api.chucknorris.io/jokes/5XFMhaHxRJCzP8pOQxd2iQ',
#    'value': 'God create the earth and all living things.... But Chuck Norris created God'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.177068',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '1NMf3RwrRre-WfGfZvllhg',
#    'updated_at': '2020-01-05 13:42:30.177068',
#    'url': 'https://api.chucknorris.io/jokes/1NMf3RwrRre-WfGfZvllhg',
#    'value': 'all gods pray to Chuck Norris'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.177068',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'rg5eGKsLQyCLqjN05eBMhw',
#    'updated_at': '2020-01-05 13:42:30.177068',
#    'url': 'https://api.chucknorris.io/jokes/rg5eGKsLQyCLqjN05eBMhw',
#    'value': "did you see the movie godzilla he did'nt come to scare newyork he came to get away from Chuck Norris"},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.177068',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'iNIEl6YOSWSekWMJSv1BMQ',
#    'updated_at': '2020-01-05 13:42:30.177068',
#    'url': 'https://api.chucknorris.io/jokes/iNIEl6YOSWSekWMJSv1BMQ',
#    'value': 'god created jesus toencourage peace when that didnt work he created Chuck Norris to enforce it'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.177068',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'Po3KcO2oSCSJ0K39MZrLXQ',
#    'updated_at': '2020-01-05 13:42:30.177068',
#    'url': 'https://api.chucknorris.io/jokes/Po3KcO2oSCSJ0K39MZrLXQ',
#    'value': 'The high tide occurs when Chuck Norris flies over the beach. the rising water is where god pees his pants'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.480041',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'sQKP-r28Tdmfyw1JIvsMaA',
#    'updated_at': '2020-01-05 13:42:30.480041',
#    'url': 'https://api.chucknorris.io/jokes/sQKP-r28Tdmfyw1JIvsMaA',
#    'value': 'when god said let there be light,Chuck Norris said ill think about it'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.480041',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'TvF1bnaJTDeSD4dz8nU1Yw',
#    'updated_at': '2020-01-05 13:42:30.480041',
#    'url': 'https://api.chucknorris.io/jokes/TvF1bnaJTDeSD4dz8nU1Yw',
#    'value': 'if god named peter the rock for brave, the Chuck Norris named chris rock because he is dumbass'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.480041',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '7O8chne5RgqHx49A6AVwaQ',
#    'updated_at': '2020-01-05 13:42:30.480041',
#    'url': 'https://api.chucknorris.io/jokes/7O8chne5RgqHx49A6AVwaQ',
#    'value': 'Chuck Norris doent have to pray to the gods.the gods pray to Chuck Norris'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.480041',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'k1YTICGHTYqHDQmfIJEtvA',
#    'updated_at': '2020-01-05 13:42:30.480041',
#    'url': 'https://api.chucknorris.io/jokes/k1YTICGHTYqHDQmfIJEtvA',
#    'value': 'when Chuck Norris saw god it was like looking in the mirror'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.480041',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'xW2OyjYnSpaEtdoyVAobAQ',
#    'updated_at': '2020-01-05 13:42:30.480041',
#    'url': 'https://api.chucknorris.io/jokes/xW2OyjYnSpaEtdoyVAobAQ',
#    'value': 'God and satan go to the Chuck Norris church every sunday.'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.480041',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '99lGv1bgQouqTlR5zYZWDQ',
#    'updated_at': '2020-01-05 13:42:30.480041',
#    'url': 'https://api.chucknorris.io/jokes/99lGv1bgQouqTlR5zYZWDQ',
#    'value': "everyone hideson Chuck Norris's birthday even god"},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.480041',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '0A_ha_XxTLuEI62tIP4-UQ',
#    'updated_at': '2020-01-05 13:42:30.480041',
#    'url': 'https://api.chucknorris.io/jokes/0A_ha_XxTLuEI62tIP4-UQ',
#    'value': 'Chuck Norris can kill godzilla by saying roar'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.480041',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'lfGt46uqSo6TTRiv7sNmJg',
#    'updated_at': '2020-01-05 13:42:30.480041',
#    'url': 'https://api.chucknorris.io/jokes/lfGt46uqSo6TTRiv7sNmJg',
#    'value': 'god created jesus-Chuck Norris created god'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.480041',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'pKJ8JsW_SGyD_YIF7Y55WQ',
#    'updated_at': '2020-01-05 13:42:30.480041',
#    'url': 'https://api.chucknorris.io/jokes/pKJ8JsW_SGyD_YIF7Y55WQ',
#    'value': 'many people belive in god. god belives in Chuck Norris'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.480041',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'o-AgkKxESAiUqqLoq9pdEQ',
#    'updated_at': '2020-01-05 13:42:30.480041',
#    'url': 'https://api.chucknorris.io/jokes/o-AgkKxESAiUqqLoq9pdEQ',
#    'value': 'god said let there be light Chuck Norris said say please'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.480041',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': '8KbeOP8UQWuxZomPgCLt8w',
#    'updated_at': '2020-01-05 13:42:30.480041',
#    'url': 'https://api.chucknorris.io/jokes/8KbeOP8UQWuxZomPgCLt8w',
#    'value': 'we pray for god.god prays for Chuck Norris'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.480041',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'tq4A6oOsSpWoMVIuPnRztA',
#    'updated_at': '2020-01-05 13:42:30.480041',
#    'url': 'https://api.chucknorris.io/jokes/tq4A6oOsSpWoMVIuPnRztA',
#    'value': 'When god said let there be light Chuck Norris said say please'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.730109',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'gLL80CDpT0ebkYaBVIbWPw',
#    'updated_at': '2020-01-05 13:42:30.730109',
#    'url': 'https://api.chucknorris.io/jokes/gLL80CDpT0ebkYaBVIbWPw',
#    'value': 'When god create Chuck Norris, god not exist anymore'},
#   {'categories': [],
#    'created_at': '2020-01-05 13:42:30.730109',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'pmQfw_1bSLiay1YmznnMGA',
#    'updated_at': '2020-01-05 13:42:30.730109',
#    'url': 'https://api.chucknorris.io/jokes/pmQfw_1bSLiay1YmznnMGA',
#    'value': "God and Chuck Norris were once playing chess together. But then they got bored and Chuck thought of something called martial arts. thats why God always sends down people to earth instead of himself. guess he didn't love Jesus. huh."},
#   {'categories': ['money'],
#    'created_at': '2020-01-05 13:42:25.352697',
#    'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#    'id': 'XfTC9rAGS_GbP9OynxTbhQ',
#    'updated_at': '2020-05-22 06:16:41.133769',
#    'url': 'https://api.chucknorris.io/jokes/XfTC9rAGS_GbP9OynxTbhQ',
#    'value': 'Chuck Norris once beat up Godzilla for lunch money'}]}

# %% [markdown]
# # OpenStreetMap
#
# Overpass es una instancia pública que nos permite realizar consultas sin molestar a las instancias principales de OpenStreetMap.

# %%
# Amenities
# https://wiki.openstreetmap.org/wiki/Key:amenity
# (43.25580545097236, -2.922715389269332, 43.25639150538353, -2.9247538815364433);

overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json];
node["amenity"="cafe"]
  (40.420801, -3.694702,40.423754, -3.688167); 
out;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
print(response)
data = response.json()
# Out:
# <Response [200]>

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.62.1 084b4234',
#  'osm3s': {'timestamp_osm_base': '2024-06-03T06:57:13Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 2977298934,
#    'lat': 40.4210523,
#    'lon': -3.689841,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '4',
#     'addr:street': 'Calle de Villalar',
#     'amenity': 'cafe',
#     'cuisine': 'regional',
#     'internet_access': 'yes',
#     'name': 'Café Villalar',
#     'phone': '+34 914358937',
#     'website': 'https://cafeteriavillalar.eatbu.com/'}},
#   {'type': 'node',
#    'id': 3426617375,
#    'lat': 40.4221948,
#    'lon': -3.6923421,
#    'tags': {'amenity': 'cafe',
#     'name': 'Gran Café Gijón',
#     'phone': '+34 915 215 425',
#     'website': 'https://cafegijon.com/',
#     'wikidata': 'Q1025608',
#     'wikipedia': 'es:Café Gijón'}},
#   {'type': 'node',
#    'id': 4703448419,
#    'lat': 40.4229908,
#    'lon': -3.6936524,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '6',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Marqués de Monasterio',
#     'amenity': 'cafe',
#     'contact:facebook': 'https://www.facebook.com/hermanasae',
#     'contact:instagram': 'https://www.instagram.com/hermanasarce/',
#     'cuisine': 'cake',
#     'disused:amenity': 'restaurant',
#     'name': 'Hermanas Arce',
#     'old_name': 'Noteolvides',
#     'opening_hours': 'Tu-Fr 09:00-17:00; Sa 09:30-17:30'}},
#   {'type': 'node',
#    'id': 4778747544,
#    'lat': 40.4223247,
#    'lon': -3.6909735,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '1',
#     'addr:postcode': '28001',
#     'addr:street': 'Calle de Recoletos',
#     'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'contact:phone': '+34 914319000',
#     'contact:website': 'https://www.santagloria.com',
#     'name': 'Santagloria',
#     'shop': 'bakery'}},
#   {'type': 'node',
#    'id': 9207850217,
#    'lat': 40.4218751,
#    'lon': -3.6901227,
#    'tags': {'amenity': 'cafe', 'name': 'masticar'}}]}

# %%
data.keys()
# Out:
# dict_keys(['version', 'generator', 'osm3s', 'elements'])

# %%
data['osm3s']
# Out:
# {'timestamp_osm_base': '2024-06-03T16:45:31Z',
#  'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'}

# %%
data.get('osm3s')
# Out:
# {'timestamp_osm_base': '2024-06-03T16:45:31Z',
#  'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'}

# %%
data['osm3s']['copyright']
# Out:
# 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'

# %%
data.get("elements")[2]
# Out:
# {'type': 'node',
#  'id': 4703448419,
#  'lat': 40.4229908,
#  'lon': -3.6936524,
#  'tags': {'addr:city': 'Madrid',
#   'addr:housenumber': '6',
#   'addr:postcode': '28004',
#   'addr:street': 'Calle del Marqués de Monasterio',
#   'amenity': 'cafe',
#   'contact:facebook': 'https://www.facebook.com/hermanasae',
#   'contact:instagram': 'https://www.instagram.com/hermanasarce/',
#   'cuisine': 'cake',
#   'disused:amenity': 'restaurant',
#   'name': 'Hermanas Arce',
#   'old_name': 'Noteolvides',
#   'opening_hours': 'Tu-Fr 09:00-17:00; Sa 09:30-17:30'}}

# %%
data.get("elements")[0]['tags']['addr:street'] + " " + data.get("elements")[0]['tags']['addr:housenumber']
# Out:
# 'Calle de Villalar 4'

# %%
for element in data['elements']:
    print(element)
# Out:
# {'type': 'node', 'id': 2977298934, 'lat': 40.4210523, 'lon': -3.689841, 'tags': {'addr:city': 'Madrid', 'addr:housenumber': '4', 'addr:street': 'Calle de Villalar', 'amenity': 'cafe', 'cuisine': 'regional', 'internet_access': 'yes', 'name': 'Café Villalar', 'phone': '+34 914358937', 'website': 'https://cafeteriavillalar.eatbu.com/'}}
# {'type': 'node', 'id': 3426617375, 'lat': 40.4221948, 'lon': -3.6923421, 'tags': {'amenity': 'cafe', 'name': 'Gran Café Gijón', 'phone': '+34 915 215 425', 'website': 'https://cafegijon.com/', 'wikidata': 'Q1025608', 'wikipedia': 'es:Café Gijón'}}
# {'type': 'node', 'id': 4703448419, 'lat': 40.4229908, 'lon': -3.6936524, 'tags': {'addr:city': 'Madrid', 'addr:housenumber': '6', 'addr:postcode': '28004', 'addr:street': 'Calle del Marqués de Monasterio', 'amenity': 'cafe', 'contact:facebook': 'https://www.facebook.com/hermanasae', 'contact:instagram': 'https://www.instagram.com/hermanasarce/', 'cuisine': 'cake', 'disused:amenity': 'restaurant', 'name': 'Hermanas Arce', 'old_name': 'Noteolvides', 'opening_hours': 'Tu-Fr 09:00-17:00; Sa 09:30-17:30'}}
# {'type': 'node', 'id': 4778747544, 'lat': 40.4223247, 'lon': -3.6909735, 'tags': {'addr:city': 'Madrid', 'addr:housenumber': '1', 'addr:postcode': '28001', 'addr:street': 'Calle de Recoletos', 'amenity': 'cafe', 'brand': 'Santagloria', 'brand:wikidata': 'Q54606497', 'contact:phone': '+34 914319000', 'contact:website': 'https://www.santagloria.com', 'name': 'Santagloria', 'shop': 'bakery'}}
# {'type': 'node', 'id': 9207850217, 'lat': 40.4218751, 'lon': -3.6901227, 'tags': {'amenity': 'cafe', 'name': 'masticar'}}

# %%
data['elements']
# Out:
# [{'type': 'node',
#   'id': 2977298934,
#   'lat': 40.4210523,
#   'lon': -3.689841,
#   'tags': {'addr:city': 'Madrid',
#    'addr:housenumber': '4',
#    'addr:street': 'Calle de Villalar',
#    'amenity': 'cafe',
#    'cuisine': 'regional',
#    'internet_access': 'yes',
#    'name': 'Café Villalar',
#    'phone': '+34 914358937',
#    'website': 'https://cafeteriavillalar.eatbu.com/'}},
#  {'type': 'node',
#   'id': 3426617375,
#   'lat': 40.4221948,
#   'lon': -3.6923421,
#   'tags': {'amenity': 'cafe',
#    'name': 'Gran Café Gijón',
#    'phone': '+34 915 215 425',
#    'website': 'https://cafegijon.com/',
#    'wikidata': 'Q1025608',
#    'wikipedia': 'es:Café Gijón'}},
#  {'type': 'node',
#   'id': 4703448419,
#   'lat': 40.4229908,
#   'lon': -3.6936524,
#   'tags': {'addr:city': 'Madrid',
#    'addr:housenumber': '6',
#    'addr:postcode': '28004',
#    'addr:street': 'Calle del Marqués de Monasterio',
#    'amenity': 'cafe',
#    'contact:facebook': 'https://www.facebook.com/hermanasae',
#    'contact:instagram': 'https://www.instagram.com/hermanasarce/',
#    'cuisine': 'cake',
#    'disused:amenity': 'restaurant',
#    'name': 'Hermanas Arce',
#    'old_name': 'Noteolvides',
#    'opening_hours': 'Tu-Fr 09:00-17:00; Sa 09:30-17:30'}},
#  {'type': 'node',
#   'id': 4778747544,
#   'lat': 40.4223247,
#   'lon': -3.6909735,
#   'tags': {'addr:city': 'Madrid',
#    'addr:housenumber': '1',
#    'addr:postcode': '28001',
#    'addr:street': 'Calle de Recoletos',
#    'amenity': 'cafe',
#    'brand': 'Santagloria',
#    'brand:wikidata': 'Q54606497',
#    'contact:phone': '+34 914319000',
#    'contact:website': 'https://www.santagloria.com',
#    'name': 'Santagloria',
#    'shop': 'bakery'}},
#  {'type': 'node',
#   'id': 9207850217,
#   'lat': 40.4218751,
#   'lon': -3.6901227,
#   'tags': {'amenity': 'cafe', 'name': 'masticar'}}]

# %%
data['elements']
# Out:
# [{'type': 'node',
#   'id': 2977298934,
#   'lat': 40.4210523,
#   'lon': -3.689841,
#   'tags': {'addr:city': 'Madrid',
#    'addr:housenumber': '4',
#    'addr:street': 'Calle de Villalar',
#    'amenity': 'cafe',
#    'cuisine': 'regional',
#    'internet_access': 'yes',
#    'name': 'Café Villalar',
#    'phone': '+34 914358937',
#    'website': 'https://cafeteriavillalar.eatbu.com/'}},
#  {'type': 'node',
#   'id': 3426617375,
#   'lat': 40.4221948,
#   'lon': -3.6923421,
#   'tags': {'amenity': 'cafe',
#    'name': 'Gran Café Gijón',
#    'phone': '+34 915 215 425',
#    'website': 'https://cafegijon.com/',
#    'wikidata': 'Q1025608',
#    'wikipedia': 'es:Café Gijón'}},
#  {'type': 'node',
#   'id': 4703448419,
#   'lat': 40.4229908,
#   'lon': -3.6936524,
#   'tags': {'addr:city': 'Madrid',
#    'addr:housenumber': '6',
#    'addr:postcode': '28004',
#    'addr:street': 'Calle del Marqués de Monasterio',
#    'amenity': 'cafe',
#    'contact:facebook': 'https://www.facebook.com/hermanasae',
#    'contact:instagram': 'https://www.instagram.com/hermanasarce/',
#    'cuisine': 'cake',
#    'disused:amenity': 'restaurant',
#    'name': 'Hermanas Arce',
#    'old_name': 'Noteolvides',
#    'opening_hours': 'Tu-Fr 09:00-17:00; Sa 09:30-17:30'}},
#  {'type': 'node',
#   'id': 4778747544,
#   'lat': 40.4223247,
#   'lon': -3.6909735,
#   'tags': {'addr:city': 'Madrid',
#    'addr:housenumber': '1',
#    'addr:postcode': '28001',
#    'addr:street': 'Calle de Recoletos',
#    'amenity': 'cafe',
#    'brand': 'Santagloria',
#    'brand:wikidata': 'Q54606497',
#    'contact:phone': '+34 914319000',
#    'contact:website': 'https://www.santagloria.com',
#    'name': 'Santagloria',
#    'shop': 'bakery'}},
#  {'type': 'node',
#   'id': 9207850217,
#   'lat': 40.4218751,
#   'lon': -3.6901227,
#   'tags': {'amenity': 'cafe', 'name': 'masticar'}}]

# %%
data['elements'][2]['tags']
# Out:
# {'addr:city': 'Madrid',
#  'addr:housenumber': '6',
#  'addr:postcode': '28004',
#  'addr:street': 'Calle del Marqués de Monasterio',
#  'amenity': 'cafe',
#  'contact:facebook': 'https://www.facebook.com/hermanasae',
#  'contact:instagram': 'https://www.instagram.com/hermanasarce/',
#  'cuisine': 'cake',
#  'disused:amenity': 'restaurant',
#  'name': 'Hermanas Arce',
#  'old_name': 'Noteolvides',
#  'opening_hours': 'Tu-Fr 09:00-17:00; Sa 09:30-17:30'}

# %%
data['elements'][1]
# Out:
# {'type': 'node',
#  'id': 3426617375,
#  'lat': 40.4221948,
#  'lon': -3.6923421,
#  'tags': {'amenity': 'cafe',
#   'name': 'Gran Café Gijón',
#   'phone': '+34 915 215 425',
#   'website': 'https://cafegijon.com/',
#   'wikidata': 'Q1025608',
#   'wikipedia': 'es:Café Gijón'}}

# %%
pd.DataFrame(data['elements'])
# Out:
#    type          id        lat       lon  \
# 0  node  2977298934  40.421052 -3.689841
# 1  node  3426617375  40.422195 -3.692342
# 2  node  4703448419  40.422991 -3.693652
# 3  node  4778747544  40.422325 -3.690974
# 4  node  9207850217  40.421875 -3.690123
#
#                                                 tags
# 0  {'addr:city': 'Madrid', 'addr:housenumber': '4...
# 1  {'amenity': 'cafe', 'name': 'Gran Café Gijón',...
# 2  {'addr:city': 'Madrid', 'addr:housenumber': '6...
# 3  {'addr:city': 'Madrid', 'addr:housenumber': '1...
# 4            {'amenity': 'cafe', 'name': 'masticar'}

# %%
def json_to_dataframe(data_entrada):
    elements = data_entrada['elements']
    places = {'lat': [], 'lon': [], 'name': [], 'address': []}

    for i in elements:
        lalitude = i['lat']
        longitude = i['lon']
        name = i['tags'].get('name')
        street = i['tags'].get('addr:street', 'Sin calle')
        number = i['tags'].get('addr:housenumber', 0)
        
        places['lat'].append(lalitude)
        places['lon'].append(longitude)
        places['name'].append(name)
        places['address'].append(str(street) + ' ' + str(number))

    df = pd.DataFrame(places)
    return df

# %%
data['elements'][1]['tags']
# Out:
# {'amenity': 'cafe',
#  'name': 'Gran Café Gijón',
#  'phone': '+34 915 215 425',
#  'website': 'https://cafegijon.com/',
#  'wikidata': 'Q1025608',
#  'wikipedia': 'es:Café Gijón'}

# %%
df_return = json_to_dataframe(data)
df_return.head()
# Out:
#          lat       lon             name                            address
# 0  40.421052 -3.689841    Café Villalar                Calle de Villalar 4
# 1  40.422195 -3.692342  Gran Café Gijón                        Sin calle 0
# 2  40.422991 -3.693652    Hermanas Arce  Calle del Marqués de Monasterio 6
# 3  40.422325 -3.690974      Santagloria               Calle de Recoletos 1
# 4  40.421875 -3.690123         masticar                        Sin calle 0

# %% [markdown]
# ## Datos del espacio

# %%
'''
https://thespacedevs.com/llapi
https://ll.thespacedevs.com/2.2.0/swagger
'''
space_url = "http://ll.thespacedevs.com/2.2.0"

path = "/astronaut"

url_total = space_url + path

response = requests.get(url_total)

# %%
print(response.status_code)
type(response.content)
response.json()
# Out:
# 200
# {'count': 766,
#  'next': 'https://ll.thespacedevs.com/2.2.0/astronaut/?limit=10&offset=10',
#  'previous': None,
#  'results': [{'id': 1,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/1/',
#    'name': 'Thomas Pesquet',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P396DT11H33M45S',
#    'eva_time': 'P1DT15H54M',
#    'age': 46,
#    'date_of_birth': '1978-02-27',
#    'date_of_death': None,
#    'nationality': 'French',
#    'bio': 'Thomas Gautier Pesquet is a French aerospace engineer, pilot, and European Space Agency astronaut. Pesquet was selected by ESA as a candidate in May 2009, and he successfully completed his basic training in November 2010. From November 2016 to June 2017, Pesquet was part of Expeditions 50 and 51 on the International Space Station as a flight engineer.',
#    'twitter': 'https://twitter.com/Thom_astro',
#    'instagram': 'https://instagram.com/thom_astro',
#    'wiki': 'https://en.wikipedia.org/wiki/Thomas_Pesquet',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'FRA,ITA,DEU,ESP,CHE,GBR,AUT,SWE,BEL,PRT,NLD,HUN,POL,DNK,CZE,ROU,NOR,FIN,GRC,EST,IRL,LUX',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/thomas2520pesquet_image_20200102120546.jpeg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190357.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 6,
#    'last_flight': '2021-04-23T09:49:02Z',
#    'first_flight': '2016-11-17T20:20:13Z'},
#   {'id': 2,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/2/',
#    'name': 'Claude Nicollier',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P42DT12H3M12S',
#    'eva_time': 'PT8H10M',
#    'age': 79,
#    'date_of_birth': '1944-09-02',
#    'date_of_death': None,
#    'nationality': 'Swiss',
#    'bio': 'Claude Nicollier is the first astronaut from Switzerland. He has flown on four Space Shuttle missions. His first spaceflight (STS-46) was in 1992, and his final spaceflight (STS-103) was in 1999. He took part in two servicing missions to the Hubble Space Telescope (called STS-61 and STS-103). During his final spaceflight he participated in a spacewalk, becoming the first European Space Agency astronaut to do so during a Space Shuttle mission. In 2000 he was assigned to the Astronaut Office Extravehicular Activity Branch, while maintaining a position as Lead ESA Astronaut in Houston. Nicollier retired from ESA in April 2007.',
#    'twitter': 'https://twitter.com/Astroclaude',
#    'instagram': None,
#    'wiki': 'https://en.wikipedia.org/wiki/Claude_Nicollier',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'FRA,ITA,DEU,ESP,CHE,GBR,AUT,SWE,BEL,PRT,NLD,HUN,POL,DNK,CZE,ROU,NOR,FIN,GRC,EST,IRL,LUX',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/claude2520nicollier_image_20181127203218.jpg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185551.jpeg',
#    'flights_count': 4,
#    'landings_count': 4,
#    'spacewalks_count': 1,
#    'last_flight': '1999-12-20T00:50:00Z',
#    'first_flight': '1992-07-31T13:56:48Z'},
#   {'id': 3,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/3/',
#    'name': 'Tim Peake',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P185DT22H11M51S',
#    'eva_time': 'PT4H43M',
#    'age': 52,
#    'date_of_birth': '1972-04-07',
#    'date_of_death': None,
#    'nationality': 'British',
#    'bio': "Major Timothy Nigel Peake CMG is a British Army Air Corps officer, former European Space Agency astronaut and International Space Station (ISS) crew member.  He is the first British ESA astronaut, the second astronaut to bear a flag of the United Kingdom patch, the sixth person born in the United Kingdom to go on board the International Space Station and the seventh UK-born person in space. He began the ESA's intensive astronaut basic training course in September 2009 and graduated on 22 November 2010",
#    'twitter': 'https://twitter.com/astro_timpeake',
#    'instagram': 'https://www.instagram.com/astro_timpeake/',
#    'wiki': 'https://en.wikipedia.org/wiki/Tim_Peake',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'FRA,ITA,DEU,ESP,CHE,GBR,AUT,SWE,BEL,PRT,NLD,HUN,POL,DNK,CZE,ROU,NOR,FIN,GRC,EST,IRL,LUX',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/tim_peake_image_20230120154350.jpg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185843.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 1,
#    'last_flight': '2015-12-15T11:03:09Z',
#    'first_flight': '2015-12-15T11:03:09Z'},
#   {'id': 4,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/4/',
#    'name': 'Buzz Aldrin',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P12DT1H52M27S',
#    'eva_time': 'PT8H1M40S',
#    'age': 94,
#    'date_of_birth': '1930-01-20',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Buzz Aldrin; born Edwin Eugene Aldrin Jr.; is an American engineer, former astronaut, and fighter pilot.\r\nAs Lunar Module Pilot on the Apollo 11 mission, he and mission commander Neil Armstrong were the first two humans to land on the Moon.',
#    'twitter': 'https://twitter.com/TheRealBuzz',
#    'instagram': 'https://www.instagram.com/drbuzzaldrin/',
#    'wiki': 'https://en.wikipedia.org/wiki/Buzz_Aldrin',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Administrator: Bill Nelson',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/buzz_aldrin_image_20220911034547.jpeg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185225.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 4,
#    'last_flight': '1969-07-16T13:32:00Z',
#    'first_flight': '1966-11-11T20:46:33Z'},
#   {'id': 5,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/5/',
#    'name': 'Chris Hadfield',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P165DT16H19M',
#    'eva_time': 'PT14H50M',
#    'age': 64,
#    'date_of_birth': '1959-08-29',
#    'date_of_death': None,
#    'nationality': 'Canadian',
#    'bio': 'Chris Austin Hadfield is a Canadian retired astronaut, engineer, and former Royal Canadian Air Force fighter pilot.\r\nThe first Canadian to walk in space, Hadfield has flown two space shuttle missions and served as commander of the International Space Station.',
#    'twitter': 'https://twitter.com/Cmdr_Hadfield',
#    'instagram': 'https://www.instagram.com/colchrishadfield/',
#    'wiki': 'https://en.wikipedia.org/wiki/Chris_Hadfield',
#    'agency': {'id': 16,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/16/',
#     'name': 'Canadian Space Agency',
#     'featured': False,
#     'type': 'Government',
#     'country_code': 'CAN',
#     'abbrev': 'CSA',
#     'description': 'The Canadian Space Agency was established by the Canadian Space Agency Act which received Royal Assent on May 10, 1990. \r\n\r\nThe Canadian space program is administered by the Canadian Space Agency. Canada has contributed technology, expertise and personnel to the world space effort, especially in collaboration with ESA and NASA. In addition to its astronauts and satellites, some of the most notable Canadian technological contributions to space exploration include the Canadarm on the Space Shuttle and Canadarm2 on the International Space Station.',
#     'administrator': 'President: Lisa Campbell',
#     'founding_year': '1990',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/canadian2520space2520agency_logo_20231122160211.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/chris_hadfield_image_20220911034200.jpeg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190208.jpeg',
#    'flights_count': 3,
#    'landings_count': 3,
#    'spacewalks_count': 2,
#    'last_flight': '2012-12-19T12:12:35Z',
#    'first_flight': '1995-11-12T12:30:43Z'},
#   {'id': 6,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/6/',
#    'name': 'David Saint-Jacques',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P203DT12H28M8S',
#    'eva_time': 'PT6H29M',
#    'age': 54,
#    'date_of_birth': '1970-01-06',
#    'date_of_death': None,
#    'nationality': 'Canadian',
#    'bio': 'David Saint-Jacques is a Canadian astronaut with the Canadian Space Agency (CSA).\r\nHe was also an engineer, an astrophysicist, and a physician prior to joining the CSA.\r\nHe was selected to join the CSA in the 2009 CSA selection along with Jeremy Hansen.',
#    'twitter': 'https://twitter.com/Astro_DavidS',
#    'instagram': 'https://www.instagram.com/astrodavids/',
#    'wiki': 'https://en.wikipedia.org/wiki/David_Saint-Jacques',
#    'agency': {'id': 16,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/16/',
#     'name': 'Canadian Space Agency',
#     'featured': False,
#     'type': 'Government',
#     'country_code': 'CAN',
#     'abbrev': 'CSA',
#     'description': 'The Canadian Space Agency was established by the Canadian Space Agency Act which received Royal Assent on May 10, 1990. \r\n\r\nThe Canadian space program is administered by the Canadian Space Agency. Canada has contributed technology, expertise and personnel to the world space effort, especially in collaboration with ESA and NASA. In addition to its astronauts and satellites, some of the most notable Canadian technological contributions to space exploration include the Canadarm on the Space Shuttle and Canadarm2 on the International Space Station.',
#     'administrator': 'President: Lisa Campbell',
#     'founding_year': '1990',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/canadian2520space2520agency_logo_20231122160211.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/david_saint-jac_image_20220911034207.jpeg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305191004.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 1,
#    'last_flight': '2018-12-03T11:31:52Z',
#    'first_flight': '2018-12-03T11:31:52Z'},
#   {'id': 7,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/7/',
#    'name': 'Anne McClain',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P203DT12H28M8S',
#    'eva_time': 'PT13H8M',
#    'age': 44,
#    'date_of_birth': '1979-06-07',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Anne Charlotte McClain is a lieutenant colonel in the U.S. Army currently assigned to NASA Astronaut Group 21.',
#    'twitter': 'https://twitter.com/AstroAnnimal',
#    'instagram': None,
#    'wiki': 'https://en.wikipedia.org/wiki/Anne_McClain',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Administrator: Bill Nelson',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/anne2520mcclain_image_20181127210625.jpg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185442.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 2,
#    'last_flight': '2018-12-03T11:31:52Z',
#    'first_flight': '2018-12-03T11:31:52Z'},
#   {'id': 8,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/8/',
#    'name': 'Andrew R. Morgan',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P271DT12H48M22S',
#    'eva_time': 'P1DT21H48M',
#    'age': 48,
#    'date_of_birth': '1976-02-05',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Andrew Richard "Drew" Morgan is a NASA astronaut from the class of 2013.',
#    'twitter': 'https://twitter.com/AstroDrewMorgan',
#    'instagram': 'https://www.instagram.com/astrodrewmorgan/',
#    'wiki': 'https://en.wikipedia.org/wiki/Andrew_R._Morgan',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Administrator: Bill Nelson',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/andrew_r._morga_image_20220911034204.jpeg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185549.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 7,
#    'last_flight': '2019-07-20T16:28:21Z',
#    'first_flight': '2019-07-20T16:28:21Z'},
#   {'id': 9,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/9/',
#    'name': 'Nick Hague',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P202DT16H3M37S',
#    'eva_time': 'PT19H56M',
#    'age': 48,
#    'date_of_birth': '1975-09-24',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Tyler Nicklaus Hague is an American Flight Test Engineer and a NASA astronaut of the class of 2013.\r\nSelected to be a flight engineer of Expedition 57 / 58 to the International Space Station, he launched on board Soyuz MS-10, which aborted shortly after launch on October 11, 2018.',
#    'twitter': 'https://twitter.com/AstroHague',
#    'instagram': 'https://www.instagram.com/astrohague/',
#    'wiki': 'https://en.wikipedia.org/wiki/Nick_Hague',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Administrator: Bill Nelson',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/nick_hague_image_20220911034312.jpeg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190648.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 3,
#    'last_flight': '2019-03-14T19:14:08Z',
#    'first_flight': '2018-10-11T08:40:15Z'},
#   {'id': 10,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/10/',
#    'name': 'Terry W. Virts',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P213DT10H50M46S',
#    'eva_time': 'PT19H2M',
#    'age': 56,
#    'date_of_birth': '1967-12-01',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Terry W. Virts Jr. is a former NASA astronaut, and Colonel in the United States Air Force.',
#    'twitter': 'https://twitter.com/AstroTerry',
#    'instagram': 'https://www.instagram.com/astro_terry/',
#    'wiki': 'https://en.wikipedia.org/wiki/Terry_W._Virts',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Administrator: Bill Nelson',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/terry_w._virts_image_20220911033815.jpeg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190900.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 3,
#    'last_flight': '2014-11-23T21:01:14Z',
#    'first_flight': '2010-02-08T09:14:00Z'}]}

# %%
url_total
# Out:
# 'http://ll.thespacedevs.com/2.2.0/astronaut'

# %%
url_total = space_url + path + "/?nationality=Spanish"

response_sp = requests.get(url_total)

# %%
response_sp
# Out:
# <Response [200]>

# %%
url_total
# Out:
# 'http://ll.thespacedevs.com/2.2.0/astronaut/?nationality=Spanish'

# %%
response_sp.json()
# Out:
# {'count': 2,
#  'next': None,
#  'previous': None,
#  'results': [{'id': 95,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/95/',
#    'name': 'Pedro Duque',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P18DT18H46M23S',
#    'eva_time': 'P0D',
#    'age': 61,
#    'date_of_birth': '1963-03-14',
#    'date_of_death': None,
#    'nationality': 'Spanish',
#    'bio': "Pedro Francisco Duque Duque, OF, OMSE (Madrid, 14 March 1963) is a Spanish astronaut and aeronautics engineer, currently serving as Spain's Minister of Science, Innovation and Universities. He was the first Spanish astronaut.\r\n\r\nDuque underwent training in both Russia and the United States. His first spaceflight was as a mission specialist aboard space shuttle mission STS-95, during which Duque supervised ESA experimental modules. In October 2003, Duque visited the International Space Station on board of a Soyuz TMA Ship for several days during a crew changeover. The scientific program of this visit was called by ESA/Spain Misión Cervantes.",
#    'twitter': None,
#    'instagram': None,
#    'wiki': 'https://en.wikipedia.org/wiki/Pedro_Duque',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'FRA,ITA,DEU,ESP,CHE,GBR,AUT,SWE,BEL,PRT,NLD,HUN,POL,DNK,CZE,ROU,NOR,FIN,GRC,EST,IRL,LUX',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/pedro2520duque_image_20181128225634.jpg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185757.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 0,
#    'last_flight': '2003-10-18T05:38:03Z',
#    'first_flight': '1998-10-29T19:19:34Z'},
#   {'id': 748,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/748/',
#    'name': 'Pablo Álvarez Fernández',
#    'status': {'id': 3, 'name': 'In-Training'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P0D',
#    'eva_time': 'P0D',
#    'age': None,
#    'date_of_birth': None,
#    'date_of_death': None,
#    'nationality': 'Spanish',
#    'bio': "Pablo holds a bachelor's degree in aeronautical engineering from the University of León (Universidad de León), Spain, and graduated with a master’s degree in aerospace engineering from the Warsaw University of Technology (Politechnika Warszawska) in 2011.\r\nAfter graduating university, Pablo was working as a structural engineer for several aircraft programmes, such as for Airbus and Safran in Spain, the UK and France between 2011 and 2017.\r\nFrom 2017 to 2020, while working as an ExoMars rover mechanical architect at Airbus Defence and Space in the UK, his responsibilities included the development of the radiosotope heater unit integration procedure in conjunction with Russian Space Agency ROSCOSMOS and ESA, as well as being a test director during the environmental test campaign.",
#    'twitter': None,
#    'instagram': None,
#    'wiki': None,
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'FRA,ITA,DEU,ESP,CHE,GBR,AUT,SWE,BEL,PRT,NLD,HUN,POL,DNK,CZE,ROU,NOR,FIN,GRC,EST,IRL,LUX',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/pablo_25c3258_image_20221123151230.jpg',
#    'profile_image_thumbnail': 'https://spacelaunchnow-prod-east.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185348.jpeg',
#    'flights_count': 0,
#    'landings_count': 0,
#    'spacewalks_count': 0,
#    'last_flight': None,
#    'first_flight': None}]}

# %%
pd.DataFrame(response_sp.json()['results'])
# Out:
#     id                                               url              name  \
# 0   86   https://ll.thespacedevs.com/2.2.0/astronaut/86/         Chen Dong
# 1  152  https://ll.thespacedevs.com/2.2.0/astronaut/152/      Rick Husband
# 2  185  https://ll.thespacedevs.com/2.2.0/astronaut/185/          Liu Yang
# 3  565  https://ll.thespacedevs.com/2.2.0/astronaut/565/   Kathleen Rubins
# 4  635  https://ll.thespacedevs.com/2.2.0/astronaut/635/    Christina Koch
# 5  648  https://ll.thespacedevs.com/2.2.0/astronaut/648/  Joseph A. Walker
# 6  710  https://ll.thespacedevs.com/2.2.0/astronaut/710/      Luke Delaney
#
#                                 status                             type  \
# 0          {'id': 1, 'name': 'Active'}  {'id': 2, 'name': 'Government'}
# 1  {'id': 4, 'name': 'Lost In Flight'}  {'id': 2, 'name': 'Government'}
# 2          {'id': 1, 'name': 'Active'}  {'id': 2, 'name': 'Government'}
# 3          {'id': 1, 'name': 'Active'}  {'id': 2, 'name': 'Government'}
# 4          {'id': 1, 'name': 'Active'}  {'id': 2, 'name': 'Government'}
# 5       {'id': 11, 'name': 'Deceased'}  {'id': 2, 'name': 'Government'}
# 6     {'id': 3, 'name': 'In-Training'}  {'id': 2, 'name': 'Government'}
#
#    in_space    time_in_space    eva_time  age date_of_birth  ...  \
# 0     False  P214DT15H54M19S    PT15H53M   45    1978-12-12  ...
# 1     False   P25DT17H32M18S         P0D   45    1957-07-12  ...
# 2     False     P195DT49M42S      PT6H7M   45    1978-10-06  ...
# 3     False   P300DT1H31M56S    P1DT3H3M   45    1978-10-14  ...
# 4     False  P328DT13H58M37S  P1DT18H15M   45    1979-01-29  ...
# 5     False       PT2H32M32S         P0D   45    1921-02-20  ...
# 6     False              P0D         P0D   45    1979-01-01  ...
#
#                                     instagram  \
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4  https://www.instagram.com/Astro_Christina/
# 5                                        None
# 6                                        None
#
#                                                 wiki  \
# 0  https://en.wikipedia.org/wiki/Chen_Dong_(astro...
# 1         https://en.wikipedia.org/wiki/Rick_Husband
# 2  https://en.wikipedia.org/wiki/Liu_Yang_(astron...
# 3      https://en.wikipedia.org/wiki/Kathleen_Rubins
# 4       https://en.wikipedia.org/wiki/Christina_Koch
# 5     https://en.wikipedia.org/wiki/Joseph_A._Walker
# 6  https://en.wikipedia.org/wiki/Luke_Delaney_(as...
#
#                                               agency  \
# 0  {'id': 17, 'url': 'https://ll.thespacedevs.com...
# 1  {'id': 44, 'url': 'https://ll.thespacedevs.com...
# 2  {'id': 17, 'url': 'https://ll.thespacedevs.com...
# 3  {'id': 44, 'url': 'https://ll.thespacedevs.com...
# 4  {'id': 44, 'url': 'https://ll.thespacedevs.com...
# 5  {'id': 44, 'url': 'https://ll.thespacedevs.com...
# 6  {'id': 44, 'url': 'https://ll.thespacedevs.com...
#
#                                        profile_image  \
# 0  https://spacelaunchnow-prod-east.nyc3.digitalo...
# 1  https://spacelaunchnow-prod-east.nyc3.digitalo...
# 2  https://spacelaunchnow-prod-east.nyc3.digitalo...
# 3  https://spacelaunchnow-prod-east.nyc3.digitalo...
# 4  https://spacelaunchnow-prod-east.nyc3.digitalo...
# 5  https://spacelaunchnow-prod-east.nyc3.digitalo...
# 6  https://spacelaunchnow-prod-east.nyc3.digitalo...
#
#                              profile_image_thumbnail flights_count  \
# 0  https://spacelaunchnow-prod-east.nyc3.digitalo...             2
# 1  https://spacelaunchnow-prod-east.nyc3.digitalo...             2
# 2  https://spacelaunchnow-prod-east.nyc3.digitalo...             2
# 3  https://spacelaunchnow-prod-east.nyc3.digitalo...             2
# 4  https://spacelaunchnow-prod-east.nyc3.digitalo...             1
# 5  https://spacelaunchnow-prod-east.nyc3.digitalo...             3
# 6  https://spacelaunchnow-prod-east.nyc3.digitalo...             0
#
#   landings_count spacewalks_count           last_flight          first_flight
# 0              2                3  2022-06-05T02:44:10Z  2016-10-16T23:30:31Z
# 1              2                0  2003-01-16T15:39:00Z  1999-05-27T10:49:42Z
# 2              2                1  2022-06-05T02:44:10Z  2012-06-16T10:37:24Z
# 3              2                4  2020-10-14T05:45:04Z  2016-07-07T01:36:00Z
# 4              1                6  2019-03-14T19:14:08Z  2019-03-14T19:14:08Z
# 5              3                0  1963-08-22T18:05:57Z  1963-01-17T16:59:00Z
# 6              0                0                  None                  None
#
# [7 rows x 24 columns]
